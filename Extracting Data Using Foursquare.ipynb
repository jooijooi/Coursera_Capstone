# %% [markdown]
# ### Notebook Used for Capstone Project

# %% [markdown]
# ## Description of the problem and a discussion of the background

# %% [markdown]
# #### Background
#
# During the Budget 2021, the goal of achieving 60,000 EV charging points at public carparks (40,000) and private premises (20,000) by 2030 was announced, as well as other measures  to support the adoption of electric vehicles (EVs). These include lowering the Additional Registration Fee (ARF) floor for fully electric cars and adjusting road tax for electric cars.
#
# By 2025, eight “EV-Ready Towns” across Singapore would be fitted with EV charging points (Ang Mo Kio, Bedok, Choa Chu Kang, Jurong West, Punggol, Queenstown, Sembawang and Tengah).These locations are well spread out across the island, and have a high concentration of car parks with existing electrical capacity to support the deployment of charging points.
#
# #### Challenge
#
# However, it is possible that these 40,000 EV charging points in HDB carparks might not be sufficient. Other than electrical capacity and grid contraints, we will be undertaking analysis on the number of existing carparks, number of hdb unit dwellings in the different estates as well as the number of employed residents by work place region, whose usual mode of transport to work is by car only. We will also be considering nearby places around carparks, where time could be spent at the office, dining, weekly errands or leisure activities since charging points will likely be slow chargers which require time to charge.
#
# Hence, these potential EV charging points could also be areas of consideration.

# %% [markdown]
# ## Description of the data and how it will be used to solve the problem

# %% [markdown]
# 4 different data sets will be used to analyse this issue:
# 1. List of HDB Carparks ('hdb-carpark-information.csv',source: https://data.gov.sg)
# 2. List HDB Dwelling Units ('hdb-property-information.csv', source: https://data.gov.sg)
# 3. Number of Employed Residents who only use car to travel to work by Workplace Region ('t111-118 .xlsx', https://www.singstat.gov.sg/)
# 4. Demographic data by Planning Area (
#
#
#
# https://www.lta.gov.sg/content/ltagov/en/industry_innovations/technologies/electric_vehicles.html/#ev_charger_deployment

# %%
#Importing relevant libraries
import pandas as pd
import numpy as np
import folium
from folium.plugins import MarkerCluster
import json
from pandas.io.json import json_normalize
import requests
from bs4 import BeautifulSoup
from pyproj import Proj, transform
#from pyproj import Transformer, transform
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm

from geopy.geocoders import Nominatim

import geopandas as gpd
#import branca.colormap as cm
import utm
import os

from sklearn.cluster import KMeans

# %% [markdown]
# ### The 8 Towns where EV charging points will be built: Ang Mo Kio, Bedok, Choa Chu Kang, Jurong West, Punggol, Queenstown, Sembawang, Tengah

# %%
ev_location=pd.read_csv('ev_location.csv')

# %%
ev_location
# Out:
#   planning_area_of_residence  area_longitude  area_latitude
# 0              CHOA CHU KANG      103.747191       1.385556
# 1                  SEMBAWANG      103.818828       1.455747
# 2                      BEDOK      103.928409       1.324047
# 3                 ANG MO KIO      103.842097       1.380092
# 4                    PUNGGOL      103.910043       1.405363
# 5                 QUEENSTOWN      103.784559       1.289073
# 6                JURONG WEST      103.704903       1.341612

# %%
#creating separate dataframe for each EV town
bedok=ev_location[(ev_location['planning_area_of_residence']=='BEDOK')]
bedok.reset_index(inplace=True,drop=True)
amk=ev_location[(ev_location['planning_area_of_residence']=='ANG MO KIO')]
amk.reset_index(inplace=True,drop=True)
punggol=ev_location[(ev_location['planning_area_of_residence']=='PUNGGOL')]
punggol.reset_index(inplace=True,drop=True)
queenstown=ev_location[(ev_location['planning_area_of_residence']=='QUEENSTOWN')]
queenstown.reset_index(inplace=True,drop=True)
jw=ev_location[(ev_location['planning_area_of_residence']=='JURONG WEST')]
jw.reset_index(inplace=True,drop=True)
semb=ev_location[(ev_location['planning_area_of_residence']=='SEMBAWANG')]
semb.reset_index(inplace=True,drop=True)
cck=ev_location[(ev_location['planning_area_of_residence']=='CHOA CHU KANG')]
cck.reset_index(inplace=True,drop=True)
tengah=ev_location[(ev_location['planning_area_of_residence']=='TENGAH')]
tengah.reset_index(inplace=True,drop=True)

# %% [markdown]
# ## Exploring Carpark Areas
#
# To maximize the 100 limit output provided by the Foursquare free API each EV town will be analyzed separately and  the 8 dataframes concatenated.

# %% [markdown]
# ## BEDOK

# %%
# @hidden_cell
#Defining Foursquare credentials and version
CLIENT_ID='5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K'
CLIENT_SECRET='UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR'
VERSION='20180605'

# %%
#create GET request URL

latitude=bedok.loc[0,'area_latitude']
longitude=bedok.loc[0,'area_longitude']

LIMIT=200
radius=1000

url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
CLIENT_ID,
CLIENT_SECRET,
VERSION,
latitude,
longitude,
radius,
LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K&client_secret=UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR&v=20180605&ll=1.3240468743815126,103.92840945179222&radius=1000&limit=200'

# %%
#send GET request url and examine results
results=requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '613da88984ec8e72cc691bff'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Bedok',
#   'headerFullLocation': 'Bedok, Singapore',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 107,
#   'suggestedBounds': {'ne': {'lat': 1.3330468833815217,
#     'lng': 103.9373950559067},
#    'sw': {'lat': 1.3150468653815035, 'lng': 103.91942384767773}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dca91d952b1c2222a85852c',
#        'name': 'Bedok Chwee Kueh 勿洛水粿',
#        'location': {'address': '#01-19 Bedok Interchange Hawker Centre',
#         'crossStreet': '207 New Upper Changi Rd',
#         'lat': 1.3249029,
#         'lng': 103.93025,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3249029,
#           'lng': 103.93025}],
#         'distance': 225,
#         'postalCode': '462208',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-19 Bedok Interchange Hawker Centre (207 New Upper Changi Rd)',
#          '462208',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dca91d952b1c2222a85852c-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59716c296e46504a8bb78069',
#        'name': 'Haidilao Hot Pot 海底捞火锅',
#        'location': {'address': '#01-13 to 17, Bedok Mall',
#         'crossStreet': '311 New Upper Changi Rd',
#         'lat': 1.3242986001170487,
#         'lng': 103.92910386284075,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3242986001170487,
#           'lng': 103.92910386284075}],
#         'distance': 82,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-13 to 17, Bedok Mall (311 New Upper Changi Rd)',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '52af0bd33cf9994f4e043bdd',
#          'name': 'Hotpot Restaurant',
#          'pluralName': 'Hotpot Restaurants',
#          'shortName': 'Hotpot',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59716c296e46504a8bb78069-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53a56590498ef405d8a19f19',
#        'name': 'Ya Kun Kaya Toast 亞坤',
#        'location': {'address': 'Bedok Mall',
#         'crossStreet': '311 New Upper Changi Rd.',
#         'lat': 1.324095089765238,
#         'lng': 103.92919839182038,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.324095089765238,
#           'lng': 103.92919839182038}],
#         'distance': 87,
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Bedok Mall (311 New Upper Changi Rd.)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53a56590498ef405d8a19f19-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4a5cf252b11cf651b0a9e5',
#        'name': 'Song Zhou Luo Bo Gao 松洲箩卜糕',
#        'location': {'address': '#01-37 Bedok Food Centre',
#         'crossStreet': '208 New Upper Changi Rd',
#         'lat': 1.3248355,
#         'lng': 103.93052,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3248355,
#           'lng': 103.93052}],
#         'distance': 250,
#         'postalCode': '460207',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-37 Bedok Food Centre (208 New Upper Changi Rd)',
#          '460207',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e4a5cf252b11cf651b0a9e5-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52ae8d0511d2b86a22cd24b1',
#        'name': 'FairPrice Fínest',
#        'location': {'address': '#B2-60, Bedok Mall',
#         'crossStreet': '311 New Upper Changi Rd',
#         'lat': 1.3241402975426375,
#         'lng': 103.92925975811036,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3241402975426375,
#           'lng': 103.92925975811036}],
#         'distance': 95,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-60, Bedok Mall (311 New Upper Changi Rd)',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52ae8d0511d2b86a22cd24b1-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52c403bd498e956216d60ea5',
#        'name': 'Greendot',
#        'location': {'address': '#B2-27, Bedok Mall',
#         'crossStreet': '311 New Upper Changi Rd.',
#         'lat': 1.3245056591834432,
#         'lng': 103.93016598933036,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3245056591834432,
#           'lng': 103.93016598933036}],
#         'distance': 202,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-27, Bedok Mall (311 New Upper Changi Rd.)',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52c403bd498e956216d60ea5-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52f8c5ae11d2ef1f1fcac674',
#        'name': 'Duke Bakery',
#        'location': {'address': '#01-08 Bedok Point',
#         'crossStreet': '799 New Upper Changi Road',
#         'lat': 1.3246906435156693,
#         'lng': 103.93251421920868,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3246906435156693,
#           'lng': 103.93251421920868}],
#         'distance': 462,
#         'postalCode': '467351',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-08 Bedok Point (799 New Upper Changi Road)',
#          '467351',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52f8c5ae11d2ef1f1fcac674-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '529d67e9498e7cc1c852e4c1',
#        'name': "McDonald's",
#        'location': {'address': '#01-10/11, Bedok Mall',
#         'crossStreet': '311 New Upper Changi Rd.',
#         'lat': 1.3241860346287102,
#         'lng': 103.9293885170949,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3241860346287102,
#           'lng': 103.9293885170949}],
#         'distance': 110,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-10/11, Bedok Mall (311 New Upper Changi Rd.)',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-529d67e9498e7cc1c852e4c1-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a71a765fdb9a74997f63685',
#        'name': 'Burger King',
#        'location': {'address': '#01-33, Heartbeat@Bedok',
#         'crossStreet': '11 Bedok North St 1',
#         'lat': 1.3269050384489067,
#         'lng': 103.93131817092124,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3269050384489067,
#           'lng': 103.93131817092124}],
#         'distance': 453,
#         'postalCode': '469662',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-33, Heartbeat@Bedok (11 Bedok North St 1)',
#          '469662',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a71a765fdb9a74997f63685-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52b26cbb498e263770d37db9',
#        'name': 'Pepper Lunch',
#        'location': {'address': '#01-04/05/06 Bedok Mall',
#         'crossStreet': '311 New Upper Changi Rd.',
#         'lat': 1.3241840559195814,
#         'lng': 103.92994751624296,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3241840559195814,
#           'lng': 103.92994751624296}],
#         'distance': 171,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-04/05/06 Bedok Mall (311 New Upper Changi Rd.)',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52b26cbb498e263770d37db9-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52a2f1a4498ea3cdf58b1c7b',
#        'name': 'Dian Xiao Er 店小二',
#        'location': {'address': '#01-73/74, Bedok Mall',
#         'crossStreet': '311 New Upper Changi Rd.',
#         'lat': 1.3251178539467172,
#         'lng': 103.93011942071624,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3251178539467172,
#           'lng': 103.93011942071624}],
#         'distance': 224,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-73/74, Bedok Mall (311 New Upper Changi Rd.)',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52a2f1a4498ea3cdf58b1c7b-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56960776498e19aa133341f1',
#        'name': 'Decathlon',
#        'location': {'address': '#01-01, ESR BizPark @Chai Chee',
#         'crossStreet': '750A Chai Chee Road',
#         'lat': 1.323037,
#         'lng': 103.922206,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.323037,
#           'lng': 103.922206}],
#         'distance': 699,
#         'postalCode': '469001',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01, ESR BizPark @Chai Chee (750A Chai Chee Road)',
#          '469001',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'shortName': 'Sporting Goods',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56960776498e19aa133341f1-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5555ecc4498e3bb61db2fda6',
#        'name': 'Baker & Cook',
#        'location': {'address': '1 Swan Lake Avenue',
#         'crossStreet': 'Opera Estate',
#         'lat': 1.320861174415304,
#         'lng': 103.9243451022693,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.320861174415304,
#           'lng': 103.9243451022693}],
#         'distance': 574,
#         'postalCode': '455700',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Swan Lake Avenue (Opera Estate)',
#          '455700',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5555ecc4498e3bb61db2fda6-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '529eca10498e761f66913b26',
#        'name': 'Wingstop',
#        'location': {'address': '#B1-53, Bedok Mall',
#         'crossStreet': '311 New Upper Changi Road',
#         'lat': 1.3244617725907446,
#         'lng': 103.93016092617682,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3244617725907446,
#           'lng': 103.93016092617682}],
#         'distance': 200,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Bedok New Town',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-53, Bedok Mall (311 New Upper Changi Road)',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d14c941735',
#          'name': 'Wings Joint',
#          'pluralName': 'Wings Joints',
#          'shortName': 'Wings',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-529eca10498e761f66913b26-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55587f48498e9be29c9071a9',
#        'name': 'PLANK Sourdough Pizza',
#        'location': {'address': '1 Swan Lake Avenue',
#         'lat': 1.3208650814396932,
#         'lng': 103.92432130671772,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3208650814396932,
#           'lng': 103.92432130671772}],
#         'distance': 576,
#         'postalCode': '455700',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Swan Lake Avenue', '455700', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55587f48498e9be29c9071a9-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c272194c11dc9b6c6222a24',
#        'name': 'Na Na Curry',
#        'location': {'address': 'Kopitiam',
#         'crossStreet': '205 Bedok North Street 1',
#         'lat': 1.3261518,
#         'lng': 103.931175,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3261518,
#           'lng': 103.931175}],
#         'distance': 386,
#         'postalCode': '460205',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Kopitiam (205 Bedok North Street 1)',
#          '460205',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c272194c11dc9b6c6222a24-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d340dfd6c7c721e4dacbe56',
#        'name': 'New World Mutton Soup',
#        'location': {'address': 'Bedok Interchange Food Centre',
#         'crossStreet': '1 Bedok Rd',
#         'lat': 1.3250603703044297,
#         'lng': 103.93013830399353,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3250603703044297,
#           'lng': 103.93013830399353}],
#         'distance': 223,
#         'postalCode': '469572',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Bedok Interchange Food Centre (1 Bedok Rd)',
#          '469572',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1dd931735',
#          'name': 'Soup Place',
#          'pluralName': 'Soup Places',
#          'shortName': 'Soup',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/soup_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d340dfd6c7c721e4dacbe56-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '547b0bf5498e3f5770006892',
#        'name': 'FATCAT Ice Cream Bar',
#        'location': {'address': 'Blk 416 Bedok North Ave 2 #01-25',
#         'crossStreet': 'Bedok North, opp Bedok Library',
#         'lat': 1.328218962974053,
#         'lng': 103.93093902975485,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.328218962974053,
#           'lng': 103.93093902975485}],
#         'distance': 543,
#         'postalCode': '460416',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 416 Bedok North Ave 2 #01-25 (Bedok North, opp Bedok Library)',
#          '460416',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '103595568'}},
#       'referralId': 'e-0-547b0bf5498e3f5770006892-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56b1dcf2498eb5612b87023c',
#        'name': "Stuff'd",
#        'location': {'address': 'Bedok Mall B2',
#         'lat': 1.32421000772689,
#         'lng': 103.92935771852014,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.32421000772689,
#           'lng': 103.92935771852014}],
#         'distance': 107,
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'country': 'Singapore',
#         'formattedAddress': ['Bedok Mall B2', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d153941735',
#          'name': 'Burrito Place',
#          'pluralName': 'Burrito Places',
#          'shortName': 'Burritos',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56b1dcf2498eb5612b87023c-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5324821311d2391c01c3400f',
#        'name': 'Percolate',
#        'location': {'address': '#01-152, 136 Bedok North Ave 3',
#         'lat': 1.3280465983256822,
#         'lng': 103.93523454666138,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3280465983256822,
#           'lng': 103.93523454666138}],
#         'distance': 880,
#         'postalCode': '460136',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-152, 136 Bedok North Ave 3',
#          '460136',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5324821311d2391c01c3400f-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb9e4957421a593ea1dc340',
#        'name': 'Bedok Interchange Hawker Centre',
#        'location': {'address': '208B New Upper Changi Rd.',
#         'lat': 1.3245557429332013,
#         'lng': 103.93033364568173,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3245557429332013,
#           'lng': 103.93033364568173}],
#         'distance': 221,
#         'postalCode': '460207',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['208B New Upper Changi Rd.',
#          '460207',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb9e4957421a593ea1dc340-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '582ae1d595ffcb36250f4df5',
#        'name': 'Nakhon Kitchen',
#        'location': {'address': 'Blk 136, Bedok North Avenue 3, #01-166',
#         'lat': 1.3283978858625856,
#         'lng': 103.93496523373656,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3283978858625856,
#           'lng': 103.93496523373656}],
#         'distance': 875,
#         'postalCode': '460136',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Bedok New Town',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 136, Bedok North Avenue 3, #01-166',
#          '460136',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-582ae1d595ffcb36250f4df5-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '529f16f4498e761f69bb1f26',
#        'name': 'Starbucks',
#        'location': {'address': '#01-92/93, Bedok Mall',
#         'crossStreet': '311 New Upper Changi Rd.',
#         'lat': 1.32476,
#         'lng': 103.929644,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.32476,
#           'lng': 103.929644}],
#         'distance': 158,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-92/93, Bedok Mall (311 New Upper Changi Rd.)',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-529f16f4498e761f69bb1f26-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52aedf7b11d21901942ba969',
#        'name': 'MOS Burger',
#        'location': {'address': '#B2-29, Bedok Mall',
#         'crossStreet': '311 New Upper Changi Rd',
#         'lat': 1.324808,
#         'lng': 103.929638,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.324808,
#           'lng': 103.929638}],
#         'distance': 160,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-29, Bedok Mall (311 New Upper Changi Rd)',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52aedf7b11d21901942ba969-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d09858c8ea0a1432f18e173',
#        'name': 'Boon Keng Rd Fishhead Beehoon',
#        'location': {'address': 'Blk 416 Bedok North Ave 2',
#         'lat': 1.328993662082405,
#         'lng': 103.93082499075291,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.328993662082405,
#           'lng': 103.93082499075291}],
#         'distance': 612,
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 416 Bedok North Ave 2', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d09858c8ea0a1432f18e173-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51444cc7e4b08f777c224e87',
#        'name': 'Saffrons Cafeteria',
#        'location': {'address': 'Swan Lake Ave',
#         'lat': 1.32152424230042,
#         'lng': 103.92419919502134,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.32152424230042,
#           'lng': 103.92419919502134}],
#         'distance': 546,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Swan Lake Ave', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51444cc7e4b08f777c224e87-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c47e17976d72d7fdab23e4d',
#        'name': 'Inspirasi Stall',
#        'location': {'address': '207 New Upper Changi Rd',
#         'crossStreet': 'Bedok Central Food Centre #01-64',
#         'lat': 1.3247112,
#         'lng': 103.930504,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3247112,
#           'lng': 103.930504}],
#         'distance': 244,
#         'postalCode': '467345',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['207 New Upper Changi Rd (Bedok Central Food Centre #01-64)',
#          '467345',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d156941735',
#          'name': 'Malay Restaurant',
#          'pluralName': 'Malay Restaurants',
#          'shortName': 'Malay',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/malaysian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c47e17976d72d7fdab23e4d-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c21b5ac11de20a115c383ce',
#        'name': 'Happy Days',
#        'location': {'address': 'Bedok Point',
#         'lat': 1.3247992926344274,
#         'lng': 103.93240878625875,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3247992926344274,
#           'lng': 103.93240878625875}],
#         'distance': 452,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Bedok Point', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c21b5ac11de20a115c383ce-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5530bab7498ef49d4dbe91cf',
#        'name': 'Yolé',
#        'location': {'address': '#01-40, Bedok Mall',
#         'crossStreet': '311 New Upper Changi Road',
#         'lat': 1.324410497205912,
#         'lng': 103.92955899238586,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.324410497205912,
#           'lng': 103.92955899238586}],
#         'distance': 134,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-40, Bedok Mall (311 New Upper Changi Road)',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '512e7cae91d4cbb4e5efe0af',
#          'name': 'Frozen Yogurt Shop',
#          'pluralName': 'Frozen Yogurt Shops',
#          'shortName': 'Yogurt',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/frozenyogurt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5530bab7498ef49d4dbe91cf-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52ae848311d2ab1eb31e775d',
#        'name': 'Popular Bookstore',
#        'location': {'address': 'B2-02/35/36, Bedok Mall',
#         'crossStreet': '311 New Upper Changi Rd.',
#         'lat': 1.3250000788567375,
#         'lng': 103.93011451106963,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3250000788567375,
#           'lng': 103.93011451106963}],
#         'distance': 217,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['B2-02/35/36, Bedok Mall (311 New Upper Changi Rd.)',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52ae848311d2ab1eb31e775d-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c78993fdf08a1cd5433d85d',
#        'name': 'Blk 216 Bedok North Street 1 Hawker & Food Centre',
#        'location': {'address': '216 Bedok North St. 1',
#         'lat': 1.3269989614587994,
#         'lng': 103.93303136448313,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3269989614587994,
#           'lng': 103.93303136448313}],
#         'distance': 610,
#         'postalCode': '460216',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['216 Bedok North St. 1', '460216', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c78993fdf08a1cd5433d85d-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5277d0ab11d23d421217454c',
#        'name': 'Bedok Mall',
#        'location': {'address': '311 New Upper Changi Rd.',
#         'lat': 1.3249843365280987,
#         'lng': 103.92936050891876,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3249843365280987,
#           'lng': 103.92936050891876}],
#         'distance': 148,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['311 New Upper Changi Rd.',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5277d0ab11d23d421217454c-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50ebe571e4b0aaf3b73fdce4',
#        'name': 'Starbucks',
#        'location': {'address': '#01-09 & #01-K2/K3/K4, Bedok Point',
#         'crossStreet': '799 New Upper Changi Rd',
#         'lat': 1.3245679190185344,
#         'lng': 103.93251777408432,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3245679190185344,
#           'lng': 103.93251777408432}],
#         'distance': 460,
#         'postalCode': '467351',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-09 & #01-K2/K3/K4, Bedok Point (799 New Upper Changi Rd)',
#          '467351',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50ebe571e4b0aaf3b73fdce4-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '596b642add70c52f2d246544',
#        'name': 'Harvey Norman Factory Outlet',
#        'location': {'address': '#01-01 to 06, #01-09 to 12, #02-02 to 06, ESR BizPark @Chai Chee',
#         'crossStreet': '750B Chai Chee Road',
#         'lat': 1.32307001076516,
#         'lng': 103.92179585546533,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.32307001076516,
#           'lng': 103.92179585546533}],
#         'distance': 744,
#         'postalCode': '469002',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01 to 06, #01-09 to 12, #02-02 to 06, ESR BizPark @Chai Chee (750B Chai Chee Road)',
#          '469002',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-596b642add70c52f2d246544-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52a30ddf11d2141b9680d53e',
#        'name': 'UNIQLO',
#        'location': {'address': '#B1-26/27/28, Bedok Mall',
#         'crossStreet': '311 New Upper Changi Rd.',
#         'lat': 1.324106177835493,
#         'lng': 103.92918636324762,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.324106177835493,
#           'lng': 103.92918636324762}],
#         'distance': 86,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-26/27/28, Bedok Mall (311 New Upper Changi Rd.)',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'shortName': 'Apparel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52a30ddf11d2141b9680d53e-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '592553e9364d971c13e86ad2',
#        'name': 'Le Nu',
#        'location': {'address': '311 New Upper Changi Road',
#         'crossStreet': '#B2-10 Bedok Mall',
#         'lat': 1.324732,
#         'lng': 103.929828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.324732,
#           'lng': 103.929828}],
#         'distance': 175,
#         'postalCode': '467360',
#         'cc': 'SG',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['311 New Upper Changi Road (#B2-10 Bedok Mall)',
#          '467360',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-592553e9364d971c13e86ad2-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59982a4f16fa041f2b28879c',
#        'name': 'Tasty Court by Chef Pung',
#        'location': {'lat': 1.315609,
#         'lng': 103.925841,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.315609,
#           'lng': 103.925841}],
#         'distance': 981,
#         'postalCode': '458322',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Siglap',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['458322', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59982a4f16fa041f2b28879c-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb7b8da7148f04d7bbacaab',
#        'name': 'Chris Kway Chap',
#        'location': {'address': '#01-80 Blk 216 Bedok North Street 1 Hawker & Food Centre',
#         'lat': 1.327171737022058,
#         'lng': 103.93308497748515,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.327171737022058,
#           'lng': 103.93308497748515}],
#         'distance': 625,
#         'postalCode': '460216',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-80 Blk 216 Bedok North Street 1 Hawker & Food Centre',
#          '460216',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb7b8da7148f04d7bbacaab-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc8156273fd6dcb98df1986',
#        'name': 'Nangfa Thai Kitchen',
#        'location': {'address': '136 Bedok North Ave 3, #01-166',
#         'lat': 1.3284636289781588,
#         'lng': 103.93493632372046,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3284636289781588,
#           'lng': 103.93493632372046}],
#         'distance': 877,
#         'postalCode': '460136',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['136 Bedok North Ave 3, #01-166',
#          '460136',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cc8156273fd6dcb98df1986-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59297a290a464d4b293933ca',
#        'name': "Arnold's Fried Chicken",
#        'location': {'address': '215 Bedok North Street 1 #01-83',
#         'crossStreet': '#01-83',
#         'lat': 1.3259099651418784,
#         'lng': 103.93369275199225,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3259099651418784,
#           'lng': 103.93369275199225}],
#         'distance': 623,
#         'postalCode': '460215',
#         'cc': 'SG',
# ...
#       'referralId': 'e-0-4c832ccad92ea093d6455272-85'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '580caa55d67c58094e66e2e0',
#        'name': 'ESR BizPark @Chai Chee',
#        'location': {'address': '750 Chai Chee Road',
#         'lat': 1.3233596401512726,
#         'lng': 103.92206581618031,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3233596401512726,
#           'lng': 103.92206581618031}],
#         'distance': 710,
#         'postalCode': '469000',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['750 Chai Chee Road', '469000', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-580caa55d67c58094e66e2e0-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5aaa260a4c954c31ff010ea9',
#        'name': 'BLACK&INK',
#        'location': {'address': '29 Swan Lake Avenue',
#         'lat': 1.3216011388736255,
#         'lng': 103.92400196531324,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3216011388736255,
#           'lng': 103.92400196531324}],
#         'distance': 560,
#         'postalCode': '455718',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'state': 'East',
#         'country': 'Singapore',
#         'formattedAddress': ['29 Swan Lake Avenue', '455718', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5aaa260a4c954c31ff010ea9-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55b61bf9498ec2cfa6346147',
#        'name': 'Eighteen Chefs',
#        'location': {'address': '#01-05/06, Bedok Mall',
#         'lat': 1.3261528,
#         'lng': 103.929695,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3261528,
#           'lng': 103.929695}],
#         'distance': 274,
#         'postalCode': '469661',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-05/06, Bedok Mall', '469661', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55b61bf9498ec2cfa6346147-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6cf244f964a5207d5f2ce3',
#        'name': 'Chai Chee 29 Food House',
#        'location': {'address': '29B Chai Chee Ave, #01-60',
#         'lat': 1.32417934556663,
#         'lng': 103.92381744805154,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.32417934556663,
#           'lng': 103.92381744805154}],
#         'distance': 511,
#         'postalCode': '462029',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['29B Chai Chee Ave, #01-60',
#          '462029',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6cf244f964a5207d5f2ce3-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4daf8ffea86e9639ef5033b5',
#        'name': 'Bus Stop 84021 (Blk 32)',
#        'location': {'address': 'New Upper Changi Road',
#         'lat': 1.3233694411503962,
#         'lng': 103.92507637421146,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3233694411503962,
#           'lng': 103.92507637421146}],
#         'distance': 378,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['New Upper Changi Road', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4daf8ffea86e9639ef5033b5-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c028be498e59a8b6f37472',
#        'name': 'Royz et Vous',
#        'location': {'address': '750 Chai Chee Rd',
#         'crossStreet': 'Viva Ind Park',
#         'lat': 1.3232623479596033,
#         'lng': 103.92288151512432,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3232623479596033,
#           'lng': 103.92288151512432}],
#         'distance': 621,
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['750 Chai Chee Rd (Viva Ind Park)', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c028be498e59a8b6f37472-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca237ceb0ff8cfa50f3ac5e',
#        'name': '7-Eleven',
#        'location': {'address': '1 Chai Chee Rd.',
#         'lat': 1.3268604797124406,
#         'lng': 103.92534014557091,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3268604797124406,
#           'lng': 103.92534014557091}],
#         'distance': 463,
#         'postalCode': '461001',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Chai Chee Rd.', '461001', 'Singapore']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca237ceb0ff8cfa50f3ac5e-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb32101715eef3bcff385bb',
#        'name': 'Sheng Siong Supermarket',
#        'location': {'address': '539A Bedok North St 3 #01-477',
#         'lat': 1.3322887095364913,
#         'lng': 103.92521917819977,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3322887095364913,
#           'lng': 103.92521917819977}],
#         'distance': 983,
#         'postalCode': '461539',
#         'cc': 'SG',
#         'neighborhood': 'Bedok North',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['539A Bedok North St 3 #01-477',
#          '461539',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb32101715eef3bcff385bb-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d102a217177b1f77fec4f22',
#        'name': "Domino's Pizza",
#        'location': {'address': '218 Bedok North 1 #01-15',
#         'lat': 1.3276911865704664,
#         'lng': 103.93493654902896,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3276911865704664,
#           'lng': 103.93493654902896}],
#         'distance': 832,
#         'postalCode': '460218',
#         'cc': 'SG',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['218 Bedok North 1 #01-15',
#          '460218',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d102a217177b1f77fec4f22-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de5f3287d8b53987c5515ab',
#        'name': 'Food Hub @ Chai Chee 福阁食厅',
#        'location': {'address': '26A Chai Chee Rd',
#         'lat': 1.323398058984963,
#         'lng': 103.92309188418734,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.323398058984963,
#           'lng': 103.92309188418734}],
#         'distance': 596,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['26A Chai Chee Rd', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4de5f3287d8b53987c5515ab-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f9de6dde4b044503c01d221',
#        'name': 'Chai Chee Minced Meat Noodle 菜市肉脞面',
#        'location': {'address': 'Blk 216 Bedok North Street 1 #01-64',
#         'lat': 1.3269420991154748,
#         'lng': 103.93304220593657,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3269420991154748,
#           'lng': 103.93304220593657}],
#         'distance': 608,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 216 Bedok North Street 1 #01-64',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f9de6dde4b044503c01d221-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd6679c7da9a35dbd86efb9',
#        'name': 'Playground @ Jalan Bangsawan',
#        'location': {'address': 'Jalan Bangsawan',
#         'lat': 1.3219081948391922,
#         'lng': 103.92354441981654,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3219081948391922,
#           'lng': 103.92354441981654}],
#         'distance': 591,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Jalan Bangsawan', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd6679c7da9a35dbd86efb9-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5acb534ec365880b26da641c',
#        'name': 'Burgs by Project Warung',
#        'location': {'address': 'Viva Business Park, Centuries Food Court',
#         'lat': 1.323437,
#         'lng': 103.92239,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.323437,
#           'lng': 103.92239}],
#         'distance': 673,
#         'postalCode': '469000',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Bedok New Town',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Viva Business Park, Centuries Food Court',
#          '469000',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5acb534ec365880b26da641c-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be2213ed27a20a12f068f5b',
#        'name': '333 Coffee Shop',
#        'location': {'address': 'Blk 136 Bedok North Ave 3',
#         'lat': 1.327783618597987,
#         'lng': 103.93490902342911,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.327783618597987,
#           'lng': 103.93490902342911}],
#         'distance': 834,
#         'postalCode': '469715',
#         'cc': 'SG',
#         'neighborhood': 'Bedok',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 136 Bedok North Ave 3',
#          '469715',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be2213ed27a20a12f068f5b-99'}]}]}}

# %%
#function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list=row['categories']
    except:
        categories_list=row['venue.categories']
    
    if len(categories_list)==0:
        return None
    else:
        return categories_list[0]['name']

# %%
#Cleaning the json and structuring it into a Pandas DataFrame
venues = results['response']['groups'][0]['items']

#flatten json
nearby_venues = pd.json_normalize(venues)
                       
#filter columns
filtered_columns=['venue.name','venue.categories','venue.location.lat','venue.location.lng']
nearby_venues=nearby_venues.loc[:,filtered_columns]

#filter category for each row
nearby_venues['venue.categories']=nearby_venues.apply(get_category_type, axis=1)
                           
#clean columns
nearby_venues.columns=[col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head(200)
# Out:
#                                   name          categories       lat  \
# 0                Bedok Chwee Kueh 勿洛水粿  Chinese Restaurant  1.324903
# 1               Haidilao Hot Pot 海底捞火锅   Hotpot Restaurant  1.324299
# 2                 Ya Kun Kaya Toast 亞坤         Coffee Shop  1.324095
# 3           Song Zhou Luo Bo Gao 松洲箩卜糕      Breakfast Spot  1.324836
# 4                     FairPrice Fínest         Supermarket  1.324140
# ..                                 ...                 ...       ...
# 95           Food Hub @ Chai Chee 福阁食厅          Food Court  1.323398
# 96  Chai Chee Minced Meat Noodle 菜市肉脞面        Noodle House  1.326942
# 97        Playground @ Jalan Bangsawan          Playground  1.321908
# 98             Burgs by Project Warung        Burger Joint  1.323437
# 99                     333 Coffee Shop         Coffee Shop  1.327784
#
#            lng
# 0   103.930250
# 1   103.929104
# 2   103.929198
# 3   103.930520
# 4   103.929260
# ..         ...
# 95  103.923092
# 96  103.933042
# 97  103.923544
# 98  103.922390
# 99  103.934909
#
# [100 rows x 4 columns]

# %%
#create 3 additional columns to indicate respective planning area and its longitude and latitude
bedok=nearby_venues.assign(planning_area='BEDOK',
                           area_latitude=latitude,
                           area_longitude=longitude)

# %%
#Repositioning the columns and renaming the column names

bedok=bedok[['planning_area','area_latitude','area_longitude','name','lat','lng','categories']]

bedok.rename(columns={'name':'venue_name',
            'lat':'venue_latitude',
             'lng':'venue_longitude',
             'categories':'venue_categories'}, inplace=True)

# %%
# Check data
bedok
# Out:
#    planning_area  area_latitude  area_longitude  \
# 0          BEDOK       1.324047      103.928409
# 1          BEDOK       1.324047      103.928409
# 2          BEDOK       1.324047      103.928409
# 3          BEDOK       1.324047      103.928409
# 4          BEDOK       1.324047      103.928409
# ..           ...            ...             ...
# 95         BEDOK       1.324047      103.928409
# 96         BEDOK       1.324047      103.928409
# 97         BEDOK       1.324047      103.928409
# 98         BEDOK       1.324047      103.928409
# 99         BEDOK       1.324047      103.928409
#
#                             venue_name  venue_latitude  venue_longitude  \
# 0                Bedok Chwee Kueh 勿洛水粿        1.324903       103.930250
# 1               Haidilao Hot Pot 海底捞火锅        1.324299       103.929104
# 2                 Ya Kun Kaya Toast 亞坤        1.324095       103.929198
# 3           Song Zhou Luo Bo Gao 松洲箩卜糕        1.324836       103.930520
# 4                     FairPrice Fínest        1.324140       103.929260
# ..                                 ...             ...              ...
# 95           Food Hub @ Chai Chee 福阁食厅        1.323398       103.923092
# 96  Chai Chee Minced Meat Noodle 菜市肉脞面        1.326942       103.933042
# 97        Playground @ Jalan Bangsawan        1.321908       103.923544
# 98             Burgs by Project Warung        1.323437       103.922390
# 99                     333 Coffee Shop        1.327784       103.934909
#
#       venue_categories
# 0   Chinese Restaurant
# 1    Hotpot Restaurant
# 2          Coffee Shop
# 3       Breakfast Spot
# 4          Supermarket
# ..                 ...
# 95          Food Court
# 96        Noodle House
# 97          Playground
# 98        Burger Joint
# 99         Coffee Shop
#
# [100 rows x 7 columns]

# %%
bedok.to_csv("bedok.csv")

# %% [markdown]
# ## JURONG WEST

# %%
# @hidden_cell
#Defining Foursquare credentials and version
CLIENT_ID='5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K'
CLIENT_SECRET='UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR'
VERSION='20180605'

# %%
# Create GET request url
latitude=jw.loc[0,'area_latitude']
longitude=jw.loc[0,'area_longitude']

LIMIT=200
radius=1000

url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
CLIENT_ID,
CLIENT_SECRET,
VERSION,
latitude,
longitude,
radius,
LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K&client_secret=UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR&v=20180605&ll=1.3416119936431667,103.70490266187328&radius=1000&limit=200'

# %%
#send GET request url and examine results
results=requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '613da8b2d1665508d2cdfa2b'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Jurong West',
#   'headerFullLocation': 'Jurong West, Singapore',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 78,
#   'suggestedBounds': {'ne': {'lat': 1.3506120026431758,
#     'lng': 103.71388833008032},
#    'sw': {'lat': 1.3326119846431577, 'lng': 103.69591699366623}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf92990b182c9b6bf7a785a',
#        'name': "Carl's Jr.",
#        'location': {'address': '#02-42, Jurong Point (JP1)',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.340574772014918,
#         'lng': 103.70638409348805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.340574772014918,
#           'lng': 103.70638409348805}],
#         'distance': 201,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-42, Jurong Point (JP1) (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf92990b182c9b6bf7a785a-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b99a1b3f964a520a68835e3',
#        'name': 'Subway',
#        'location': {'address': '#01-32A, Jurong Point (JP1)',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.3402782215026714,
#         'lng': 103.70654837343909,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3402782215026714,
#           'lng': 103.70654837343909}],
#         'distance': 235,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'neighborhood': 'Jurong West',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-32A, Jurong Point (JP1) (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b99a1b3f964a520a68835e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb53feb6edc76b07f832f1c',
#        'name': 'Ya Kun Kaya Toast',
#        'location': {'address': '#01-07/08 Boon Lay MRT Station',
#         'crossStreet': '301 Boon Lay Way',
#         'lat': 1.339619026719961,
#         'lng': 103.70578609670542,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.339619026719961,
#           'lng': 103.70578609670542}],
#         'distance': 242,
#         'postalCode': '649846',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-07/08 Boon Lay MRT Station (301 Boon Lay Way)',
#          '649846',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb53feb6edc76b07f832f1c-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0bddb84d49ef3bf6fa5b6a',
#        'name': 'PUTIEN Restaurant 莆田菜馆',
#        'location': {'address': '#02-34 Jurong Point (JP1)',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.3403995886337043,
#         'lng': 103.70646756600489,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3403995886337043,
#           'lng': 103.70646756600489}],
#         'distance': 220,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-34 Jurong Point (JP1) (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0bddb84d49ef3bf6fa5b6a-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a5b255cda7080394db05b14',
#        'name': 'Din Tai Fung 鼎泰豐 (Din Tai Fung)',
#        'location': {'address': '#B1-68/69, Jurong Point (JP2)',
#         'crossStreet': '63 Jurong West Central 3',
#         'lat': 1.3390294738962747,
#         'lng': 103.70576467069365,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3390294738962747,
#           'lng': 103.70576467069365}],
#         'distance': 303,
#         'postalCode': '648331',
#         'cc': 'SG',
#         'city': 'Jurong Town',
#         'state': 'South West Community Development Council',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-68/69, Jurong Point (JP2) (63 Jurong West Central 3)',
#          '648331',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a5b255cda7080394db05b14-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53d5ff8a498e1ed5df4e9cb4',
#        'name': 'Legendary Hong Kong 港饮港食',
#        'location': {'address': '#03-80, Jurong Point Shopping Centre',
#         'crossStreet': '63 Jurong West Central 3',
#         'lat': 1.339817312976089,
#         'lng': 103.70589077097227,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.339817312976089,
#           'lng': 103.70589077097227}],
#         'distance': 228,
#         'postalCode': '648331',
#         'cc': 'SG',
#         'neighborhood': 'Jurong West, Singapore',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#03-80, Jurong Point Shopping Centre (63 Jurong West Central 3)',
#          '648331',
#          'Singapore']},
#        'categories': [{'id': '58daa1558bbb0b01f18ec1d3',
#          'name': 'Cha Chaan Teng',
#          'pluralName': 'Cha Chaan Tengs',
#          'shortName': 'Cha Chaan Teng',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53d5ff8a498e1ed5df4e9cb4-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c065e5a91d776b003b7f8f9',
#        'name': 'Starbucks',
#        'location': {'address': '#03-52, Jurong Point (JP2)',
#         'crossStreet': '63 Jurong West Ctrl 3',
#         'lat': 1.338905506248772,
#         'lng': 103.70564235029383,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.338905506248772,
#           'lng': 103.70564235029383}],
#         'distance': 312,
#         'postalCode': '648337',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#03-52, Jurong Point (JP2) (63 Jurong West Ctrl 3)',
#          '648337',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c065e5a91d776b003b7f8f9-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058817f964a5203eb122e3',
#        'name': 'Jurong Point',
#        'location': {'address': '1 Jurong West Central 2',
#         'crossStreet': 'Jurong West Central 3',
#         'lat': 1.3391210655133183,
#         'lng': 103.70635165790331,
#         'distance': 320,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Jurong West Central 2 (Jurong West Central 3)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058817f964a5203eb122e3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50740940e4b09794da8dd53a',
#        'name': 'Malaysia Boleh!',
#        'location': {'address': '#03-28, Jurong Point Shopping Centre (JP2)',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.3388558900922622,
#         'lng': 103.70521529434546,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3388558900922622,
#           'lng': 103.70521529434546}],
#         'distance': 308,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#03-28, Jurong Point Shopping Centre (JP2) (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50740940e4b09794da8dd53a-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54f14dfa498e6a39f072211a',
#        'name': 'Ichiban Boshi',
#        'location': {'address': '#B1-75/76, Jurong Point',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.3389864856170495,
#         'lng': 103.7059128540334,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3389864856170495,
#           'lng': 103.7059128540334}],
#         'distance': 313,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'neighborhood': 'Jurong West',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-75/76, Jurong Point (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54f14dfa498e6a39f072211a-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '560cca01498e7c713b92aaf9',
#        'name': '4Fingers Crispy Chicken',
#        'location': {'address': 'Jurong Point',
#         'lat': 1.3405153370978315,
#         'lng': 103.70642670526469,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3405153370978315,
#           'lng': 103.70642670526469}],
#         'distance': 208,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Jurong Point', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d14c941735',
#          'name': 'Wings Joint',
#          'pluralName': 'Wings Joints',
#          'shortName': 'Wings',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/wings_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-560cca01498e7c713b92aaf9-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b827134f964a5204fd330e3',
#        'name': 'Dian Xiao Er 店小二',
#        'location': {'address': '#B1-57/58/59, Jurong Point',
#         'crossStreet': '63 Jurong West Central 3',
#         'lat': 1.338877321920833,
#         'lng': 103.70551659537135,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.338877321920833,
#           'lng': 103.70551659537135}],
#         'distance': 311,
#         'postalCode': '648331',
#         'cc': 'SG',
#         'neighborhood': 'Jurong West',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-57/58/59, Jurong Point (63 Jurong West Central 3)',
#          '648331',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b827134f964a5204fd330e3-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b38adedf964a5205c4f25e3',
#        'name': 'Golden Village',
#        'location': {'address': '#03-25B/26, Jurong Point (JP1)',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.3403784530831864,
#         'lng': 103.70645178943121,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3403784530831864,
#           'lng': 103.70645178943121}],
#         'distance': 220,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#03-25B/26, Jurong Point (JP1) (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'shortName': 'Cineplex',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b38adedf964a5205c4f25e3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '506d3504e4b04e90355d47c5',
#        'name': 'Boon Lay Cafe',
#        'location': {'address': '#01-13 Boon Lay MRT Station',
#         'lat': 1.3390516517106479,
#         'lng': 103.70587093073208,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3390516517106479,
#           'lng': 103.70587093073208}],
#         'distance': 304,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-13 Boon Lay MRT Station', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-506d3504e4b04e90355d47c5-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56175099498e1ee7f3f53e72',
#        'name': 'Sushi Express 争鮮回転寿司',
#        'location': {'address': 'Jurong Point',
#         'crossStreet': '63 Jurong West Central 3',
#         'lat': 1.3387845551939093,
#         'lng': 103.70525966634135,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3387845551939093,
#           'lng': 103.70525966634135}],
#         'distance': 317,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Jurong Point (63 Jurong West Central 3)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56175099498e1ee7f3f53e72-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdb73f44006a1436bcbd8b2',
#        'name': 'Popular Bookstore',
#        'location': {'address': '#B1-41, Jurong Point (JP1)',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.3403822999886263,
#         'lng': 103.70679173340145,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3403822999886263,
#           'lng': 103.70679173340145}],
#         'distance': 250,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-41, Jurong Point (JP1) (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cdb73f44006a1436bcbd8b2-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbc7606e4529521e4e055a4',
#        'name': 'KFC',
#        'location': {'address': '#01-30 Jurong Point (JP1)',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.339841876840794,
#         'lng': 103.70652844653279,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.339841876840794,
#           'lng': 103.70652844653279}],
#         'distance': 267,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-30 Jurong Point (JP1) (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbc7606e4529521e4e055a4-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fdd5daee4b0d60dd8d4d337',
#        'name': 'Central Hong Kong Cafe 中环香港茶餐厅',
#        'location': {'address': 'Jurong Point Shopping Centre (JP2)',
#         'crossStreet': 'Jurong West',
#         'lat': 1.3404009483632162,
#         'lng': 103.70593904606093,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3404009483632162,
#           'lng': 103.70593904606093}],
#         'distance': 177,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Jurong Point Shopping Centre (JP2) (Jurong West)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fdd5daee4b0d60dd8d4d337-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cba802b7148f04d2434ddab',
#        'name': 'Pizza Hut',
#        'location': {'address': '1 Jurong West Central 2, #01-33 Jurong Point Shopping Centre',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.3397416185242368,
#         'lng': 103.70671736182216,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3397416185242368,
#           'lng': 103.70671736182216}],
#         'distance': 290,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'neighborhood': 'Jurong West',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Jurong West Central 2, #01-33 Jurong Point Shopping Centre (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cba802b7148f04d2434ddab-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b50436bf964a520561f27e3',
#        'name': 'Soup Restaurant 三盅两件',
#        'location': {'address': '#02-33, Jurong Point Shopping Centre',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.3403399840747485,
#         'lng': 103.7065201234175,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3403399840747485,
#           'lng': 103.7065201234175}],
#         'distance': 229,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-33, Jurong Point Shopping Centre (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b50436bf964a520561f27e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4c119af964a520ddad26e3',
#        'name': "McDonald's / McCafé",
#        'location': {'address': '#01-31, Jurong Point (JP1)',
#         'crossStreet': '1 Jurong West Ctrl 2',
#         'lat': 1.3398517874852698,
#         'lng': 103.70655761174972,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3398517874852698,
#           'lng': 103.70655761174972}],
#         'distance': 268,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-31, Jurong Point (JP1) (1 Jurong West Ctrl 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4c119af964a520ddad26e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d43c1ade198721e4fbab48b',
#        'name': 'Ya Kun Kaya Toast 亞坤',
#        'location': {'address': '#02-K1/K2, Jurong Point (JP1)',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.3400372461543018,
#         'lng': 103.70667643634059,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3400372461543018,
#           'lng': 103.70667643634059}],
#         'distance': 264,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-K1/K2, Jurong Point (JP1) (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d43c1ade198721e4fbab48b-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4520b50349224b4eca014f',
#        'name': 'Shokutsu TEN Japanese Food Street',
#        'location': {'address': 'B1, Jurong Point',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.3394017453176106,
#         'lng': 103.70695393835204,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3394017453176106,
#           'lng': 103.70695393835204}],
#         'distance': 335,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['B1, Jurong Point (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d4520b50349224b4eca014f-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56139d5d498ed4c504ac3f98',
#        'name': 'Monster Curry',
#        'location': {'address': 'Jurong Point 2, #03-57',
#         'lat': 1.3389723093681292,
#         'lng': 103.70589561015095,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3389723093681292,
#           'lng': 103.70589561015095}],
#         'distance': 313,
#         'postalCode': '648331',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Jurong Point 2, #03-57', '648331', 'Singapore']},
#        'categories': [{'id': '55a59bace4b013909087cb30',
#          'name': 'Japanese Curry Restaurant',
#          'pluralName': 'Japanese Curry Restaurants',
#          'shortName': 'Japanese Curry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56139d5d498ed4c504ac3f98-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd572f56f6495214f076fec',
#        'name': 'Shihlin Taiwan Street Snacks 士林台湾小吃',
#        'location': {'address': '#01-34, Jurong Point',
#         'crossStreet': '1 Jurong West Central',
#         'lat': 1.3387312352479275,
#         'lng': 103.7053315063212,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3387312352479275,
#           'lng': 103.7053315063212}],
#         'distance': 324,
#         'postalCode': '649846',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-34, Jurong Point (1 Jurong West Central)',
#          '649846',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd572f56f6495214f076fec-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '528e0ca6498e555880400ef8',
#        'name': 'Hee Kee Desserts 囍记',
#        'location': {'address': '1 Jurong West Central 2 #03-54/55',
#         'crossStreet': 'Jurong Point Shopping Centre',
#         'lat': 1.3389091473521704,
#         'lng': 103.70573018129777,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3389091473521704,
#           'lng': 103.70573018129777}],
#         'distance': 314,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Jurong West Central 2 #03-54/55 (Jurong Point Shopping Centre)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '91151929'}},
#       'referralId': 'e-0-528e0ca6498e555880400ef8-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb9dbd653649c744b4e48fb',
#        'name': 'Men-ichi Japanese Ramen (麺いち)',
#        'location': {'address': '#B1-54 Jurong Point (JP1)',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.33937591191307,
#         'lng': 103.7068967088148,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.33937591191307,
#           'lng': 103.7068967088148}],
#         'distance': 333,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-54 Jurong Point (JP1) (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb9dbd653649c744b4e48fb-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f6d56a5e4b07fa2c598ccbe',
#        'name': 'Hong Kong Egglet',
#        'location': {'address': '#03-84 Jurong Point',
#         'lat': 1.340395496773492,
#         'lng': 103.70580871910724,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.340395496773492,
#           'lng': 103.70580871910724}],
#         'distance': 168,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#03-84 Jurong Point', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f6d56a5e4b07fa2c598ccbe-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4caeb1f5c5e6a1cda722c7f6',
#        'name': 'EnergyOne Jurong',
#        'location': {'address': 'SAFRA Jurong',
#         'crossStreet': '333 Boon Lay Way',
#         'lat': 1.3352252034449004,
#         'lng': 103.70681739347184,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3352252034449004,
#           'lng': 103.70681739347184}],
#         'distance': 742,
#         'postalCode': '649848',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['SAFRA Jurong (333 Boon Lay Way)',
#          '649848',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4caeb1f5c5e6a1cda722c7f6-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb97275935e9521152a2790',
#        'name': 'FairPrice Xtra',
#        'location': {'address': '#03-01/02, Jurong Point (JP2)',
#         'crossStreet': '63 Jurong West Central 3',
#         'lat': 1.3396949569719252,
#         'lng': 103.70574474334717,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3396949569719252,
#           'lng': 103.70574474334717}],
#         'distance': 233,
#         'postalCode': '648331',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#03-01/02, Jurong Point (JP2) (63 Jurong West Central 3)',
#          '648331',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb97275935e9521152a2790-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb166aff964a52018913ce3',
#        'name': 'NTUC Foodfare',
#        'location': {'address': '679 Jurong West Central 1',
#         'lat': 1.3447455848521117,
#         'lng': 103.70665128767172,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3447455848521117,
#           'lng': 103.70665128767172}],
#         'distance': 399,
#         'postalCode': '640679',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['679 Jurong West Central 1',
#          '640679',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb166aff964a52018913ce3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2b277eb34ad13a4643e9ce',
#        'name': 'Sheng Siong Supermarket',
#        'location': {'address': '7 Jurong West Ave 5 #01-01/08',
#         'lat': 1.3489900678374267,
#         'lng': 103.70349682124699,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3489900678374267,
#           'lng': 103.70349682124699}],
#         'distance': 836,
#         'postalCode': '649486',
#         'cc': 'SG',
#         'neighborhood': 'Jurong West',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['7 Jurong West Ave 5 #01-01/08',
#          '649486',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2b277eb34ad13a4643e9ce-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb004b3562d224bdf311388',
#        'name': 'Kidz Amaze',
#        'location': {'address': '333 Boon Lay Way',
#         'crossStreet': 'SAFRA Jurong',
#         'lat': 1.3351972711140698,
#         'lng': 103.70603404897763,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3351972711140698,
#           'lng': 103.70603404897763}],
#         'distance': 725,
#         'postalCode': '649848',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['333 Boon Lay Way (SAFRA Jurong)',
#          '649848',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb004b3562d224bdf311388-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9b40ad9c663704b9555ffd',
#        'name': 'Crystal Jade La Mian Xiao Long Bao 翡翠拉面小笼包',
#        'location': {'address': '#03-96 to 104, Jurong Point',
#         'crossStreet': '1 Jurong West Central 2',
#         'lat': 1.3402549819846261,
#         'lng': 103.70593031459542,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3402549819846261,
#           'lng': 103.70593031459542}],
#         'distance': 189,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#03-96 to 104, Jurong Point (1 Jurong West Central 2)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9b40ad9c663704b9555ffd-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0bb1b5340720a1b16f8893',
#        'name': 'EAT. 24 Hrs',
#        'location': {'address': 'Jurong Point Shopping Centre (JP2)',
#         'crossStreet': 'Jurong West Central',
#         'lat': 1.3388617748184624,
#         'lng': 103.70592606257698,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3388617748184624,
#           'lng': 103.70592606257698}],
#         'distance': 326,
#         'cc': 'SG',
#         'neighborhood': 'Jurong West',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Jurong Point Shopping Centre (JP2) (Jurong West Central)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0bb1b5340720a1b16f8893-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db26cff43a17e743789739f',
#        'name': "McDonald's / McCafé",
#        'location': {'address': '291 Boon Lay Way',
#         'crossStreet': 'Jurong Central Park',
#         'lat': 1.3392128300502797,
#         'lng': 103.70867580591214,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3392128300502797,
#           'lng': 103.70867580591214}],
#         'distance': 497,
#         'postalCode': '649849',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['291 Boon Lay Way (Jurong Central Park)',
#          '649849',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db26cff43a17e743789739f-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c27b50b3492a5938a45b628',
#        'name': 'Block 187 Boon Lay Ave',
#        'location': {'address': 'Boon Lay Avenue',
#         'lat': 1.3450055368642038,
#         'lng': 103.71025158583537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3450055368642038,
#           'lng': 103.71025158583537}],
#         'distance': 705,
#         'postalCode': '640187',
#         'cc': 'SG',
#         'city': 'Jurong West New Town',
#         'country': 'Singapore',
#         'formattedAddress': ['Boon Lay Avenue', '640187', 'Singapore']},
#        'categories': [{'id': '4d954b06a243a5684965b473',
#          'name': 'Residential Building (Apartment / Condo)',
#          'pluralName': 'Residential Buildings (Apartments / Condos)',
#          'shortName': 'Residential',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c27b50b3492a5938a45b628-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f96a868e4b03fde926e7770',
#        'name': 'Share Tea 歇脚亭',
#        'location': {'address': '#03-53 Jurong Point (JP2)',
#         'crossStreet': '63 Jurong West Central 3',
#         'lat': 1.3389582027366747,
#         'lng': 103.70580060977834,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3389582027366747,
#           'lng': 103.70580060977834}],
#         'distance': 311,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#03-53 Jurong Point (JP2) (63 Jurong West Central 3)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f96a868e4b03fde926e7770-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d8ee1c6fa94370473520ec6',
#        'name': 'Challenger',
#        'location': {'address': '#B1-94/95/96, Jurong Point (JP2)',
#         'crossStreet': '63 Jurong West Central 3',
#         'lat': 1.3395191481529172,
#         'lng': 103.70590581578159,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3395191481529172,
#           'lng': 103.70590581578159}],
#         'distance': 258,
#         'postalCode': '648886',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-94/95/96, Jurong Point (JP2) (63 Jurong West Central 3)',
#          '648886',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
# ...
#        'categories': [{'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'shortName': 'Concert Hall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52e69704498e36fed355e359-63'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cefa4825de16ea8ed7cc196',
#        'name': 'BazGym @ SAFRA Jurong',
#        'location': {'address': '#3C-01, SAFRA Jurong Club',
#         'crossStreet': '333 Boon Lay Way',
#         'lat': 1.3351977262294144,
#         'lng': 103.70600822546858,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3351977262294144,
#           'lng': 103.70600822546858}],
#         'distance': 724,
#         'postalCode': '649848',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#3C-01, SAFRA Jurong Club (333 Boon Lay Way)',
#          '649848',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cefa4825de16ea8ed7cc196-64'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca2a8401ee76dcb09dcf2dd',
#        'name': 'Raiders Cyber Cafe',
#        'location': {'address': 'Jurong Safra',
#         'lat': 1.3351719223589948,
#         'lng': 103.70602635520464,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3351719223589948,
#           'lng': 103.70602635520464}],
#         'distance': 727,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Jurong Safra', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d18d941735',
#          'name': 'Gaming Cafe',
#          'pluralName': 'Gaming Cafes',
#          'shortName': 'Gaming Cafe',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gamingcafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca2a8401ee76dcb09dcf2dd-65'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d52437b3062a1cd238c6fa3',
#        'name': 'Masego The Safari Spa',
#        'location': {'address': 'Level 3 SAFRA Jurong',
#         'crossStreet': '333 Boon Lay Way',
#         'lat': 1.3351825526616081,
#         'lng': 103.7060950342489,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3351825526616081,
#           'lng': 103.7060950342489}],
#         'distance': 727,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Level 3 SAFRA Jurong (333 Boon Lay Way)',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#          'name': 'Massage Studio',
#          'pluralName': 'Massage Studios',
#          'shortName': 'Massage Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d52437b3062a1cd238c6fa3-66'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2891329fb5d13a3cb19957',
#        'name': 'Hanis',
#        'location': {'address': 'SAFRA Jurong',
#         'crossStreet': '333 Boon Lay Way',
#         'lat': 1.335377887523763,
#         'lng': 103.70705295712217,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.335377887523763,
#           'lng': 103.70705295712217}],
#         'distance': 734,
#         'postalCode': '649848',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['SAFRA Jurong (333 Boon Lay Way)',
#          '649848',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2891329fb5d13a3cb19957-67'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51beaab1498e121aba9511d3',
#        'name': 'Gelàre',
#        'location': {'address': 'Inside Kidz Amaze @ Level 1',
#         'crossStreet': '333 Boon Lay Way',
#         'lat': 1.3351126536446762,
#         'lng': 103.7062724791911,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3351126536446762,
#           'lng': 103.7062724791911}],
#         'distance': 739,
#         'postalCode': '649848',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Inside Kidz Amaze @ Level 1 (333 Boon Lay Way)',
#          '649848',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51beaab1498e121aba9511d3-68'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8c652b8018a1cd43aaecd2',
#        'name': 'Joy Garden Restaurant',
#        'location': {'address': 'SAFRA Jurong',
#         'crossStreet': '333 Boon Lay Way',
#         'lat': 1.3351002767564324,
#         'lng': 103.70629027992108,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3351002767564324,
#           'lng': 103.70629027992108}],
#         'distance': 741,
#         'postalCode': '649848',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['SAFRA Jurong (333 Boon Lay Way)',
#          '649848',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8c652b8018a1cd43aaecd2-69'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '578702a7498e24ddd4313494',
#        'name': 'Old Town White Coffee',
#        'location': {'address': 'Safra Jurong',
#         'lat': 1.33503,
#         'lng': 103.706572,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.33503,
#           'lng': 103.706572}],
#         'distance': 755,
#         'cc': 'SG',
#         'neighborhood': 'Jurong West',
#         'country': 'Singapore',
#         'formattedAddress': ['Safra Jurong', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-578702a7498e24ddd4313494-70'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d46c827f83bcbff5c0334dc',
#        'name': 'Blk 185 Boon Lay Avenue',
#        'location': {'address': '185 Boon Lay Ave.',
#         'lat': 1.3468772263908064,
#         'lng': 103.7105266156231,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3468772263908064,
#           'lng': 103.7105266156231}],
#         'distance': 857,
#         'postalCode': '640185',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['185 Boon Lay Ave.', '640185', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1f7941735',
#          'name': 'Flea Market',
#          'pluralName': 'Flea Markets',
#          'shortName': 'Flea Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d46c827f83bcbff5c0334dc-71'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd8de717d454688b8ffeded',
#        'name': 'SBS Transit: Bus 257',
#        'location': {'lat': 1.3364202360241308,
#         'lng': 103.69863195485334,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3364202360241308,
#           'lng': 103.69863195485334}],
#         'distance': 906,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d12b951735',
#          'name': 'Bus Line',
#          'pluralName': 'Bus Lines',
#          'shortName': 'Bus',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd8de717d454688b8ffeded-72'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c7bfaa193ef236ae7f4b60f',
#        'name': 'Playground@jurong West St 61',
#        'location': {'lat': 1.336403169273802,
#         'lng': 103.69848266166521,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.336403169273802,
#           'lng': 103.69848266166521}],
#         'distance': 920,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c7bfaa193ef236ae7f4b60f-73'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf449be6c29236adc7775a2',
#        'name': 'Juz Bread @ Pioneer Mall',
#        'location': {'address': '638/638A Jurong West Street 61',
#         'crossStreet': '#01-08',
#         'lat': 1.341753742363355,
#         'lng': 103.69644337322138,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.341753742363355,
#           'lng': 103.69644337322138}],
#         'distance': 941,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['638/638A Jurong West Street 61 (#01-08)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf449be6c29236adc7775a2-74'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d0dcdeabe6d6ea8343a07b5',
#        'name': '24hr Coffeeshop @ Jalan Bahar',
#        'location': {'lat': 1.3500990610706978,
#         'lng': 103.70496153831482,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3500990610706978,
#           'lng': 103.70496153831482}],
#         'distance': 944,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d0dcdeabe6d6ea8343a07b5-75'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c38fb69edba9521673ad625',
#        'name': "Singapore Boys' Home",
#        'location': {'address': '30 Jurong West St 24',
#         'lat': 1.3497022043062985,
#         'lng': 103.70764374732971,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3497022043062985,
#           'lng': 103.70764374732971}],
#         'distance': 950,
#         'postalCode': '649696',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['30 Jurong West St 24', '649696', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'shortName': 'Hostel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c38fb69edba9521673ad625-76'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dde6db6227106a58b8b131b',
#        'name': '760 Basketball Court',
#        'location': {'address': 'Jurong west st 74',
#         'lat': 1.348961325617154,
#         'lng': 103.70000839355086,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.348961325617154,
#           'lng': 103.70000839355086}],
#         'distance': 982,
#         'postalCode': '640760',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Jurong west st 74', '640760', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e1941735',
#          'name': 'Basketball Court',
#          'pluralName': 'Basketball Courts',
#          'shortName': 'Basketball Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/basketballcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dde6db6227106a58b8b131b-77'}]}]}}

# %%
#function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list=row['categories']
    except:
        categories_list=row['venue.categories']
    
    if len(categories_list)==0:
        return None
    else:
        return categories_list[0]['name']

# %%
#Cleaning the json and structuring it into a Pandas DataFrame
venues = results['response']['groups'][0]['items']

#flatten json
nearby_venues = pd.json_normalize(venues)
                       
#filter columns
filtered_columns=['venue.name','venue.categories','venue.location.lat','venue.location.lng']
nearby_venues=nearby_venues.loc[:,filtered_columns]

#filter category for each row
nearby_venues['venue.categories']=nearby_venues.apply(get_category_type, axis=1)
                           
#clean columns
nearby_venues.columns=[col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head(200)
# Out:
#                                name            categories       lat  \
# 0                        Carl's Jr.  Fast Food Restaurant  1.340575
# 1                            Subway        Sandwich Place  1.340278
# 2                 Ya Kun Kaya Toast        Breakfast Spot  1.339619
# 3            PUTIEN Restaurant 莆田菜馆    Chinese Restaurant  1.340400
# 4   Din Tai Fung 鼎泰豐 (Din Tai Fung)    Chinese Restaurant  1.339029
# ..                              ...                   ...       ...
# 73     Playground@jurong West St 61            Playground  1.336403
# 74         Juz Bread @ Pioneer Mall                Bakery  1.341754
# 75    24hr Coffeeshop @ Jalan Bahar           Coffee Shop  1.350099
# 76             Singapore Boys' Home                Hostel  1.349702
# 77             760 Basketball Court      Basketball Court  1.348961
#
#            lng
# 0   103.706384
# 1   103.706548
# 2   103.705786
# 3   103.706468
# 4   103.705765
# ..         ...
# 73  103.698483
# 74  103.696443
# 75  103.704962
# 76  103.707644
# 77  103.700008
#
# [78 rows x 4 columns]

# %%
#create 3 additional columns to indicate respective planning area and its longitude and latitude
jw=nearby_venues.assign(planning_area='JURONG WEST',
                           area_latitude=latitude,
                           area_longitude=longitude)

# %%
jw=jw[['planning_area','area_latitude','area_longitude','name','lat','lng','categories']]

# %%
jw.rename(columns={'name':'venue_name',
            'lat':'venue_latitude',
             'lng':'venue_longitude',
             'categories':'venue_categories'}, inplace=True)

# %%
jw
# Out:
#    planning_area  area_latitude  area_longitude  \
# 0    JURONG WEST       1.341612      103.704903
# 1    JURONG WEST       1.341612      103.704903
# 2    JURONG WEST       1.341612      103.704903
# 3    JURONG WEST       1.341612      103.704903
# 4    JURONG WEST       1.341612      103.704903
# ..           ...            ...             ...
# 73   JURONG WEST       1.341612      103.704903
# 74   JURONG WEST       1.341612      103.704903
# 75   JURONG WEST       1.341612      103.704903
# 76   JURONG WEST       1.341612      103.704903
# 77   JURONG WEST       1.341612      103.704903
#
#                          venue_name  venue_latitude  venue_longitude  \
# 0                        Carl's Jr.        1.340575       103.706384
# 1                            Subway        1.340278       103.706548
# 2                 Ya Kun Kaya Toast        1.339619       103.705786
# 3            PUTIEN Restaurant 莆田菜馆        1.340400       103.706468
# 4   Din Tai Fung 鼎泰豐 (Din Tai Fung)        1.339029       103.705765
# ..                              ...             ...              ...
# 73     Playground@jurong West St 61        1.336403       103.698483
# 74         Juz Bread @ Pioneer Mall        1.341754       103.696443
# 75    24hr Coffeeshop @ Jalan Bahar        1.350099       103.704962
# 76             Singapore Boys' Home        1.349702       103.707644
# 77             760 Basketball Court        1.348961       103.700008
#
#         venue_categories
# 0   Fast Food Restaurant
# 1         Sandwich Place
# 2         Breakfast Spot
# 3     Chinese Restaurant
# 4     Chinese Restaurant
# ..                   ...
# 73            Playground
# 74                Bakery
# 75           Coffee Shop
# 76                Hostel
# 77      Basketball Court
#
# [78 rows x 7 columns]

# %%
jw.to_csv("jw.csv")

# %% [markdown]
# ## CHOA CHU KANG

# %%
# @hidden_cell
#Defining Foursquare credentials and version
CLIENT_ID='5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K'
CLIENT_SECRET='UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR'
VERSION='20180605'

# %%
#Create GET request url

latitude=cck.loc[0,'area_latitude']
longitude=cck.loc[0,'area_longitude']

LIMIT=200
radius=1000

url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
CLIENT_ID,
CLIENT_SECRET,
VERSION,
latitude,
longitude,
radius,
LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K&client_secret=UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR&v=20180605&ll=1.385555907688099,103.74719055092544&radius=1000&limit=200'

# %%
#send GET request url and examine results

results=requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '613da8c8d6eeb73204c97ecc'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Choa Chu Kang',
#   'headerFullLocation': 'Choa Chu Kang, Singapore',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 42,
#   'suggestedBounds': {'ne': {'lat': 1.394555916688108,
#     'lng': 103.75617638318077},
#    'sw': {'lat': 1.37655589868809, 'lng': 103.7382047186701}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f6332c6e4b08b476e2604b1',
#        'name': 'パン達人 BAKER TALENT',
#        'location': {'address': '303 Choa Chu Kang Ave 4 #01-723',
#         'lat': 1.384180192719575,
#         'lng': 103.74423274608141,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.384180192719575,
#           'lng': 103.74423274608141}],
#         'distance': 363,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['303 Choa Chu Kang Ave 4 #01-723', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f6332c6e4b08b476e2604b1-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9f5913f964a520c81d37e3',
#        'name': 'Subway',
#        'location': {'address': "#B1-34/35, Lot 1 Shoppers' Mall",
#         'crossStreet': '21 Choa Chu Kang Ave 4',
#         'lat': 1.3856426501611323,
#         'lng': 103.74472477290492,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3856426501611323,
#           'lng': 103.74472477290492}],
#         'distance': 274,
#         'postalCode': '689812',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ["#B1-34/35, Lot 1 Shoppers' Mall (21 Choa Chu Kang Ave 4)",
#          '689812',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9f5913f964a520c81d37e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5880b1eb0037eb57b0799c9b',
#        'name': 'Starbucks',
#        'location': {'address': '#01-04, Keat Hong Community Club',
#         'crossStreet': '2 Choa Chu Kang Loop',
#         'lat': 1.3843242464021184,
#         'lng': 103.74466556072359,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3843242464021184,
#           'lng': 103.74466556072359}],
#         'distance': 312,
#         'postalCode': '689787',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-04, Keat Hong Community Club (2 Choa Chu Kang Loop)',
#          '689787',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5880b1eb0037eb57b0799c9b-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdab2a84006a143196ad3b2',
#        'name': 'Dian Xiao Er 店小二',
#        'location': {'address': "#B1-32/33 Lot 1 Shoppers' Mall",
#         'crossStreet': '21 Choa Chu Kang Ave 4',
#         'lat': 1.3856036276890777,
#         'lng': 103.74474771552191,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3856036276890777,
#           'lng': 103.74474771552191}],
#         'distance': 271,
#         'postalCode': '689812',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ["#B1-32/33 Lot 1 Shoppers' Mall (21 Choa Chu Kang Ave 4)",
#          '689812',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cdab2a84006a143196ad3b2-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bada046f964a520c75f3be3',
#        'name': 'Siam Kitchen',
#        'location': {'address': "#02-25, Lot 1 Shoppers' Mall",
#         'crossStreet': '21 Choa Chu Kang Ave 4',
#         'lat': 1.3852400991889278,
#         'lng': 103.74488887837721,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3852400991889278,
#           'lng': 103.74488887837721}],
#         'distance': 258,
#         'postalCode': '689812',
#         'cc': 'SG',
#         'neighborhood': 'Choa Chu Kang',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ["#02-25, Lot 1 Shoppers' Mall (21 Choa Chu Kang Ave 4)",
#          '689812',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bada046f964a520c75f3be3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc9575cb6c49c7482658e91',
#        'name': 'Choa Chu Kang Swimming Complex',
#        'location': {'address': 'Choa Chu Kang Sports & Recreation Centre/Stadium',
#         'crossStreet': '1 Choa Chu Kang St 53',
#         'lat': 1.3914828781410968,
#         'lng': 103.74792063722406,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3914828781410968,
#           'lng': 103.74792063722406}],
#         'distance': 664,
#         'postalCode': '689236',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'state': 'None',
#         'country': 'Singapore',
#         'formattedAddress': ['Choa Chu Kang Sports & Recreation Centre/Stadium (1 Choa Chu Kang St 53)',
#          '689236',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d15e941735',
#          'name': 'Pool',
#          'pluralName': 'Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc9575cb6c49c7482658e91-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9b74139c6637046a5461fd',
#        'name': 'Limbang Park',
#        'location': {'address': 'Choa Chu Kang St. 51',
#         'lat': 1.3899047890967722,
#         'lng': 103.74449863605007,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3899047890967722,
#           'lng': 103.74449863605007}],
#         'distance': 569,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Choa Chu Kang St. 51', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9b74139c6637046a5461fd-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7be9c6f964a52071732fe3',
#        'name': 'Ya Kun Kaya Toast 亞坤',
#        'location': {'address': '#B1-K4/K5, Lot One',
#         'crossStreet': '21 Choa Chu Kang Avenue 4',
#         'lat': 1.3855372706251978,
#         'lng': 103.74474658498957,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3855372706251978,
#           'lng': 103.74474658498957}],
#         'distance': 271,
#         'postalCode': '689812',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-K4/K5, Lot One (21 Choa Chu Kang Avenue 4)',
#          '689812',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7be9c6f964a52071732fe3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ccbd03572106dcb41209799',
#        'name': 'Choa Chu Kang Sports & Recreation Centre',
#        'location': {'address': '1 Choa Chu Kang St 53',
#         'lat': 1.391600825774209,
#         'lng': 103.7478307912528,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.391600825774209,
#           'lng': 103.7478307912528}],
#         'distance': 676,
#         'postalCode': '689236',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Choa Chu Kang St 53', '689236', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ccbd03572106dcb41209799-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf3203494feb1f7c74021ba',
#        'name': 'Roof Top Garden',
#        'location': {'address': "Lot 1 Shoppers' Mall",
#         'lat': 1.3852679925257927,
#         'lng': 103.74483106661988,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3852679925257927,
#           'lng': 103.74483106661988}],
#         'distance': 264,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ["Lot 1 Shoppers' Mall", 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf3203494feb1f7c74021ba-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '537afd3a498ee189b9fe7f57',
#        'name': "Nando's",
#        'location': {'address': "Lot 1 Shoppers' Mall",
#         'crossStreet': '21 Choa Chu Kang Ave. 4',
#         'lat': 1.3844874164098018,
#         'lng': 103.74496991467447,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3844874164098018,
#           'lng': 103.74496991467447}],
#         'distance': 274,
#         'postalCode': '689812',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ["Lot 1 Shoppers' Mall (21 Choa Chu Kang Ave. 4)",
#          '689812',
#          'Singapore']},
#        'categories': [{'id': '4def73e84765ae376e57713a',
#          'name': 'Portuguese Restaurant',
#          'pluralName': 'Portuguese Restaurants',
#          'shortName': 'Portuguese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/portuguese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-537afd3a498ee189b9fe7f57-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd352979854d13ad980fd4d',
#        'name': 'Choa Chu Kang Stadium',
#        'location': {'address': '1 Choa Chu Kang St 53',
#         'lat': 1.3906130188539194,
#         'lng': 103.75012401014779,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3906130188539194,
#           'lng': 103.75012401014779}],
#         'distance': 650,
#         'postalCode': '689236',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Choa Chu Kang St 53', '689236', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d184941735',
#          'name': 'Stadium',
#          'pluralName': 'Stadiums',
#          'shortName': 'Stadium',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd352979854d13ad980fd4d-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9b2dc278ffa0939e7e7275',
#        'name': 'KFC',
#        'location': {'address': '#01-02, Keat Hong Shopping Centre',
#         'crossStreet': '253 Choa Chu Kang Ave 1',
#         'lat': 1.3772273644479736,
#         'lng': 103.744419101957,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3772273644479736,
#           'lng': 103.744419101957}],
#         'distance': 977,
#         'postalCode': '680253',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-02, Keat Hong Shopping Centre (253 Choa Chu Kang Ave 1)',
#          '680253',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9b2dc278ffa0939e7e7275-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0953ccf964a520bc1523e3',
#        'name': "McDonald's",
#        'location': {'address': '10 Choa Chu Kang Ave 4, #01-K3',
#         'crossStreet': 'Choa Chu Kang MRT',
#         'lat': 1.385665256637247,
#         'lng': 103.74472524010288,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.385665256637247,
#           'lng': 103.74472524010288}],
#         'distance': 274,
#         'postalCode': '689810',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['10 Choa Chu Kang Ave 4, #01-K3 (Choa Chu Kang MRT)',
#          '689810',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0953ccf964a520bc1523e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '596af537c876c85832c15b3a',
#        'name': "McDonald's",
#        'location': {'address': '818 Choa Chu Kang Avenue 1 #01-02',
#         'lat': 1.3783178311654798,
#         'lng': 103.74883197441625,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3783178311654798,
#           'lng': 103.74883197441625}],
#         'distance': 826,
#         'postalCode': '688266',
#         'cc': 'SG',
#         'neighborhood': 'Keat Hong',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['818 Choa Chu Kang Avenue 1 #01-02',
#          '688266',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-596af537c876c85832c15b3a-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0953a3f964a520b91523e3',
#        'name': "McDonald's / McCafé",
#        'location': {'address': "#01-20, Lot 1 Shopper's Mall",
#         'crossStreet': '21 Choa Chu Kang Ave 4',
#         'lat': 1.385554285132296,
#         'lng': 103.74480182605238,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.385554285132296,
#           'lng': 103.74480182605238}],
#         'distance': 265,
#         'postalCode': '689812',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ["#01-20, Lot 1 Shopper's Mall (21 Choa Chu Kang Ave 4)",
#          '689812',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0953a3f964a520b91523e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6ece37f964a5205dcb2ce3',
#        'name': 'CCK 302 Coffeehouse',
#        'location': {'address': '302 Choa Chu Kang Ave 4',
#         'lat': 1.3847990238534764,
#         'lng': 103.74329454063925,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3847990238534764,
#           'lng': 103.74329454063925}],
#         'distance': 441,
#         'postalCode': '680302',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['302 Choa Chu Kang Ave 4',
#          '680302',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6ece37f964a5205dcb2ce3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8a12fff964a520be5e32e3',
#        'name': '旺 Wang Cafe',
#        'location': {'address': '#01-24/25, Choa Chu Kang MRT',
#         'crossStreet': '10 Choa Chu Kang Ave 4',
#         'lat': 1.3856836529643952,
#         'lng': 103.74446296403629,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3856836529643952,
#           'lng': 103.74446296403629}],
#         'distance': 303,
#         'postalCode': '689810',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-24/25, Choa Chu Kang MRT (10 Choa Chu Kang Ave 4)',
#          '689810',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8a12fff964a520be5e32e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c259764f7ced13a44f8246d',
#        'name': '145 Coffee Shop',
#        'location': {'address': '145 Teck Whye Lane',
#         'lat': 1.38159066345659,
#         'lng': 103.75235661427298,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.38159066345659,
#           'lng': 103.75235661427298}],
#         'distance': 724,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['145 Teck Whye Lane', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c259764f7ced13a44f8246d-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b822f1df964a52095cc30e3',
#        'name': 'NTUC FairPrice',
#        'location': {'address': "#B1-05 Lot 1 Shoppers' Mall",
#         'crossStreet': '21 Choa Chu Kang Ave 4',
#         'lat': 1.3845883336801141,
#         'lng': 103.74501471786418,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3845883336801141,
#           'lng': 103.74501471786418}],
#         'distance': 265,
#         'postalCode': '689812',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ["#B1-05 Lot 1 Shoppers' Mall (21 Choa Chu Kang Ave 4)",
#          '689812',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b822f1df964a52095cc30e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d5f50d95b276dcbd59106c6',
#        'name': 'PastaMania',
#        'location': {'address': "#03-02A, Lot One Shoppers' Mall",
#         'crossStreet': '21 Choa Chu Kang Ave 4',
#         'lat': 1.3846459103139463,
#         'lng': 103.7450027560069,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3846459103139463,
#           'lng': 103.7450027560069}],
#         'distance': 263,
#         'postalCode': '689812',
#         'cc': 'SG',
#         'neighborhood': 'Choa Chu Kang',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ["#03-02A, Lot One Shoppers' Mall (21 Choa Chu Kang Ave 4)",
#          '689812',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d5f50d95b276dcbd59106c6-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bee61703686c9b6e576246e',
#        'name': 'Courts',
#        'location': {'address': "Lot 1 Shoppers' Mall",
#         'crossStreet': '21 Choa Chu Kang Ave. 4',
#         'lat': 1.384732480644711,
#         'lng': 103.74519935522719,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.384732480644711,
#           'lng': 103.74519935522719}],
#         'distance': 239,
#         'postalCode': '689812',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ["Lot 1 Shoppers' Mall (21 Choa Chu Kang Ave. 4)",
#          '689812',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bee61703686c9b6e576246e-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d5926fc7e2237042676ad73',
#        'name': 'The Old Pontian Cafe',
#        'location': {'address': "Lot 1 Shopper's Mall",
#         'lat': 1.3851029471541025,
#         'lng': 103.74480891421992,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3851029471541025,
#           'lng': 103.74480891421992}],
#         'distance': 269,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ["Lot 1 Shopper's Mall", 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d5926fc7e2237042676ad73-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8be6bed22db1c42b0df304',
#        'name': 'Arnor Crepes',
#        'location': {'address': "#B1-K32, Lot 1 Shopper's Mall, 21 Choa Chu Kang Ave. 4",
#         'lat': 1.3847328922602469,
#         'lng': 103.74497544061249,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3847328922602469,
#           'lng': 103.74497544061249}],
#         'distance': 262,
#         'postalCode': '689812',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ["#B1-K32, Lot 1 Shopper's Mall, 21 Choa Chu Kang Ave. 4",
#          '689812',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e8be6bed22db1c42b0df304-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d71b103bce5721e80e0c215',
#        'name': 'Spuddies',
#        'location': {'address': "#B1-K9 Lot One Shoppers' Mall",
#         'crossStreet': '21 Choa Chu Kang Ave. 4',
#         'lat': 1.385592,
#         'lng': 103.744747,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.385592,
#           'lng': 103.744747}],
#         'distance': 271,
#         'postalCode': '689812',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ["#B1-K9 Lot One Shoppers' Mall (21 Choa Chu Kang Ave. 4)",
#          '689812',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d71b103bce5721e80e0c215-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e8cf7bdd3e3720da3c06ebe',
#        'name': 'NTUC Foodfare',
#        'location': {'address': 'Blk 303 Choa Chu Kang Ave 4',
#         'lat': 1.3844729462166863,
#         'lng': 103.74396098351383,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3844729462166863,
#           'lng': 103.74396098351383}],
#         'distance': 379,
#         'postalCode': '680303',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 303 Choa Chu Kang Ave 4',
#          '680303',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e8cf7bdd3e3720da3c06ebe-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcfe9d4caff95218a12cef0',
#        'name': 'Sin Tong Hong Eating House',
#        'location': {'address': 'Blk 429 Choa Chu Kang Ave 4',
#         'lat': 1.3832034080056264,
#         'lng': 103.74019423070108,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3832034080056264,
#           'lng': 103.74019423070108}],
#         'distance': 821,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 429 Choa Chu Kang Ave 4', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bcfe9d4caff95218a12cef0-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c74e1a5d8948cfab71d66da',
#        'name': "Mr Bean @ Lot One Shopper's Mall",
#        'location': {'address': '21 Choa Chu Kang Ave 4',
#         'lat': 1.3844754627043077,
#         'lng': 103.7444322578213,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3844754627043077,
#           'lng': 103.7444322578213}],
#         'distance': 329,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['21 Choa Chu Kang Ave 4', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c74e1a5d8948cfab71d66da-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d81f6cd6476a093f1931853',
#        'name': 'Playground @ Blk 344 CCK Loop',
#        'location': {'address': 'Block 344, Choa Chu Kang Loop.',
#         'lat': 1.3829114850478723,
#         'lng': 103.74569231879526,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3829114850478723,
#           'lng': 103.74569231879526}],
#         'distance': 338,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Block 344, Choa Chu Kang Loop.', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d81f6cd6476a093f1931853-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5d7229f964a5203d5d29e3',
#        'name': 'Choa Chu Kang ClubFITT Gym',
#        'location': {'address': '1 Choa Chu Kang St 53',
#         'lat': 1.3913110288649753,
#         'lng': 103.7480387472727,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3913110288649753,
#           'lng': 103.7480387472727}],
#         'distance': 647,
#         'postalCode': '689236',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Choa Chu Kang St 53', '689236', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5d7229f964a5203d5d29e3-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6efb3af964a52099d42ce3',
#        'name': "McDonald's",
#        'location': {'address': '#01-01, Chua Chu Kang CC',
#         'crossStreet': '35 Teck Whye Ave',
#         'lat': 1.3814309958314157,
#         'lng': 103.75222440832219,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3814309958314157,
#           'lng': 103.75222440832219}],
#         'distance': 724,
#         'postalCode': '688892',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01, Chua Chu Kang CC (35 Teck Whye Ave)',
#          '688892',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b6efb3af964a52099d42ce3-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9f6b1b19e4236a7d935889',
#        'name': 'Keat Hong Shopping Centre',
#        'location': {'address': '253 Choa Chu Kang Ave 1',
#         'crossStreet': 'Choa Chu Kang Ave 2',
#         'lat': 1.3772929520719812,
#         'lng': 103.74442909343317,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3772929520719812,
#           'lng': 103.74442909343317}],
#         'distance': 969,
#         'postalCode': '680253',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['253 Choa Chu Kang Ave 1 (Choa Chu Kang Ave 2)',
#          '680253',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ff941735',
#          'name': 'Miscellaneous Shop',
#          'pluralName': 'Miscellaneous Shops',
#          'shortName': 'Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9f6b1b19e4236a7d935889-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ed029bd7ee5be844aeb9173',
#        'name': 'Reliance Provision Management',
#        'location': {'address': '233 Choa Chu Kang Central, #B1-97',
#         'lat': 1.3807748961326198,
#         'lng': 103.74803445707622,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3807748961326198,
#           'lng': 103.74803445707622}],
#         'distance': 540,
#         'postalCode': '680233',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['233 Choa Chu Kang Central, #B1-97',
#          '680233',
#          'Singapore']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ed029bd7ee5be844aeb9173-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c9c9ce146978cfa05518f7f',
#        'name': 'Bus Stop 44471 (Blk 234)',
#        'location': {'address': 'Choa Chu Kang Central',
#         'lat': 1.3805452868085304,
#         'lng': 103.74805227522715,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3805452868085304,
#           'lng': 103.74805227522715}],
#         'distance': 565,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Choa Chu Kang Central', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c9c9ce146978cfa05518f7f-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dffbfa162e1fc1f12bee4a7',
#        'name': '\ue043\ue341\ue34c\ue344\ue342\ue120\ue147\ue33b\ue33a',
#        'location': {'address': 'Yum yum!',
#         'lat': 1.3803201599200032,
#         'lng': 103.74349363897487,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3803201599200032,
#           'lng': 103.74349363897487}],
#         'distance': 713,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Yum yum!', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d105951735',
#          'name': 'Kids Store',
#          'pluralName': 'Kids Stores',
#          'shortName': 'Kids Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_kids_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dffbfa162e1fc1f12bee4a7-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5417c936498e13531abfb343',
#        'name': '爱麺子',
#        'location': {'lat': 1.3815975189208984,
#         'lng': 103.75244140625,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3815975189208984,
#           'lng': 103.75244140625}],
#         'distance': 731,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5417c936498e13531abfb343-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3e896a6b3d236a906e7364',
#        'name': 'PJC Good News Cafe',
#        'location': {'lat': 1.3846927751860438,
#         'lng': 103.75437097011286,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3846927751860438,
#           'lng': 103.75437097011286}],
#         'distance': 804,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1a1941735',
#          'name': 'College Cafeteria',
#          'pluralName': 'College Cafeterias',
#          'shortName': 'Cafeteria',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d3e896a6b3d236a906e7364-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c51512c250dd13a19c8047d',
#        'name': 'NTUC FairPrice',
#        'location': {'address': '140 Teck Whye Lane #01-351',
#         'lat': 1.3801768489622654,
#         'lng': 103.75318224889648,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3801768489622654,
#           'lng': 103.75318224889648}],
#         'distance': 896,
#         'postalCode': '680140',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['140 Teck Whye Lane #01-351',
#          '680140',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c51512c250dd13a19c8047d-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d285d786e27a14363251924',
#        'name': 'Playground @ 439',
#        'location': {'address': 'Blk 439 choa chu kang ave 4.',
#         'lat': 1.383691,
#         'lng': 103.74004,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.383691,
#           'lng': 103.74004}],
#         'distance': 822,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 439 choa chu kang ave 4.', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d285d786e27a14363251924-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c68fcfb0e98a593a34f2359',
#        'name': 'Sweet Talk Teck Whye',
#        'location': {'address': 'Teck Whye Lane Market',
#         'lat': 1.380042752654829,
#         'lng': 103.75310923042221,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.380042752654829,
#           'lng': 103.75310923042221}],
#         'distance': 900,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Teck Whye Lane Market', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c68fcfb0e98a593a34f2359-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd531aa4e32d13a6591c080',
#        'name': '85 Cafe',
#        'location': {'address': '#01-05 Keat Hong Shopping Centre',
#         'crossStreet': '253 Choa Chu Kang Avenue 1',
#         'lat': 1.3773226032809833,
#         'lng': 103.74440685725686,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3773226032809833,
#           'lng': 103.74440685725686}],
#         'distance': 967,
#         'postalCode': '680253',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-05 Keat Hong Shopping Centre (253 Choa Chu Kang Avenue 1)',
#          '680253',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd531aa4e32d13a6591c080-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e18368918a8166f738928a0',
#        'name': 'The Rail Corridor (North) | Choa Chu Kang',
#        'location': {'address': 'Former KTM Railway, Choa Chu Kang',
#         'lat': 1.390685,
#         'lng': 103.753592,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.390685,
#           'lng': 103.753592}],
#         'distance': 912,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Former KTM Railway, Choa Chu Kang',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e18368918a8166f738928a0-41'}]}]}}

# %%
#function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list=row['categories']
    except:
        categories_list=row['venue.categories']
    
    if len(categories_list)==0:
        return None
    else:
        return categories_list[0]['name']

# %%
#Cleaning the json and structuring it into a Pandas DataFrame
venues = results['response']['groups'][0]['items']

#flatten json
nearby_venues = pd.json_normalize(venues)
                       
#filter columns
filtered_columns=['venue.name','venue.categories','venue.location.lat','venue.location.lng']
nearby_venues=nearby_venues.loc[:,filtered_columns]

#filter category for each row
nearby_venues['venue.categories']=nearby_venues.apply(get_category_type, axis=1)
                           
#clean columns
nearby_venues.columns=[col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head(200)
# Out:
#                                          name              categories  \
# 0                           パン達人 BAKER TALENT                  Bakery
# 1                                      Subway          Sandwich Place
# 2                                   Starbucks             Coffee Shop
# 3                            Dian Xiao Er 店小二        Asian Restaurant
# 4                                Siam Kitchen         Thai Restaurant
# 5              Choa Chu Kang Swimming Complex                    Pool
# 6                                Limbang Park                    Park
# 7                        Ya Kun Kaya Toast 亞坤             Coffee Shop
# 8    Choa Chu Kang Sports & Recreation Centre    Gym / Fitness Center
# 9                             Roof Top Garden              Playground
# 10                                    Nando's   Portuguese Restaurant
# 11                      Choa Chu Kang Stadium                 Stadium
# 12                                        KFC    Fast Food Restaurant
# 13                                 McDonald's    Fast Food Restaurant
# 14                                 McDonald's    Fast Food Restaurant
# 15                        McDonald's / McCafé    Fast Food Restaurant
# 16                        CCK 302 Coffeehouse              Food Court
# 17                                旺 Wang Cafe                    Café
# 18                            145 Coffee Shop             Coffee Shop
# 19                             NTUC FairPrice             Supermarket
# 20                                 PastaMania      Italian Restaurant
# 21                                     Courts  Furniture / Home Store
# 22                       The Old Pontian Cafe            Noodle House
# 23                               Arnor Crepes             Snack Place
# 24                                   Spuddies             Snack Place
# 25                              NTUC Foodfare              Food Court
# 26                 Sin Tong Hong Eating House             Coffee Shop
# 27           Mr Bean @ Lot One Shopper's Mall             Snack Place
# 28              Playground @ Blk 344 CCK Loop              Playground
# 29                 Choa Chu Kang ClubFITT Gym                     Gym
# 30                                 McDonald's    Fast Food Restaurant
# 31                  Keat Hong Shopping Centre      Miscellaneous Shop
# 32              Reliance Provision Management       Convenience Store
# 33                   Bus Stop 44471 (Blk 234)             Bus Station
# 34                                                Kids Store
# 35                                        爱麺子             Coffee Shop
# 36                         PJC Good News Cafe       College Cafeteria
# 37                             NTUC FairPrice           Grocery Store
# 38                           Playground @ 439              Playground
# 39                       Sweet Talk Teck Whye            Dessert Shop
# 40                                    85 Cafe              Food Court
# 41  The Rail Corridor (North) | Choa Chu Kang                   Trail
#
#          lat         lng
# 0   1.384180  103.744233
# 1   1.385643  103.744725
# 2   1.384324  103.744666
# 3   1.385604  103.744748
# 4   1.385240  103.744889
# 5   1.391483  103.747921
# 6   1.389905  103.744499
# 7   1.385537  103.744747
# 8   1.391601  103.747831
# 9   1.385268  103.744831
# 10  1.384487  103.744970
# 11  1.390613  103.750124
# 12  1.377227  103.744419
# 13  1.385665  103.744725
# 14  1.378318  103.748832
# 15  1.385554  103.744802
# 16  1.384799  103.743295
# 17  1.385684  103.744463
# 18  1.381591  103.752357
# 19  1.384588  103.745015
# 20  1.384646  103.745003
# 21  1.384732  103.745199
# 22  1.385103  103.744809
# 23  1.384733  103.744975
# 24  1.385592  103.744747
# 25  1.384473  103.743961
# 26  1.383203  103.740194
# 27  1.384475  103.744432
# 28  1.382911  103.745692
# 29  1.391311  103.748039
# 30  1.381431  103.752224
# 31  1.377293  103.744429
# 32  1.380775  103.748034
# 33  1.380545  103.748052
# 34  1.380320  103.743494
# 35  1.381598  103.752441
# 36  1.384693  103.754371
# 37  1.380177  103.753182
# 38  1.383691  103.740040
# 39  1.380043  103.753109
# 40  1.377323  103.744407
# 41  1.390685  103.753592

# %%
#create 3 additional columns to indicate respective planning area and its longitude and latitude
cck=nearby_venues.assign(planning_area='CHOA CHU KANG',
                           area_latitude=latitude,
                           area_longitude=longitude)

# %%
#Repositioning the columns and renaming the column names
cck=cck[['planning_area','area_latitude','area_longitude','name','lat','lng','categories']]
cck.rename(columns={'name':'venue_name',
            'lat':'venue_latitude',
             'lng':'venue_longitude',
             'categories':'venue_categories'}, inplace=True)

# %%
#check data
cck
# Out:
#     planning_area  area_latitude  area_longitude  \
# 0   CHOA CHU KANG       1.385556      103.747191
# 1   CHOA CHU KANG       1.385556      103.747191
# 2   CHOA CHU KANG       1.385556      103.747191
# 3   CHOA CHU KANG       1.385556      103.747191
# 4   CHOA CHU KANG       1.385556      103.747191
# 5   CHOA CHU KANG       1.385556      103.747191
# 6   CHOA CHU KANG       1.385556      103.747191
# 7   CHOA CHU KANG       1.385556      103.747191
# 8   CHOA CHU KANG       1.385556      103.747191
# 9   CHOA CHU KANG       1.385556      103.747191
# 10  CHOA CHU KANG       1.385556      103.747191
# 11  CHOA CHU KANG       1.385556      103.747191
# 12  CHOA CHU KANG       1.385556      103.747191
# 13  CHOA CHU KANG       1.385556      103.747191
# 14  CHOA CHU KANG       1.385556      103.747191
# 15  CHOA CHU KANG       1.385556      103.747191
# 16  CHOA CHU KANG       1.385556      103.747191
# 17  CHOA CHU KANG       1.385556      103.747191
# 18  CHOA CHU KANG       1.385556      103.747191
# 19  CHOA CHU KANG       1.385556      103.747191
# 20  CHOA CHU KANG       1.385556      103.747191
# 21  CHOA CHU KANG       1.385556      103.747191
# 22  CHOA CHU KANG       1.385556      103.747191
# 23  CHOA CHU KANG       1.385556      103.747191
# 24  CHOA CHU KANG       1.385556      103.747191
# 25  CHOA CHU KANG       1.385556      103.747191
# 26  CHOA CHU KANG       1.385556      103.747191
# 27  CHOA CHU KANG       1.385556      103.747191
# 28  CHOA CHU KANG       1.385556      103.747191
# 29  CHOA CHU KANG       1.385556      103.747191
# 30  CHOA CHU KANG       1.385556      103.747191
# 31  CHOA CHU KANG       1.385556      103.747191
# 32  CHOA CHU KANG       1.385556      103.747191
# 33  CHOA CHU KANG       1.385556      103.747191
# 34  CHOA CHU KANG       1.385556      103.747191
# 35  CHOA CHU KANG       1.385556      103.747191
# 36  CHOA CHU KANG       1.385556      103.747191
# 37  CHOA CHU KANG       1.385556      103.747191
# 38  CHOA CHU KANG       1.385556      103.747191
# 39  CHOA CHU KANG       1.385556      103.747191
# 40  CHOA CHU KANG       1.385556      103.747191
# 41  CHOA CHU KANG       1.385556      103.747191
#
#                                    venue_name  venue_latitude  \
# 0                           パン達人 BAKER TALENT        1.384180
# 1                                      Subway        1.385643
# 2                                   Starbucks        1.384324
# 3                            Dian Xiao Er 店小二        1.385604
# 4                                Siam Kitchen        1.385240
# 5              Choa Chu Kang Swimming Complex        1.391483
# 6                                Limbang Park        1.389905
# 7                        Ya Kun Kaya Toast 亞坤        1.385537
# 8    Choa Chu Kang Sports & Recreation Centre        1.391601
# 9                             Roof Top Garden        1.385268
# 10                                    Nando's        1.384487
# 11                      Choa Chu Kang Stadium        1.390613
# 12                                        KFC        1.377227
# 13                                 McDonald's        1.385665
# 14                                 McDonald's        1.378318
# 15                        McDonald's / McCafé        1.385554
# 16                        CCK 302 Coffeehouse        1.384799
# 17                                旺 Wang Cafe        1.385684
# 18                            145 Coffee Shop        1.381591
# 19                             NTUC FairPrice        1.384588
# 20                                 PastaMania        1.384646
# 21                                     Courts        1.384732
# 22                       The Old Pontian Cafe        1.385103
# 23                               Arnor Crepes        1.384733
# 24                                   Spuddies        1.385592
# 25                              NTUC Foodfare        1.384473
# 26                 Sin Tong Hong Eating House        1.383203
# 27           Mr Bean @ Lot One Shopper's Mall        1.384475
# 28              Playground @ Blk 344 CCK Loop        1.382911
# 29                 Choa Chu Kang ClubFITT Gym        1.391311
# 30                                 McDonald's        1.381431
# 31                  Keat Hong Shopping Centre        1.377293
# 32              Reliance Provision Management        1.380775
# 33                   Bus Stop 44471 (Blk 234)        1.380545
# 34                                          1.380320
# 35                                        爱麺子        1.381598
# 36                         PJC Good News Cafe        1.384693
# 37                             NTUC FairPrice        1.380177
# 38                           Playground @ 439        1.383691
# 39                       Sweet Talk Teck Whye        1.380043
# 40                                    85 Cafe        1.377323
# 41  The Rail Corridor (North) | Choa Chu Kang        1.390685
#
#     venue_longitude        venue_categories
# 0        103.744233                  Bakery
# 1        103.744725          Sandwich Place
# 2        103.744666             Coffee Shop
# 3        103.744748        Asian Restaurant
# 4        103.744889         Thai Restaurant
# 5        103.747921                    Pool
# 6        103.744499                    Park
# 7        103.744747             Coffee Shop
# 8        103.747831    Gym / Fitness Center
# 9        103.744831              Playground
# 10       103.744970   Portuguese Restaurant
# 11       103.750124                 Stadium
# 12       103.744419    Fast Food Restaurant
# 13       103.744725    Fast Food Restaurant
# 14       103.748832    Fast Food Restaurant
# 15       103.744802    Fast Food Restaurant
# 16       103.743295              Food Court
# 17       103.744463                    Café
# 18       103.752357             Coffee Shop
# 19       103.745015             Supermarket
# 20       103.745003      Italian Restaurant
# 21       103.745199  Furniture / Home Store
# 22       103.744809            Noodle House
# 23       103.744975             Snack Place
# 24       103.744747             Snack Place
# 25       103.743961              Food Court
# 26       103.740194             Coffee Shop
# 27       103.744432             Snack Place
# 28       103.745692              Playground
# 29       103.748039                     Gym
# 30       103.752224    Fast Food Restaurant
# 31       103.744429      Miscellaneous Shop
# 32       103.748034       Convenience Store
# 33       103.748052             Bus Station
# 34       103.743494              Kids Store
# 35       103.752441             Coffee Shop
# 36       103.754371       College Cafeteria
# 37       103.753182           Grocery Store
# 38       103.740040              Playground
# 39       103.753109            Dessert Shop
# 40       103.744407              Food Court
# 41       103.753592                   Trail

# %%
cck.to_csv("cck.csv")

# %% [markdown]
# ## PUNGGOL

# %%
# @hidden_cell
#Defining Foursquare credentials and version
CLIENT_ID='5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K'
CLIENT_SECRET='UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR'
VERSION='20180605'

# %%
# Create GET request url

latitude=punggol.loc[0,'area_latitude']
longitude=punggol.loc[0,'area_longitude']

LIMIT=200
radius=1000

url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
CLIENT_ID,
CLIENT_SECRET,
VERSION,
latitude,
longitude,
radius,
LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K&client_secret=UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR&v=20180605&ll=1.405362997897329,103.91004339487458&radius=1000&limit=200'

# %%
#send GET request url and examine results

results=requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '613da8e8cb2e670bcf59ed2f'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Punggol',
#   'headerFullLocation': 'Punggol, Singapore',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 68,
#   'suggestedBounds': {'ne': {'lat': 1.414363006897338,
#     'lng': 103.91902930280251},
#    'sw': {'lat': 1.39636298889732, 'lng': 103.90105748694664}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4de2614c52b1d38d296c044a',
#        'name': 'Punggol Waterway Park',
#        'location': {'address': 'Punggol',
#         'lat': 1.4102274642652444,
#         'lng': 103.90697479248047,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4102274642652444,
#           'lng': 103.90697479248047}],
#         'distance': 640,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Punggol', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4de2614c52b1d38d296c044a-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '516d1fc7498e1277107cfd36',
#        'name': 'Waterway Point',
#        'location': {'address': '83 Punggol Central',
#         'crossStreet': 'Punggol Walk',
#         'lat': 1.4054246944609918,
#         'lng': 103.90241100370038,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4054246944609918,
#           'lng': 103.90241100370038}],
#         'distance': 849,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['83 Punggol Central (Punggol Walk)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-516d1fc7498e1277107cfd36-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '569dcc4b498ed9bc446b4175',
#        'name': 'Shaw Theatres',
#        'location': {'address': '#B2-11 Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4069484134090613,
#         'lng': 103.90242260109125,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4069484134090613,
#           'lng': 103.90242260109125}],
#         'distance': 866,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-11 Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'shortName': 'Cineplex',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-569dcc4b498ed9bc446b4175-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a9d1fe498e747dc94e8554',
#        'name': 'Uniqlo',
#        'location': {'address': 'L1 Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4067211434870583,
#         'lng': 103.90183732086888,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4067211434870583,
#           'lng': 103.90183732086888}],
#         'distance': 925,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['L1 Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'shortName': 'Apparel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a9d1fe498e747dc94e8554-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '569dbcf3498ed27f54d10e63',
#        'name': 'FairPrice Finest',
#        'location': {'address': '#B2-32, Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.407054644439422,
#         'lng': 103.90234761423325,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.407054644439422,
#           'lng': 103.90234761423325}],
#         'distance': 876,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-32, Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-569dbcf3498ed27f54d10e63-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a2da13498ef4b16b0bf720',
#        'name': "Swensen's",
#        'location': {'address': '#02-35, Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4059304790963372,
#         'lng': 103.90167410094242,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4059304790963372,
#           'lng': 103.90167410094242}],
#         'distance': 933,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-35, Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a2da13498ef4b16b0bf720-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5731f5e3498e3c48b3af3a50',
#        'name': 'i Darts LAVA',
#        'location': {'address': '9 Sentul Crescent, #02-03 SAFRA PUNGGOL',
#         'lat': 1.410513907977455,
#         'lng': 103.90618809422179,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.410513907977455,
#           'lng': 103.90618809422179}],
#         'distance': 716,
#         'postalCode': '828654',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['9 Sentul Crescent, #02-03 SAFRA PUNGGOL',
#          '828654',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5731f5e3498e3c48b3af3a50-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56b45276498eeb26ba1691bd',
#        'name': 'KOI Cafe',
#        'location': {'address': '83, Punggol Central, Waterway Point, #B1-K2, SE 828761',
#         'lat': 1.4069519409398872,
#         'lng': 103.9023707132145,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4069519409398872,
#           'lng': 103.9023707132145}],
#         'distance': 871,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['83, Punggol Central, Waterway Point, #B1-K2, SE 828761',
#          'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56b45276498eeb26ba1691bd-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b2b8ad5e97dfb002cca6508',
#        'name': 'NTUC FairPrice',
#        'location': {'address': 'Oasis Terraces',
#         'crossStreet': 'B1-01',
#         'lat': 1.4030512001966253,
#         'lng': 103.91341986775551,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4030512001966253,
#           'lng': 103.91341986775551}],
#         'distance': 455,
#         'postalCode': '821667',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Oasis Terraces (B1-01)', '821667', 'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b2b8ad5e97dfb002cca6508-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b23313a3e6741002caf3831',
#        'name': 'Starbucks',
#        'location': {'address': 'Oasis Terraces',
#         'crossStreet': 'Level 2',
#         'lat': 1.402571,
#         'lng': 103.912896,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.402571,
#           'lng': 103.912896}],
#         'distance': 444,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Oasis Terraces (Level 2)', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b23313a3e6741002caf3831-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a1fec5498ed9b2aff85a87',
#        'name': 'So Pho',
#        'location': {'address': 'Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.406946891287501,
#         'lng': 103.90246214727334,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.406946891287501,
#           'lng': 103.90246214727334}],
#         'distance': 861,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Waterway Point (83 Punggol Central)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a1fec5498ed9b2aff85a87-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b2331cc237dee002cc11ccd',
#        'name': 'McDonald’s / McCafé',
#        'location': {'address': 'Oasis Terraces',
#         'crossStreet': 'Level 2',
#         'lat': 1.4025386089704104,
#         'lng': 103.91304337588963,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4025386089704104,
#           'lng': 103.91304337588963}],
#         'distance': 458,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Oasis Terraces (Level 2)', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b2331cc237dee002cc11ccd-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56ab4d10498e6a94992b4cfc',
#        'name': 'Din Tai Fung 鼎泰豐',
#        'location': {'address': '#01-22, Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4066485498475065,
#         'lng': 103.90213956349609,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4066485498475065,
#           'lng': 103.90213956349609}],
#         'distance': 891,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-22, Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56ab4d10498e6a94992b4cfc-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57369448498e45f1decf154c',
#        'name': "McDonald's",
#        'location': {'address': '#03-05, SAFRA Punggol',
#         'crossStreet': '9 Sentul Crescent',
#         'lat': 1.410087692565293,
#         'lng': 103.90592970102844,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.410087692565293,
#           'lng': 103.90592970102844}],
#         'distance': 697,
#         'postalCode': '828654',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#03-05, SAFRA Punggol (9 Sentul Crescent)',
#          '828654',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57369448498e45f1decf154c-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '569ddba5498e3013ce57dde4',
#        'name': 'Social Square',
#        'location': {'address': '#01-26, Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4069418656671098,
#         'lng': 103.90243239882304,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4069418656671098,
#           'lng': 103.90243239882304}],
#         'distance': 865,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-26, Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-569ddba5498e3013ce57dde4-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56f52fd3498efedacf8872a7',
#        'name': 'Genki Sushi',
#        'location': {'address': '#02-23 Waterway Point (West wing)',
#         'lat': 1.4066135537990099,
#         'lng': 103.90204504078514,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4066135537990099,
#           'lng': 103.90204504078514}],
#         'distance': 900,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-23 Waterway Point (West wing)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56f52fd3498efedacf8872a7-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e86ef7846903b39f83f24bd',
#        'name': 'Wave Bridge',
#        'location': {'address': 'Punggol Waterway',
#         'crossStreet': 'Near Oasis LRT',
#         'lat': 1.403451433611347,
#         'lng': 103.91349558688046,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.403451433611347,
#           'lng': 103.91349558688046}],
#         'distance': 439,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Punggol Waterway (Near Oasis LRT)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1df941735',
#          'name': 'Bridge',
#          'pluralName': 'Bridges',
#          'shortName': 'Bridge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/bridge_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e86ef7846903b39f83f24bd-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4073c1f964a52048b825e3',
#        'name': 'Sheng Siong Supermarket 昇菘超市',
#        'location': {'address': '#01-01, Coralinus',
#         'crossStreet': '301 Punggol Central',
#         'lat': 1.4023877428899514,
#         'lng': 103.90470077848144,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4023877428899514,
#           'lng': 103.90470077848144}],
#         'distance': 680,
#         'postalCode': '820301',
#         'cc': 'SG',
#         'neighborhood': 'Punggol',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01, Coralinus (301 Punggol Central)',
#          '820301',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4073c1f964a52048b825e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56adf2b7498e3b4bd3925531',
#        'name': 'Uncle Leong Signatures',
#        'location': {'address': 'Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4070324356848343,
#         'lng': 103.90242124218662,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4070324356848343,
#           'lng': 103.90242124218662}],
#         'distance': 868,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Waterway Point (83 Punggol Central)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56adf2b7498e3b4bd3925531-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a58323498e66937eafbfa9',
#        'name': 'Toast Box 土司工坊',
#        'location': {'address': 'Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4071022436897045,
#         'lng': 103.90237142852804,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4071022436897045,
#           'lng': 103.90237142852804}],
#         'distance': 875,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Waterway Point (83 Punggol Central)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a58323498e66937eafbfa9-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '569ee40d498e1db0b55e6b99',
#        'name': 'Starbucks',
#        'location': {'address': '#01-67, Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4060871998966102,
#         'lng': 103.9018219656174,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4060871998966102,
#           'lng': 103.9018219656174}],
#         'distance': 918,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-67, Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-569ee40d498e1db0b55e6b99-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc269e574a9a5933057d3f6',
#        'name': 'Punggol Secondary School',
#        'location': {'address': '51 Edgefield Plains',
#         'lat': 1.4019293249142708,
#         'lng': 103.90897555148197,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4019293249142708,
#           'lng': 103.90897555148197}],
#         'distance': 400,
#         'postalCode': '828870',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['51 Edgefield Plains', '828870', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d13d941735',
#          'name': 'High School',
#          'pluralName': 'High Schools',
#          'shortName': 'High School',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc269e574a9a5933057d3f6-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a07f70498e2c0eaa62d60f',
#        'name': 'Cookhouse by Koufu',
#        'location': {'address': '#02-20, Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.407214255678947,
#         'lng': 103.90192349653015,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.407214255678947,
#           'lng': 103.90192349653015}],
#         'distance': 926,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-20, Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a07f70498e2c0eaa62d60f-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a2f460498e17284dfdeea7',
#        'name': 'Subway',
#        'location': {'address': 'Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4069685955652709,
#         'lng': 103.90241987705505,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4069685955652709,
#           'lng': 103.90241987705505}],
#         'distance': 867,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Waterway Point (83 Punggol Central)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a2f460498e17284dfdeea7-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56aef6b0498e7cbb2bb7458a',
#        'name': 'PappaRich',
#        'location': {'address': 'Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4068952713242397,
#         'lng': 103.90244505351451,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4068952713242397,
#           'lng': 103.90244505351451}],
#         'distance': 862,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Waterway Point (83 Punggol Central)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56aef6b0498e7cbb2bb7458a-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b9a5e2e911fc4002ce6f52c',
#        'name': 'KFC',
#        'location': {'crossStreet': 'Oasis Terraces',
#         'lat': 1.4029615,
#         'lng': 103.91343,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4029615,
#           'lng': 103.91343}],
#         'distance': 462,
#         'postalCode': '821669',
#         'cc': 'SG',
#         'neighborhood': 'Punggol',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Oasis Terraces', '821669', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b9a5e2e911fc4002ce6f52c-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '505307c1e4b06562e2650c6f',
#        'name': 'Roasted Delights 新香港',
#        'location': {'address': 'Broadway',
#         'crossStreet': '#01-01 612 Punggol Dr',
#         'lat': 1.4049271633092972,
#         'lng': 103.9089258618175,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4049271633092972,
#           'lng': 103.9089258618175}],
#         'distance': 133,
#         'postalCode': '820612',
#         'cc': 'SG',
#         'city': 'Damai Grove',
#         'state': 'Punggol',
#         'country': 'Singapore',
#         'formattedAddress': ['Broadway (#01-01 612 Punggol Dr)',
#          '820612',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-505307c1e4b06562e2650c6f-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '569f1324498e620828940b83',
#        'name': 'Rong Hua Bak Kut Teh',
#        'location': {'address': '#B1-23 Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4070880349011148,
#         'lng': 103.9024358639188,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4070880349011148,
#           'lng': 103.9024358639188}],
#         'distance': 868,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-23 Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-569f1324498e620828940b83-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '569f50f6498e0c3b03c9ba1c',
#        'name': 'Daiso',
#        'location': {'address': '#B1-09, Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4070798007029575,
#         'lng': 103.90222579182492,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4070798007029575,
#           'lng': 103.90222579182492}],
#         'distance': 890,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-09, Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '52dea92d3cf9994f4e043dbb',
#          'name': 'Discount Store',
#          'pluralName': 'Discount Stores',
#          'shortName': 'Discount Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/discountstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-569f50f6498e0c3b03c9ba1c-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d0dfd2ce0b98cfa1a41df93',
#        'name': 'Punggol Treelodge Basketball Court',
#        'location': {'address': 'Punggol',
#         'lat': 1.4041414417420293,
#         'lng': 103.90759954873977,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4041414417420293,
#           'lng': 103.90759954873977}],
#         'distance': 304,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Punggol', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e1941735',
#          'name': 'Basketball Court',
#          'pluralName': 'Basketball Courts',
#          'shortName': 'Basketball Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/basketballcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d0dfd2ce0b98cfa1a41df93-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56ac4f26498ef3afc40664e2',
#        'name': 'The Coffee Bean & Tea Leaf',
#        'location': {'address': '#01-27, Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4069534810682496,
#         'lng': 103.90245206329863,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4069534810682496,
#           'lng': 103.90245206329863}],
#         'distance': 863,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-27, Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56ac4f26498ef3afc40664e2-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '569e0dfb498e231544cd72b4',
#        'name': 'Twelve Cupcakes ✨',
#        'location': {'address': 'Waterway Point @ Punggol',
#         'lat': 1.405523,
#         'lng': 103.907066,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.405523,
#           'lng': 103.907066}],
#         'distance': 331,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Waterway Point @ Punggol', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-569e0dfb498e231544cd72b4-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a30e1d498e0d995f0ec5ef',
#        'name': 'Buddy Hoagies Café & Grill',
#        'location': {'address': '#02-22, Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4069133272194183,
#         'lng': 103.90210944928498,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4069133272194183,
#           'lng': 103.90210944928498}],
#         'distance': 899,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-22, Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1cc941735',
#          'name': 'Steakhouse',
#          'pluralName': 'Steakhouses',
#          'shortName': 'Steakhouse',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a30e1d498e0d995f0ec5ef-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f7c10dae4b02e0090644f16',
#        'name': '飲水思源',
#        'location': {'address': 'Fu Chan 富城餐室',
#         'crossStreet': '301 Punggol Drive',
#         'lat': 1.4035414592400757,
#         'lng': 103.90645563105544,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4035414592400757,
#           'lng': 103.90645563105544}],
#         'distance': 447,
#         'postalCode': '823301',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Fu Chan 富城餐室 (301 Punggol Drive)',
#          '823301',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f7c10dae4b02e0090644f16-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b2b8904898bdc002c1d988e',
#        'name': 'R&B Tea 茶',
#        'location': {'address': 'Oasis Terraces',
#         'crossStreet': 'B1-03',
#         'lat': 1.402918,
#         'lng': 103.913316,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.402918,
#           'lng': 103.913316}],
#         'distance': 454,
#         'postalCode': '821667',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Oasis Terraces (B1-03)', '821667', 'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b2b8904898bdc002c1d988e-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a06500498e8d62a38beb6a',
#        'name': 'The Soup Spoon Union',
#        'location': {'address': '#B3-12, Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4071167985741988,
#         'lng': 103.90219315326691,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4071167985741988,
#           'lng': 103.90219315326691}],
#         'distance': 895,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B3-12, Waterway Point (83 Punggol Central)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1dd931735',
#          'name': 'Soup Place',
#          'pluralName': 'Soup Places',
#          'shortName': 'Soup',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/soup_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a06500498e8d62a38beb6a-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '554b2b22498eac17443b52be',
#        'name': 'Water Drop Teahouse 滴水坊',
#        'location': {'address': 'Fo Guang Shan (Singapore), No.1 Punggol Place (3rd floor)',
#         'crossStreet': 'Pungol Drive',
#         'lat': 1.4067653894589793,
#         'lng': 103.90543780091573,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4067653894589793,
#           'lng': 103.90543780091573}],
#         'distance': 535,
#         'postalCode': '828844',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Fo Guang Shan (Singapore), No.1 Punggol Place (3rd floor) (Pungol Drive)',
#          '828844',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1dc931735',
#          'name': 'Tea Room',
#          'pluralName': 'Tea Rooms',
#          'shortName': 'Tea Room',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/tearoom_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-554b2b22498eac17443b52be-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56ab3672498eb95ba219ac9a',
#        'name': 'KFC',
#        'location': {'address': '#B2-08 Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4070473257174922,
#         'lng': 103.90242040157318,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4070473257174922,
#           'lng': 103.90242040157318}],
#         'distance': 868,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-08 Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56ab3672498eb95ba219ac9a-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a22b24498e1e86ca17a3fd',
#        'name': 'Tenderfresh Classic',
#        'location': {'address': 'Waterway Point #B2-04',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4070446865782735,
#         'lng': 103.90238271724671,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4070446865782735,
#           'lng': 103.90238271724671}],
#         'distance': 872,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'neighborhood': 'Punggol',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Waterway Point #B2-04 (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a22b24498e1e86ca17a3fd-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '569c5b32498e2d32d7192dd4',
#        'name': "McDonald's / McCafe",
#        'location': {'address': '#B2-07, Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4070583268158896,
#         'lng': 103.9023713780459,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4070583268158896,
#           'lng': 103.9023713780459}],
#         'distance': 874,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'neighborhood': 'Punggol',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-07, Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-569c5b32498e2d32d7192dd4-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56ee807d498e73779f3f0116',
#        'name': 'Community Plaza',
#        'location': {'lat': 1.4017620526313133,
#         'lng': 103.91465677291548,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4017620526313133,
#           'lng': 103.91465677291548}],
#         'distance': 651,
#         'cc': 'SG',
# ...
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a45c526c4df1d5eb2a09e64-53'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56bf1e36cd10624fa51578d9',
#        'name': '一哥老火汤',
#        'location': {'address': 'Waterway Point B1-22',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.407106,
#         'lng': 103.902463,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.407106,
#           'lng': 103.902463}],
#         'distance': 865,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Waterway Point B1-22 (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56bf1e36cd10624fa51578d9-54'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca0ef7e3244b21a1e4b3703',
#        'name': 'SBS Transit: Punggol LRT (West Loop)',
#        'location': {'lat': 1.4051824745546406,
#         'lng': 103.90225808010834,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4051824745546406,
#           'lng': 103.90225808010834}],
#         'distance': 866,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fc931735',
#          'name': 'Light Rail Station',
#          'pluralName': 'Light Rail Stations',
#          'shortName': 'Light Rail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/lightrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca0ef7e3244b21a1e4b3703-55'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50b611f2f136805b2d8c274c',
#        'name': 'Cheers',
#        'location': {'address': 'Punggol Place',
#         'lat': 1.4043430161704258,
#         'lng': 103.90230793953897,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4043430161704258,
#           'lng': 103.90230793953897}],
#         'distance': 868,
#         'postalCode': '824276',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Punggol Place', '824276', 'Singapore']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50b611f2f136805b2d8c274c-56'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '569d732c498eb5f352ef5b38',
#        'name': 'The Boardwalk',
#        'location': {'address': 'Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4063172936789752,
#         'lng': 103.9022695762444,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4063172936789752,
#           'lng': 103.9022695762444}],
#         'distance': 871,
#         'cc': 'SG',
#         'city': 'Punggol',
#         'state': 'North East Community Development Region',
#         'country': 'Singapore',
#         'formattedAddress': ['Waterway Point (83 Punggol Central)',
#          'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a25',
#          'name': 'Pedestrian Plaza',
#          'pluralName': 'Pedestrian Plazas',
#          'shortName': 'Pedestrian Street/Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-569d732c498eb5f352ef5b38-57'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57359938cd10c41112538e75',
#        'name': 'Pezzo',
#        'location': {'address': '#B2-K8, Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.407051,
#         'lng': 103.902384,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.407051,
#           'lng': 103.902384}],
#         'distance': 872,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B2-K8, Waterway Point (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57359938cd10c41112538e75-58'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c4abb4c916bc1002c5c93c4',
#        'name': 'Playmade by 丸作',
#        'location': {'address': '#B1-K6 Waterway Point',
#         'lat': 1.406789,
#         'lng': 103.902263,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.406789,
#           'lng': 103.902263}],
#         'distance': 880,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Punggol',
#         'state': 'North East Community Development Region',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-K6 Waterway Point', '828761', 'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'shortName': 'Bubble Tea',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c4abb4c916bc1002c5c93c4-59'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56a9cfa4498efbdcf3a77c65',
#        'name': 'H&M',
#        'location': {'address': '83 Punggol Central',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.4062735844987622,
#         'lng': 103.90202475478874,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4062735844987622,
#           'lng': 103.90202475478874}],
#         'distance': 898,
#         'postalCode': '828761',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['83 Punggol Central (83 Punggol Central)',
#          '828761',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'shortName': 'Apparel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56a9cfa4498efbdcf3a77c65-60'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d22c95193006900234af451',
#        'name': 'Popeyes Louisiana Kitchen',
#        'location': {'address': 'Waterway Point',
#         'lat': 1.4068164,
#         'lng': 103.90207,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4068164,
#           'lng': 103.90207}],
#         'distance': 901,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Waterway Point', 'Singapore']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5d22c95193006900234af451-61'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5aa8af236e465072c6cb8972',
#        'name': 'Guschlbauer',
#        'location': {'address': '#01-K16 Waterway Point',
#         'crossStreet': '83 Punggol Central',
#         'lat': 1.406443,
#         'lng': 103.901897,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.406443,
#           'lng': 103.901897}],
#         'distance': 914,
#         'postalCode': '828726',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-K16 Waterway Point (83 Punggol Central)',
#          '828726',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'shortName': 'Bakery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5aa8af236e465072c6cb8972-62'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '574a7633498eb57fb742e402',
#        'name': 'Toy Or Game',
#        'location': {'address': '#02-18',
#         'crossStreet': 'Waterway Point',
#         'lat': 1.4066791480150964,
#         'lng': 103.90186706642308,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4066791480150964,
#           'lng': 103.90186706642308}],
#         'distance': 921,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-18 (Waterway Point)', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1f3941735',
#          'name': 'Toy / Game Store',
#          'pluralName': 'Toy / Game Stores',
#          'shortName': 'Toys & Games',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/toys_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-574a7633498eb57fb742e402-63'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eedfc400e01899e004bdc40',
#        'name': '7-Eleven',
#        'location': {'address': 'Blk 639 Punggol Drive',
#         'lat': 1.39958184954582,
#         'lng': 103.91600517921556,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.39958184954582,
#           'lng': 103.91600517921556}],
#         'distance': 924,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 639 Punggol Drive', 'Singapore']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eedfc400e01899e004bdc40-64'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d30715582fd5481ac48b3a8',
#        'name': 'Roof Garden @ Blk 106c',
#        'location': {'address': 'Punggol field',
#         'lat': 1.397261,
#         'lng': 103.907262,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.397261,
#           'lng': 103.907262}],
#         'distance': 953,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Punggol field', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d30715582fd5481ac48b3a8-65'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d7c9b78ea35236abd255c23',
#        'name': 'Master Crab 螃蟹师傅',
#        'location': {'address': 'Blk 108 Punggol Field (Kopitiam)',
#         'lat': 1.3967332981290081,
#         'lng': 103.90899156452903,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3967332981290081,
#           'lng': 103.90899156452903}],
#         'distance': 967,
#         'postalCode': '820108',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 108 Punggol Field (Kopitiam)',
#          '820108',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d7c9b78ea35236abd255c23-66'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51725b2ae4b0f4dfa617f4b2',
#        'name': 'Bus Stop 65321 (Kadaloor Stn)',
#        'location': {'address': 'Punggol Drive',
#         'lat': 1.3993683302011832,
#         'lng': 103.91656231382166,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3993683302011832,
#           'lng': 103.91656231382166}],
#         'distance': 985,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Punggol Drive', 'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b4f',
#          'name': 'Bus Stop',
#          'pluralName': 'Bus Stops',
#          'shortName': 'Bus Stop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51725b2ae4b0f4dfa617f4b2-67'}]}]}}

# %%
#function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list=row['categories']
    except:
        categories_list=row['venue.categories']
    
    if len(categories_list)==0:
        return None
    else:
        return categories_list[0]['name']

# %%
#Cleaning the json and structuring it into a Pandas DataFrame
venues = results['response']['groups'][0]['items']

#flatten json
nearby_venues = pd.json_normalize(venues)
                       
#filter columns
filtered_columns=['venue.name','venue.categories','venue.location.lat','venue.location.lng']
nearby_venues=nearby_venues.loc[:,filtered_columns]

#filter category for each row
nearby_venues['venue.categories']=nearby_venues.apply(get_category_type, axis=1)
                           
#clean columns
nearby_venues.columns=[col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head(200)
# Out:
#                              name         categories       lat         lng
# 0           Punggol Waterway Park               Park  1.410227  103.906975
# 1                  Waterway Point      Shopping Mall  1.405425  103.902411
# 2                   Shaw Theatres          Multiplex  1.406948  103.902423
# 3                          Uniqlo     Clothing Store  1.406721  103.901837
# 4                FairPrice Finest        Supermarket  1.407055  103.902348
# ..                            ...                ...       ...         ...
# 63                    Toy Or Game   Toy / Game Store  1.406679  103.901867
# 64                       7-Eleven  Convenience Store  1.399582  103.916005
# 65         Roof Garden @ Blk 106c               Park  1.397261  103.907262
# 66               Master Crab 螃蟹师傅        Coffee Shop  1.396733  103.908992
# 67  Bus Stop 65321 (Kadaloor Stn)           Bus Stop  1.399368  103.916562
#
# [68 rows x 4 columns]

# %%
#create 3 additional columns to indicate respective planning area and its longitude and latitude
punggol=nearby_venues.assign(planning_area='PUNGGOL',
                           area_latitude=latitude,
                           area_longitude=longitude)

# %%
#Repositioning the columns and renaming the column names
punggol=punggol[['planning_area','area_latitude','area_longitude','name','lat','lng','categories']]

punggol.rename(columns={'name':'venue_name',
            'lat':'venue_latitude',
             'lng':'venue_longitude',
             'categories':'venue_categories'}, inplace=True)

# %%
#check data
punggol
# Out:
#    planning_area  area_latitude  area_longitude  \
# 0        PUNGGOL       1.405363      103.910043
# 1        PUNGGOL       1.405363      103.910043
# 2        PUNGGOL       1.405363      103.910043
# 3        PUNGGOL       1.405363      103.910043
# 4        PUNGGOL       1.405363      103.910043
# ..           ...            ...             ...
# 63       PUNGGOL       1.405363      103.910043
# 64       PUNGGOL       1.405363      103.910043
# 65       PUNGGOL       1.405363      103.910043
# 66       PUNGGOL       1.405363      103.910043
# 67       PUNGGOL       1.405363      103.910043
#
#                        venue_name  venue_latitude  venue_longitude  \
# 0           Punggol Waterway Park        1.410227       103.906975
# 1                  Waterway Point        1.405425       103.902411
# 2                   Shaw Theatres        1.406948       103.902423
# 3                          Uniqlo        1.406721       103.901837
# 4                FairPrice Finest        1.407055       103.902348
# ..                            ...             ...              ...
# 63                    Toy Or Game        1.406679       103.901867
# 64                       7-Eleven        1.399582       103.916005
# 65         Roof Garden @ Blk 106c        1.397261       103.907262
# 66               Master Crab 螃蟹师傅        1.396733       103.908992
# 67  Bus Stop 65321 (Kadaloor Stn)        1.399368       103.916562
#
#      venue_categories
# 0                Park
# 1       Shopping Mall
# 2           Multiplex
# 3      Clothing Store
# 4         Supermarket
# ..                ...
# 63   Toy / Game Store
# 64  Convenience Store
# 65               Park
# 66        Coffee Shop
# 67           Bus Stop
#
# [68 rows x 7 columns]

# %%
punggol.to_csv("punggol.csv")

# %% [markdown]
# ## ANG MO KIO

# %%
# @hidden_cell
#Defining Foursquare credentials and version
CLIENT_ID='5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K'
CLIENT_SECRET='UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR'
VERSION='20180605'

# %%
#Create GET request url

latitude=amk.loc[0,'area_latitude']
longitude=amk.loc[0,'area_longitude']

LIMIT=200
radius=1000

url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
CLIENT_ID,
CLIENT_SECRET,
VERSION,
latitude,
longitude,
radius,
LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K&client_secret=UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR&v=20180605&ll=1.380092406326446,103.842096537105&radius=1000&limit=200'

# %%
#send GET request url and examine results

results=requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '613da906d1665508d2cea284'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Ang Mo Kio',
#   'headerFullLocation': 'Ang Mo Kio, Singapore',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 39,
#   'suggestedBounds': {'ne': {'lat': 1.389092415326455,
#     'lng': 103.85108234867631},
#    'sw': {'lat': 1.3710923973264368, 'lng': 103.83311072553367}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57ced66f498eb312cf9a5f15',
#        'name': 'Prodigal Roasters',
#        'location': {'address': 'Blk 625, Ang Mo Kio Ave 9',
#         'lat': 1.3822120650112213,
#         'lng': 103.84134650230408,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3822120650112213,
#           'lng': 103.84134650230408}],
#         'distance': 250,
#         'postalCode': '560625',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 625, Ang Mo Kio Ave 9',
#          '560625',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57ced66f498eb312cf9a5f15-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c3ac9db16cb2d7f0ed901a9',
#        'name': 'Ho-Ree Roasted Food 好味烧腊',
#        'location': {'address': '#01-84 628 Ang Mo Kio Food Centre',
#         'crossStreet': 'Blk 628 Ang Mo Kio Ave 4',
#         'lat': 1.3811602378001138,
#         'lng': 103.84097655413296,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3811602378001138,
#           'lng': 103.84097655413296}],
#         'distance': 172,
#         'postalCode': '560628',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-84 628 Ang Mo Kio Food Centre (Blk 628 Ang Mo Kio Ave 4)',
#          '560628',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c3ac9db16cb2d7f0ed901a9-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d7baee98f89224bb2539526',
#        'name': 'Vegetarian @ 630 AMK Kopitiam',
#        'location': {'address': 'Blk 630 Ang Mo Kio St 61',
#         'lat': 1.3807211478002785,
#         'lng': 103.84132749028151,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3807211478002785,
#           'lng': 103.84132749028151}],
#         'distance': 110,
#         'postalCode': '560630',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 630 Ang Mo Kio St 61',
#          '560630',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d3941735',
#          'name': 'Vegetarian / Vegan Restaurant',
#          'pluralName': 'Vegetarian / Vegan Restaurants',
#          'shortName': 'Vegetarian / Vegan',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d7baee98f89224bb2539526-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b95738df964a52046a334e3',
#        'name': 'Ang Mo Kio Town Garden West',
#        'location': {'address': 'Ang Mo Kio Ave 6',
#         'crossStreet': 'opp Ang Mo Kio Library',
#         'lat': 1.3760388362663805,
#         'lng': 103.84452750322855,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3760388362663805,
#           'lng': 103.84452750322855}],
#         'distance': 526,
#         'postalCode': '569869',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Ang Mo Kio Ave 6 (opp Ang Mo Kio Library)',
#          '569869',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b95738df964a52046a334e3-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e250500d22df6f888761a56',
#        'name': 'Shanghai Ren Jia 上海人家',
#        'location': {'address': 'Blk 151 Ang Mo Kio Ave 5 #01-3046',
#         'lat': 1.377067740107575,
#         'lng': 103.84132926875178,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.377067740107575,
#           'lng': 103.84132926875178}],
#         'distance': 347,
#         'postalCode': '560151',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 151 Ang Mo Kio Ave 5 #01-3046',
#          '560151',
#          'Singapore']},
#        'categories': [{'id': '52af3b593cf9994f4e043c00',
#          'name': 'Shanghai Restaurant',
#          'pluralName': 'Shanghai Restaurants',
#          'shortName': 'Shanghai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e250500d22df6f888761a56-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d0b4eb8b93b224bd2054bbf',
#        'name': 'Mr Teh Tarik Eating House',
#        'location': {'address': '608 Ang Mo Kio Ave 5 #01-2771',
#         'lat': 1.378458062057113,
#         'lng': 103.8366848230362,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.378458062057113,
#           'lng': 103.8366848230362}],
#         'distance': 629,
#         'postalCode': '560608',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['608 Ang Mo Kio Ave 5 #01-2771',
#          '560608',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d0b4eb8b93b224bd2054bbf-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57d12fd6498e1fc60b9bfd20',
#        'name': 'Sumo Big Prawn',
#        'location': {'address': '#01-72 628 Ang Mo Kio Market & Food Centre',
#         'crossStreet': '628 Ang Mo Kio Ave 4',
#         'lat': 1.3811210843779824,
#         'lng': 103.84077843127767,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3811210843779824,
#           'lng': 103.84077843127767}],
#         'distance': 186,
#         'postalCode': '560628',
#         'cc': 'SG',
#         'neighborhood': 'Ang Mo Kio, Singapore',
#         'city': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-72 628 Ang Mo Kio Market & Food Centre (628 Ang Mo Kio Ave 4)',
#          '560628',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57d12fd6498e1fc60b9bfd20-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50c453c5e4b0e9bc07bbd064',
#        'name': 'Charcos The Flaming Chicken',
#        'location': {'address': '608 Ang Mo Kio Ave 5, #01-2771',
#         'lat': 1.3782201668288778,
#         'lng': 103.83687074989234,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3782201668288778,
#           'lng': 103.83687074989234}],
#         'distance': 617,
#         'postalCode': '560608',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['608 Ang Mo Kio Ave 5, #01-2771',
#          '560608',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d169941735',
#          'name': 'Australian Restaurant',
#          'pluralName': 'Australian Restaurants',
#          'shortName': 'Australian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/australian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50c453c5e4b0e9bc07bbd064-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db65516fa8c3502410e77b0',
#        'name': 'Nanyang Polytechnic Auditorium',
#        'location': {'address': '180 Ang Mo Kio Ave 8',
#         'lat': 1.3801859511812247,
#         'lng': 103.84829807201557,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3801859511812247,
#           'lng': 103.84829807201557}],
#         'distance': 690,
#         'postalCode': '569830',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['180 Ang Mo Kio Ave 8', '569830', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1af941735',
#          'name': 'College Auditorium',
#          'pluralName': 'College Auditoriums',
#          'shortName': 'Auditorium',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/auditorium_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db65516fa8c3502410e77b0-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5799ecad498ec6d503ab8a53',
#        'name': 'Mr Teh Tarik',
#        'location': {'address': 'Blk 728 Ang Mo Kio Avenue 6',
#         'crossStreet': 'Ang Mo Kio Central',
#         'lat': 1.3721677783775261,
#         'lng': 103.84560223678665,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3721677783775261,
#           'lng': 103.84560223678665}],
#         'distance': 964,
#         'postalCode': '560728',
#         'cc': 'SG',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 728 Ang Mo Kio Avenue 6 (Ang Mo Kio Central)',
#          '560728',
#          'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b79ff',
#          'name': 'Halal Restaurant',
#          'pluralName': 'Halal Restaurants',
#          'shortName': 'Halal',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5799ecad498ec6d503ab8a53-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51243f60e4b02ffb6a43eeea',
#        'name': 'Soi 19 十九街 Thai Wanton Mee',
#        'location': {'address': 'Blk 151 Ang Mo Kio Ave 5',
#         'lat': 1.3770035731848176,
#         'lng': 103.84070578967811,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3770035731848176,
#           'lng': 103.84070578967811}],
#         'distance': 377,
#         'postalCode': '560151',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 151 Ang Mo Kio Ave 5',
#          '560151',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51243f60e4b02ffb6a43eeea-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ea685b549015fc80b3b86d9',
#        'name': 'Yio Chu Kang Squash And Tennis Center',
#        'location': {'address': '200 Ang Mo Kio Ave 9',
#         'lat': 1.3823905005232942,
#         'lng': 103.84578873663082,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3823905005232942,
#           'lng': 103.84578873663082}],
#         'distance': 484,
#         'postalCode': '569770',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['200 Ang Mo Kio Ave 9', '569770', 'Singapore']},
#        'categories': [{'id': '4e39a956bd410d7aed40cbc3',
#          'name': 'Tennis Court',
#          'pluralName': 'Tennis Courts',
#          'shortName': 'Tennis Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_tennis_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ea685b549015fc80b3b86d9-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d267d73467d6ea8419fb495',
#        'name': 'Liang Seng Huat Pte Ltd',
#        'location': {'address': '632 Ang Mo Kio Ave 4',
#         'crossStreet': 'Ang Mo Kio St 61',
#         'lat': 1.3797592366808389,
#         'lng': 103.84175132962882,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3797592366808389,
#           'lng': 103.84175132962882}],
#         'distance': 53,
#         'postalCode': '560632',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['632 Ang Mo Kio Ave 4 (Ang Mo Kio St 61)',
#          '560632',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d267d73467d6ea8419fb495-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51106ddfe4b06f1f2fbb9fa4',
#        'name': 'Subway',
#        'location': {'address': 'Blk A, Lvl 2, North Wing Centre',
#         'lat': 1.380691,
#         'lng': 103.849113,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.380691,
#           'lng': 103.849113}],
#         'distance': 783,
#         'cc': 'SG',
#         'city': 'Nanyang Polytechnic',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk A, Lvl 2, North Wing Centre', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51106ddfe4b06f1f2fbb9fa4-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cba15204c60a093251244ca',
#        'name': "McDonald's / McCafé",
#        'location': {'address': '10 Ang Mo Kio St. 12',
#         'crossStreet': 'Ang Mo Kio Town Park East',
#         'lat': 1.3724615165738063,
#         'lng': 103.84497980176036,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3724615165738063,
#           'lng': 103.84497980176036}],
#         'distance': 908,
#         'postalCode': '567740',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['10 Ang Mo Kio St. 12 (Ang Mo Kio Town Park East)',
#          '567740',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cba15204c60a093251244ca-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c37e39dae2da593abd4ffc5',
#        'name': 'Mayflower Market & Food Centre',
#        'location': {'address': '162 Ang Mo Kio Ave 4',
#         'lat': 1.3740506635058949,
#         'lng': 103.8388794994651,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3740506635058949,
#           'lng': 103.8388794994651}],
#         'distance': 761,
#         'postalCode': '560162',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['162 Ang Mo Kio Ave 4', '560162', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c37e39dae2da593abd4ffc5-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d337eec5c2db60c4bb6cb6c',
#        'name': '7-Eleven',
#        'location': {'address': '#01-01 Yio Chu Kang MRT Station',
#         'crossStreet': '3000 Ang Mo Kio Ave. 8',
#         'lat': 1.3816514252680192,
#         'lng': 103.84451051892127,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3816514252680192,
#           'lng': 103.84451051892127}],
#         'distance': 319,
#         'postalCode': '569813',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01 Yio Chu Kang MRT Station (3000 Ang Mo Kio Ave. 8)',
#          '569813',
#          'Singapore']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d337eec5c2db60c4bb6cb6c-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '559b6ea2498e6906f2cd6c78',
#        'name': 'Foodgle Hub',
#        'location': {'address': 'Block P1 Convention Centre',
#         'crossStreet': '180 Ang Mo Kio Avenue 8',
#         'lat': 1.3768895452580805,
#         'lng': 103.84931340113828,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3768895452580805,
#           'lng': 103.84931340113828}],
#         'distance': 878,
#         'postalCode': '569830',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Block P1 Convention Centre (180 Ang Mo Kio Avenue 8)',
#          '569830',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-559b6ea2498e6906f2cd6c78-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c4906da3013a59356652de2',
#        'name': 'Coffee Sense 咖啡鄉',
#        'location': {'address': 'Blk 181 Ang Mo Kio Ave 5, #01-2922',
#         'lat': 1.377207267064104,
#         'lng': 103.83704939814193,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.377207267064104,
#           'lng': 103.83704939814193}],
#         'distance': 647,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 181 Ang Mo Kio Ave 5, #01-2922',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c4906da3013a59356652de2-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e103080b61c637b97a21504',
#        'name': 'Courts',
#        'location': {'address': '730 Ang Mo Kio Ave 6',
#         'lat': 1.3734864861781395,
#         'lng': 103.84606954566723,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3734864861781395,
#           'lng': 103.84606954566723}],
#         'distance': 858,
#         'postalCode': '560730',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['730 Ang Mo Kio Ave 6', '560730', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'shortName': 'Electronics',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e103080b61c637b97a21504-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7f5200f964a5205b2730e3',
#        'name': 'Yio Chu Kang ClubFITT Gym',
#        'location': {'address': '200 Ang Mo Kio Ave 9',
#         'lat': 1.3823379978229333,
#         'lng': 103.84599366905869,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3823379978229333,
#           'lng': 103.84599366905869}],
#         'distance': 500,
#         'postalCode': '569770',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['200 Ang Mo Kio Ave 9', '569770', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'shortName': 'Gym / Fitness',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7f5200f964a5205b2730e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5927e19660d11b1c66aea40a',
#        'name': 'Angel Supermart',
#        'location': {'address': 'Blk 631 Ang Mo Kio Ave 4, #01-938',
#         'lat': 1.3793966747164272,
#         'lng': 103.84081619540956,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3793966747164272,
#           'lng': 103.84081619540956}],
#         'distance': 162,
#         'postalCode': '561631',
#         'cc': 'SG',
#         'city': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 631 Ang Mo Kio Ave 4, #01-938',
#          '561631',
#          'Singapore']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5927e19660d11b1c66aea40a-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5285f3cd11d2b6a8411ecef4',
#        'name': 'Broadway Coffeeshop',
#        'location': {'address': 'Blk 727 Ang Mo Kio Ave 6',
#         'lat': 1.3730720409991226,
#         'lng': 103.84639344910318,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3730720409991226,
#           'lng': 103.84639344910318}],
#         'distance': 916,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 727 Ang Mo Kio Ave 6', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5285f3cd11d2b6a8411ecef4-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b89ee24f964a520f05632e3',
#        'name': 'Yio Chu Kang Swimming Complex',
#        'location': {'address': '202 Ang Mo Kio Ave 9',
#         'lat': 1.3817029395277733,
#         'lng': 103.84688439515668,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3817029395277733,
#           'lng': 103.84688439515668}],
#         'distance': 562,
#         'postalCode': '569771',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['202 Ang Mo Kio Ave 9', '569771', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d15e941735',
#          'name': 'Pool',
#          'pluralName': 'Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b89ee24f964a520f05632e3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf5b60c64e3721e9b5c1dc8',
#        'name': 'Bus Stop 55139 (Blk 641)',
#        'location': {'address': 'Ang Mo Kio Ave 4',
#         'lat': 1.3789212938147482,
#         'lng': 103.83994440754653,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3789212938147482,
#           'lng': 103.83994440754653}],
#         'distance': 272,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Ang Mo Kio Ave 4', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf5b60c64e3721e9b5c1dc8-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0951d8f964a520a51523e3',
#        'name': "McDonald's",
#        'location': {'address': '163 Ang Mo Kio Ave 4 #01-438',
#         'lat': 1.3736505544423518,
#         'lng': 103.83749563244339,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3736505544423518,
#           'lng': 103.83749563244339}],
#         'distance': 881,
#         'postalCode': '560163',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['163 Ang Mo Kio Ave 4 #01-438',
#          '560163',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0951d8f964a520a51523e3-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd000909854d13a550cf74d',
#        'name': 'South Canteen',
#        'location': {'address': 'Blk P Level 2, NYP',
#         'crossStreet': '180 Ang Mo Kio Ave 8',
#         'lat': 1.378085101313606,
#         'lng': 103.8494796849789,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.378085101313606,
#           'lng': 103.8494796849789}],
#         'distance': 851,
#         'postalCode': '569830',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk P Level 2, NYP (180 Ang Mo Kio Ave 8)',
#          '569830',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1a1941735',
#          'name': 'College Cafeteria',
#          'pluralName': 'College Cafeterias',
#          'shortName': 'Cafeteria',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd000909854d13a550cf74d-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53211558498e26c70e0d14ca',
#        'name': 'Kow Loon Hong Kong Tim Sum 九龍香港點心 (Kow Loon Hong Kong Tim Sum)',
#        'location': {'address': '151 Ang Mo Kio Ave 5 #01-3030',
#         'lat': 1.3769554382899518,
#         'lng': 103.84080400448265,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3769554382899518,
#           'lng': 103.84080400448265}],
#         'distance': 377,
#         'postalCode': '560151',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['151 Ang Mo Kio Ave 5 #01-3030',
#          '560151',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1f5931735',
#          'name': 'Dim Sum Restaurant',
#          'pluralName': 'Dim Sum Restaurants',
#          'shortName': 'Dim Sum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53211558498e26c70e0d14ca-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b36ee37f964a520583e25e3',
#        'name': 'Selera Rasa Nasi Lemak',
#        'location': {'address': '603 Ang Mo Kio Ave 5',
#         'lat': 1.3806003520586858,
#         'lng': 103.83582031400658,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3806003520586858,
#           'lng': 103.83582031400658}],
#         'distance': 700,
#         'postalCode': '560603',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['603 Ang Mo Kio Ave 5', '560603', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d156941735',
#          'name': 'Malay Restaurant',
#          'pluralName': 'Malay Restaurants',
#          'shortName': 'Malay',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/malaysian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b36ee37f964a520583e25e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a06701904d1ae7351306b66',
#        'name': 'Burger King (KBCC)',
#        'location': {'address': 'Ang Mo Kio Ave 4',
#         'crossStreet': 'Kebun Baru Community Centre',
#         'lat': 1.373285,
#         'lng': 103.837259,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.373285,
#           'lng': 103.837259}],
#         'distance': 929,
#         'postalCode': '569897',
#         'cc': 'SG',
#         'city': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['Ang Mo Kio Ave 4 (Kebun Baru Community Centre)',
#          '569897',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a06701904d1ae7351306b66-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc988dab6c49c743e988e91',
#        'name': 'Hong Kong Street Zhen Ji 香港街珍记',
#        'location': {'address': '158 Ang Mo Kio Ave 4',
#         'lat': 1.3747420259391867,
#         'lng': 103.83890581354501,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3747420259391867,
#           'lng': 103.83890581354501}],
#         'distance': 693,
#         'postalCode': '560158',
#         'cc': 'SG',
#         'city': 'Ang Mo Kio',
#         'country': 'Singapore',
#         'formattedAddress': ['158 Ang Mo Kio Ave 4', '560158', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc988dab6c49c743e988e91-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d5f615d29ef236a95729859',
#        'name': '日本村 @ Yio Chu Kang',
#        'location': {'lat': 1.3829724979068831,
#         'lng': 103.84607874558353,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3829724979068831,
#           'lng': 103.84607874558353}],
#         'distance': 546,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d5f615d29ef236a95729859-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5302dfe0498e095dbc2f2964',
#        'name': 'Toshiba TEC Singapore Cafe',
#        'location': {'address': '2 Ang Mo Kio Street 62',
#         'lat': 1.384180432392154,
#         'lng': 103.8469576601468,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.384180432392154,
#           'lng': 103.8469576601468}],
#         'distance': 706,
#         'postalCode': '569138',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['2 Ang Mo Kio Street 62', '569138', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d128941735',
#          'name': 'Cafeteria',
#          'pluralName': 'Cafeterias',
#          'shortName': 'Cafeteria',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5302dfe0498e095dbc2f2964-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cc6521401fb236a93cdb6ba',
#        'name': 'Ang Mo Kio Bus Depot (SMRT Buses)',
#        'location': {'address': '6 Ang Mo Kio St 62',
#         'lat': 1.385640905963696,
#         'lng': 103.84617499113082,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.385640905963696,
#           'lng': 103.84617499113082}],
#         'distance': 766,
#         'postalCode': '569140',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['6 Ang Mo Kio St 62', '569140', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cc6521401fb236a93cdb6ba-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7b5e31f964a52048602fe3',
#        'name': 'SBS Transit East District (Ang Mo Kio Depot)',
#        'location': {'address': '15 Ang Mo Kio St 63',
#         'lat': 1.3857729994717414,
#         'lng': 103.84719371795654,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3857729994717414,
#           'lng': 103.84719371795654}],
#         'distance': 849,
#         'postalCode': '569117',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['15 Ang Mo Kio St 63', '569117', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7b5e31f964a52048602fe3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd8dab553a7f04db1756516',
#        'name': 'NYP Swimming Pool',
#        'location': {'address': '180 Ang Mo Kio Avenue 8',
#         'lat': 1.3832495319060862,
#         'lng': 103.8496002447278,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3832495319060862,
#           'lng': 103.8496002447278}],
#         'distance': 906,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['180 Ang Mo Kio Avenue 8', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d15e941735',
#          'name': 'Pool',
#          'pluralName': 'Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd8dab553a7f04db1756516-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cbfbf1cacd48cfa55ed453f',
#        'name': 'NCS Cafeteria @ B6',
#        'location': {'lat': 1.3882589244124053,
#         'lng': 103.84416026524572,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.3882589244124053,
#           'lng': 103.84416026524572}],
#         'distance': 937,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cbfbf1cacd48cfa55ed453f-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf8593901568cfad8ad1fe7',
#        'name': 'Bus Stop 55221 (Opp SMRT Buses AMK Depot)',
#        'location': {'address': 'Ang Mo Kio St 64',
#         'lat': 1.387853783998446,
#         'lng': 103.84627103805542,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.387853783998446,
#           'lng': 103.84627103805542}],
#         'distance': 980,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Ang Mo Kio St 64', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf8593901568cfad8ad1fe7-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d930d7952ed224be18d13ac',
#        'name': 'Double Delight',
#        'location': {'lat': 1.375117,
#         'lng': 103.849534,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.375117,
#           'lng': 103.849534}],
#         'distance': 995,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d930d7952ed224be18d13ac-38'}]}]}}

# %%
#function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list=row['categories']
    except:
        categories_list=row['venue.categories']
    
    if len(categories_list)==0:
        return None
    else:
        return categories_list[0]['name']

# %%
#Cleaning the json and structuring it into a Pandas DataFrame
venues = results['response']['groups'][0]['items']

#flatten json
nearby_venues = pd.json_normalize(venues)
                       
#filter columns
filtered_columns=['venue.name','venue.categories','venue.location.lat','venue.location.lng']
nearby_venues=nearby_venues.loc[:,filtered_columns]

#filter category for each row
nearby_venues['venue.categories']=nearby_venues.apply(get_category_type, axis=1)
                           
#clean columns
nearby_venues.columns=[col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head(200)
# Out:
#                                                  name  \
# 0                                   Prodigal Roasters
# 1                            Ho-Ree Roasted Food 好味烧腊
# 2                       Vegetarian @ 630 AMK Kopitiam
# 3                         Ang Mo Kio Town Garden West
# 4                               Shanghai Ren Jia 上海人家
# 5                           Mr Teh Tarik Eating House
# 6                                      Sumo Big Prawn
# 7                         Charcos The Flaming Chicken
# 8                      Nanyang Polytechnic Auditorium
# 9                                        Mr Teh Tarik
# 10                         Soi 19 十九街 Thai Wanton Mee
# 11              Yio Chu Kang Squash And Tennis Center
# 12                            Liang Seng Huat Pte Ltd
# 13                                             Subway
# 14                                McDonald's / McCafé
# 15                     Mayflower Market & Food Centre
# 16                                           7-Eleven
# 17                                        Foodgle Hub
# 18                                   Coffee Sense 咖啡鄉
# 19                                             Courts
# 20                          Yio Chu Kang ClubFITT Gym
# 21                                    Angel Supermart
# 22                                Broadway Coffeeshop
# 23                      Yio Chu Kang Swimming Complex
# 24                           Bus Stop 55139 (Blk 641)
# 25                                         McDonald's
# 26                                      South Canteen
# 27  Kow Loon Hong Kong Tim Sum 九龍香港點心 (Kow Loon Ho...
# 28                             Selera Rasa Nasi Lemak
# 29                                 Burger King (KBCC)
# 30                     Hong Kong Street Zhen Ji 香港街珍记
# 31                                 日本村 @ Yio Chu Kang
# 32                         Toshiba TEC Singapore Cafe
# 33                  Ang Mo Kio Bus Depot (SMRT Buses)
# 34       SBS Transit East District (Ang Mo Kio Depot)
# 35                                  NYP Swimming Pool
# 36                                 NCS Cafeteria @ B6
# 37          Bus Stop 55221 (Opp SMRT Buses AMK Depot)
# 38                                     Double Delight
#
#                        categories       lat         lng
# 0                     Coffee Shop  1.382212  103.841347
# 1              Chinese Restaurant  1.381160  103.840977
# 2   Vegetarian / Vegan Restaurant  1.380721  103.841327
# 3                            Park  1.376039  103.844528
# 4             Shanghai Restaurant  1.377068  103.841329
# 5                      Food Court  1.378458  103.836685
# 6                    Noodle House  1.381121  103.840778
# 7           Australian Restaurant  1.378220  103.836871
# 8              College Auditorium  1.380186  103.848298
# 9                Halal Restaurant  1.372168  103.845602
# 10                Thai Restaurant  1.377004  103.840706
# 11                   Tennis Court  1.382391  103.845789
# 12                     Food Court  1.379759  103.841751
# 13           Fast Food Restaurant  1.380691  103.849113
# 14           Fast Food Restaurant  1.372462  103.844980
# 15                     Food Court  1.374051  103.838879
# 16              Convenience Store  1.381651  103.844511
# 17                     Food Court  1.376890  103.849313
# 18                     Food Court  1.377207  103.837049
# 19              Electronics Store  1.373486  103.846070
# 20           Gym / Fitness Center  1.382338  103.845994
# 21              Convenience Store  1.379397  103.840816
# 22                     Food Court  1.373072  103.846393
# 23                           Pool  1.381703  103.846884
# 24                    Bus Station  1.378921  103.839944
# 25           Fast Food Restaurant  1.373651  103.837496
# 26              College Cafeteria  1.378085  103.849480
# 27             Dim Sum Restaurant  1.376955  103.840804
# 28               Malay Restaurant  1.380600  103.835820
# 29           Fast Food Restaurant  1.373285  103.837259
# 30             Chinese Restaurant  1.374742  103.838906
# 31            Japanese Restaurant  1.382972  103.846079
# 32                      Cafeteria  1.384180  103.846958
# 33                    Bus Station  1.385641  103.846175
# 34                    Bus Station  1.385773  103.847194
# 35                           Pool  1.383250  103.849600
# 36                     Food Court  1.388259  103.844160
# 37                    Bus Station  1.387854  103.846271
# 38                   Dessert Shop  1.375117  103.849534

# %%
#create 3 additional columns to indicate respective planning area and its longitude and latitude
amk=nearby_venues.assign(planning_area='ANG MO KIO',
                           area_latitude=latitude,
                           area_longitude=longitude)

# %%
#Repositioning the columns and renaming the column names

amk=amk[['planning_area','area_latitude','area_longitude','name','lat','lng','categories']]
amk.rename(columns={'name':'venue_name',
            'lat':'venue_latitude',
             'lng':'venue_longitude',
             'categories':'venue_categories'}, inplace=True)

# %%
#check data
amk
# Out:
#    planning_area  area_latitude  area_longitude  \
# 0     ANG MO KIO       1.380092      103.842097
# 1     ANG MO KIO       1.380092      103.842097
# 2     ANG MO KIO       1.380092      103.842097
# 3     ANG MO KIO       1.380092      103.842097
# 4     ANG MO KIO       1.380092      103.842097
# 5     ANG MO KIO       1.380092      103.842097
# 6     ANG MO KIO       1.380092      103.842097
# 7     ANG MO KIO       1.380092      103.842097
# 8     ANG MO KIO       1.380092      103.842097
# 9     ANG MO KIO       1.380092      103.842097
# 10    ANG MO KIO       1.380092      103.842097
# 11    ANG MO KIO       1.380092      103.842097
# 12    ANG MO KIO       1.380092      103.842097
# 13    ANG MO KIO       1.380092      103.842097
# 14    ANG MO KIO       1.380092      103.842097
# 15    ANG MO KIO       1.380092      103.842097
# 16    ANG MO KIO       1.380092      103.842097
# 17    ANG MO KIO       1.380092      103.842097
# 18    ANG MO KIO       1.380092      103.842097
# 19    ANG MO KIO       1.380092      103.842097
# 20    ANG MO KIO       1.380092      103.842097
# 21    ANG MO KIO       1.380092      103.842097
# 22    ANG MO KIO       1.380092      103.842097
# 23    ANG MO KIO       1.380092      103.842097
# 24    ANG MO KIO       1.380092      103.842097
# 25    ANG MO KIO       1.380092      103.842097
# 26    ANG MO KIO       1.380092      103.842097
# 27    ANG MO KIO       1.380092      103.842097
# 28    ANG MO KIO       1.380092      103.842097
# 29    ANG MO KIO       1.380092      103.842097
# 30    ANG MO KIO       1.380092      103.842097
# 31    ANG MO KIO       1.380092      103.842097
# 32    ANG MO KIO       1.380092      103.842097
# 33    ANG MO KIO       1.380092      103.842097
# 34    ANG MO KIO       1.380092      103.842097
# 35    ANG MO KIO       1.380092      103.842097
# 36    ANG MO KIO       1.380092      103.842097
# 37    ANG MO KIO       1.380092      103.842097
# 38    ANG MO KIO       1.380092      103.842097
#
#                                            venue_name  venue_latitude  \
# 0                                   Prodigal Roasters        1.382212
# 1                            Ho-Ree Roasted Food 好味烧腊        1.381160
# 2                       Vegetarian @ 630 AMK Kopitiam        1.380721
# 3                         Ang Mo Kio Town Garden West        1.376039
# 4                               Shanghai Ren Jia 上海人家        1.377068
# 5                           Mr Teh Tarik Eating House        1.378458
# 6                                      Sumo Big Prawn        1.381121
# 7                         Charcos The Flaming Chicken        1.378220
# 8                      Nanyang Polytechnic Auditorium        1.380186
# 9                                        Mr Teh Tarik        1.372168
# 10                         Soi 19 十九街 Thai Wanton Mee        1.377004
# 11              Yio Chu Kang Squash And Tennis Center        1.382391
# 12                            Liang Seng Huat Pte Ltd        1.379759
# 13                                             Subway        1.380691
# 14                                McDonald's / McCafé        1.372462
# 15                     Mayflower Market & Food Centre        1.374051
# 16                                           7-Eleven        1.381651
# 17                                        Foodgle Hub        1.376890
# 18                                   Coffee Sense 咖啡鄉        1.377207
# 19                                             Courts        1.373486
# 20                          Yio Chu Kang ClubFITT Gym        1.382338
# 21                                    Angel Supermart        1.379397
# 22                                Broadway Coffeeshop        1.373072
# 23                      Yio Chu Kang Swimming Complex        1.381703
# 24                           Bus Stop 55139 (Blk 641)        1.378921
# 25                                         McDonald's        1.373651
# 26                                      South Canteen        1.378085
# 27  Kow Loon Hong Kong Tim Sum 九龍香港點心 (Kow Loon Ho...        1.376955
# 28                             Selera Rasa Nasi Lemak        1.380600
# 29                                 Burger King (KBCC)        1.373285
# 30                     Hong Kong Street Zhen Ji 香港街珍记        1.374742
# 31                                 日本村 @ Yio Chu Kang        1.382972
# 32                         Toshiba TEC Singapore Cafe        1.384180
# 33                  Ang Mo Kio Bus Depot (SMRT Buses)        1.385641
# 34       SBS Transit East District (Ang Mo Kio Depot)        1.385773
# 35                                  NYP Swimming Pool        1.383250
# 36                                 NCS Cafeteria @ B6        1.388259
# 37          Bus Stop 55221 (Opp SMRT Buses AMK Depot)        1.387854
# 38                                     Double Delight        1.375117
#
#     venue_longitude               venue_categories
# 0        103.841347                    Coffee Shop
# 1        103.840977             Chinese Restaurant
# 2        103.841327  Vegetarian / Vegan Restaurant
# 3        103.844528                           Park
# 4        103.841329            Shanghai Restaurant
# 5        103.836685                     Food Court
# 6        103.840778                   Noodle House
# 7        103.836871          Australian Restaurant
# 8        103.848298             College Auditorium
# 9        103.845602               Halal Restaurant
# 10       103.840706                Thai Restaurant
# 11       103.845789                   Tennis Court
# 12       103.841751                     Food Court
# 13       103.849113           Fast Food Restaurant
# 14       103.844980           Fast Food Restaurant
# 15       103.838879                     Food Court
# 16       103.844511              Convenience Store
# 17       103.849313                     Food Court
# 18       103.837049                     Food Court
# 19       103.846070              Electronics Store
# 20       103.845994           Gym / Fitness Center
# 21       103.840816              Convenience Store
# 22       103.846393                     Food Court
# 23       103.846884                           Pool
# 24       103.839944                    Bus Station
# 25       103.837496           Fast Food Restaurant
# 26       103.849480              College Cafeteria
# 27       103.840804             Dim Sum Restaurant
# 28       103.835820               Malay Restaurant
# 29       103.837259           Fast Food Restaurant
# 30       103.838906             Chinese Restaurant
# 31       103.846079            Japanese Restaurant
# 32       103.846958                      Cafeteria
# 33       103.846175                    Bus Station
# 34       103.847194                    Bus Station
# 35       103.849600                           Pool
# 36       103.844160                     Food Court
# 37       103.846271                    Bus Station
# 38       103.849534                   Dessert Shop

# %%
amk.to_csv("amk.csv")

# %% [markdown]
# ## SEMBAWANG

# %%
# @hidden_cell
#Defining Foursquare credentials and version
CLIENT_ID='5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K'
CLIENT_SECRET='UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR'
VERSION='20180605'

# %%
#Create GET request url

latitude=semb.loc[0,'area_latitude']
longitude=semb.loc[0,'area_longitude']

LIMIT=200
radius=1000

url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
CLIENT_ID,
CLIENT_SECRET,
VERSION,
latitude,
longitude,
radius,
LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K&client_secret=UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR&v=20180605&ll=1.4557470456642672,103.818827683365&radius=1000&limit=200'

# %%
#send GET request url and examine results
results=requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '613da917655c20456e56b3b3'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Sembawang',
#   'headerFullLocation': 'Sembawang, Singapore',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 31,
#   'suggestedBounds': {'ne': {'lat': 1.4647470546642762,
#     'lng': 103.82781378863032},
#    'sw': {'lat': 1.446747036664258, 'lng': 103.80984157809968}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '567d4285498ef1df28cfb57b',
#        'name': 'Starbucks',
#        'location': {'address': '#01-22, Sun Plaza',
#         'crossStreet': '30 Sembawang Drive',
#         'lat': 1.4481281132935184,
#         'lng': 103.81965198217407,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4481281132935184,
#           'lng': 103.81965198217407}],
#         'distance': 853,
#         'postalCode': '757713',
#         'cc': 'SG',
#         'city': 'Sembawang Estate',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-22, Sun Plaza (30 Sembawang Drive)',
#          '757713',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-567d4285498ef1df28cfb57b-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55a645e2498e6c54786f5cc3',
#        'name': "McDonald's",
#        'location': {'address': '#01-16 /17 Sun Plaza',
#         'crossStreet': '30 Sembawang Drive',
#         'lat': 1.4485522814289518,
#         'lng': 103.81992740654019,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4485522814289518,
#           'lng': 103.81992740654019}],
#         'distance': 810,
#         'postalCode': '757713',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-16 /17 Sun Plaza (30 Sembawang Drive)',
#          '757713',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55a645e2498e6c54786f5cc3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '565ddb0a498e5dbdf2a66b09',
#        'name': 'White Restaurant',
#        'location': {'address': '#03-16, Sun Plaza',
#         'crossStreet': '30 Sembawang Drive',
#         'lat': 1.4484677257620298,
#         'lng': 103.81986930816716,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4484677257620298,
#           'lng': 103.81986930816716}],
#         'distance': 818,
#         'postalCode': '757713',
#         'cc': 'SG',
#         'neighborhood': 'Sembawang',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#03-16, Sun Plaza (30 Sembawang Drive)',
#          '757713',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-565ddb0a498e5dbdf2a66b09-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52763051498e2ba9ba738c00',
#        'name': 'Happy Hawkers Coffee Shop',
#        'location': {'address': '406A Sembawang Drive',
#         'lat': 1.452428714108723,
#         'lng': 103.81692104575298,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.452428714108723,
#           'lng': 103.81692104575298}],
#         'distance': 425,
#         'cc': 'SG',
#         'neighborhood': 'Sembawang',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['406A Sembawang Drive', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52763051498e2ba9ba738c00-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5597b0cc498ef6c957d5529b',
#        'name': "Swensen's",
#        'location': {'address': '#02-21/22 Sun Plaza',
#         'crossStreet': '30 Sembawang Drive',
#         'lat': 1.448177166719735,
#         'lng': 103.8194713549583,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.448177166719735,
#           'lng': 103.8194713549583}],
#         'distance': 845,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-21/22 Sun Plaza (30 Sembawang Drive)',
#          'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f1',
#          'name': 'Bistro',
#          'pluralName': 'Bistros',
#          'shortName': 'Bistro',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5597b0cc498ef6c957d5529b-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7f5eecf964a520a02a30e3',
#        'name': 'NTUC FairPrice',
#        'location': {'address': '#B1-01/02, Sun Plaza',
#         'crossStreet': '30 Sembawang Dr',
#         'lat': 1.448071168837641,
#         'lng': 103.81941928535086,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.448071168837641,
#           'lng': 103.81941928535086}],
#         'distance': 857,
#         'postalCode': '757713',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-01/02, Sun Plaza (30 Sembawang Dr)',
#          '757713',
#          'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7f5eecf964a520a02a30e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2d4abe260bc9282bd919d3',
#        'name': 'Bus Stop 58121 (Blk 424A Car Park)',
#        'location': {'address': 'Canberra Rd.',
#         'lat': 1.4533384959161786,
#         'lng': 103.81954686198895,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4533384959161786,
#           'lng': 103.81954686198895}],
#         'distance': 279,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Canberra Rd.', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2d4abe260bc9282bd919d3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7a7fe9f964a520de2e2fe3',
#        'name': 'Ya Kun Kaya Toast 亞坤',
#        'location': {'address': 'Sun Plaza',
#         'crossStreet': '30 Sembawang Drive',
#         'lat': 1.4481281417510359,
#         'lng': 103.81944098706671,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4481281417510359,
#           'lng': 103.81944098706671}],
#         'distance': 850,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Sun Plaza (30 Sembawang Drive)', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b7a7fe9f964a520de2e2fe3-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '572c2d7d498e05a2d47b33c5',
#        'name': 'Chang Cheng Mee Wah',
#        'location': {'address': '27 Woodlands Link',
#         'lat': 1.4522474934935585,
#         'lng': 103.81119181808205,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4522474934935585,
#           'lng': 103.81119181808205}],
#         'distance': 934,
#         'postalCode': '738732',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['27 Woodlands Link', '738732', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-572c2d7d498e05a2d47b33c5-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54dc62f1498e5eff7d8517f8',
#        'name': 'Sushi Express',
#        'location': {'address': 'Sun Plaza',
#         'lat': 1.4481183960933321,
#         'lng': 103.81934801161154,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4481183960933321,
#           'lng': 103.81934801161154}],
#         'distance': 851,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Sun Plaza', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54dc62f1498e5eff7d8517f8-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba74f6cf964a520f08a39e3',
#        'name': 'KFC',
#        'location': {'address': '#01-25 Sun Plaza',
#         'crossStreet': '30 Sembawang Dr.',
#         'lat': 1.447949625982657,
#         'lng': 103.81897128353275,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.447949625982657,
#           'lng': 103.81897128353275}],
#         'distance': 868,
#         'postalCode': '757713',
#         'cc': 'SG',
#         'city': 'Sembawang Estate',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-25 Sun Plaza (30 Sembawang Dr.)',
#          '757713',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba74f6cf964a520f08a39e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5613d109498edcf85f4c2d8c',
#        'name': 'Bar 3O1 Kitchen',
#        'location': {'address': 'NS Home Team',
#         'lat': 1.458153200176274,
#         'lng': 103.82172006047215,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.458153200176274,
#           'lng': 103.82172006047215}],
#         'distance': 418,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['NS Home Team', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5613d109498edcf85f4c2d8c-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4eb67b5a0cd688257845ffe4',
#        'name': 'Seafood Kampong',
#        'location': {'address': 'HomeTeamNS @ Sembawang',
#         'crossStreet': '301 Canberra Rd',
#         'lat': 1.4586744281556323,
#         'lng': 103.8219165802002,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4586744281556323,
#           'lng': 103.8219165802002}],
#         'distance': 473,
#         'postalCode': '759774',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['HomeTeamNS @ Sembawang (301 Canberra Rd)',
#          '759774',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'shortName': 'Seafood',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4eb67b5a0cd688257845ffe4-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '587878e76b0cdb090262b267',
#        'name': 'D.U.I.T',
#        'location': {'lat': 1.458609026990441,
#         'lng': 103.82196800329818,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.458609026990441,
#           'lng': 103.82196800329818}],
#         'distance': 472,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f4',
#          'name': 'Buffet',
#          'pluralName': 'Buffets',
#          'shortName': 'Buffet',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-587878e76b0cdb090262b267-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '584e9fc46ad73d598e06313f',
#        'name': '8 darts',
#        'location': {'lat': 1.4591471452767546,
#         'lng': 103.82168736806939,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4591471452767546,
#           'lng': 103.82168736806939}],
#         'distance': 494,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '5744ccdfe4b0c0459246b4b5',
#          'name': 'Indoor Play Area',
#          'pluralName': 'Indoor Play Areas',
#          'shortName': 'Indoor Play Area',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-584e9fc46ad73d598e06313f-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57caeddb498ecc39c6153e93',
#        'name': 'Hai Bin Prawning',
#        'location': {'lat': 1.4591025403402493,
#         'lng': 103.82175997919374,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4591025403402493,
#           'lng': 103.82175997919374}],
#         'distance': 495,
#         'postalCode': '759955',
#         'cc': 'SG',
#         'city': 'Sembawang Estate',
#         'country': 'Singapore',
#         'formattedAddress': ['759955', 'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a0f',
#          'name': 'Fishing Spot',
#          'pluralName': 'Fishing Spots',
#          'shortName': 'Fishing Spot',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_fishmarket_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57caeddb498ecc39c6153e93-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf0741d1c158cfade50cab5',
#        'name': 'Phan Nee Supermart',
#        'location': {'lat': 1.460799214536491,
#         'lng': 103.81916664022829,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.460799214536491,
#           'lng': 103.81916664022829}],
#         'distance': 563,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'shortName': 'Grocery Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf0741d1c158cfade50cab5-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b058816f964a5201fb122e3',
#        'name': 'Sun Plaza',
#        'location': {'address': '30 Sembawang Dr',
#         'crossStreet': 'next to Sembawang MRT',
#         'lat': 1.448386577730186,
#         'lng': 103.81974966033243,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.448386577730186,
#           'lng': 103.81974966033243}],
#         'distance': 825,
#         'postalCode': '757713',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['30 Sembawang Dr (next to Sembawang MRT)',
#          '757713',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b058816f964a5201fb122e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf627bc9abec9b64a6b25e8',
#        'name': 'Blk 358 Admiralty Drive Playground',
#        'location': {'address': '358 Admiralty Drive',
#         'crossStreet': 'Sun Bliss',
#         'lat': 1.449478515781803,
#         'lng': 103.8159063022572,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.449478515781803,
#           'lng': 103.8159063022572}],
#         'distance': 769,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['358 Admiralty Drive (Sun Bliss)', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf627bc9abec9b64a6b25e8-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59071070eacf4521f0a3b350',
#        'name': 'Pot Addiction International Steamboat And BBQ Buffet',
#        'location': {'address': '#02-14 Sun Plaza',
#         'crossStreet': '30 Sembawang Drive',
#         'lat': 1.4484153,
#         'lng': 103.81987,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4484153,
#           'lng': 103.81987}],
#         'distance': 824,
#         'postalCode': '757713',
#         'cc': 'SG',
#         'neighborhood': 'Sembawang',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-14 Sun Plaza (30 Sembawang Drive)',
#          '757713',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59071070eacf4521f0a3b350-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf35f5ac9af6dcbcec4a57f',
#        'name': 'Super Sundries Minimart',
#        'location': {'address': 'Admiralty road west',
#         'lat': 1.461045,
#         'lng': 103.824056,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.461045,
#           'lng': 103.824056}],
#         'distance': 828,
#         'postalCode': '759956',
#         'cc': 'SG',
#         'state': 'Sg',
#         'country': 'Singapore',
#         'formattedAddress': ['Admiralty road west', '759956', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1f6941735',
#          'name': 'Department Store',
#          'pluralName': 'Department Stores',
#          'shortName': 'Department Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf35f5ac9af6dcbcec4a57f-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c25bdf4905a0f4756156260',
#        'name': 'Watsons',
#        'location': {'address': '#B1-17/18, Sun Plaza',
#         'crossStreet': '30 Sembawang Drive',
#         'lat': 1.4480522613400126,
#         'lng': 103.81926852705568,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4480522613400126,
#           'lng': 103.81926852705568}],
#         'distance': 857,
#         'postalCode': '757713',
#         'cc': 'SG',
#         'neighborhood': 'semb',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#B1-17/18, Sun Plaza (30 Sembawang Drive)',
#          '757713',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'shortName': 'Pharmacy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c25bdf4905a0f4756156260-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55029948498e5a08746c289e',
#        'name': 'Toast Box 土司工坊',
#        'location': {'address': '#01-01 Sun Plaza, 30 Sembawang Dr. Singapore',
#         'lat': 1.4480212647990534,
#         'lng': 103.8189674197214,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4480212647990534,
#           'lng': 103.8189674197214}],
#         'distance': 860,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01 Sun Plaza, 30 Sembawang Dr. Singapore',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55029948498e5a08746c289e-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dd90202fa76ad96d14ad988',
#        'name': 'Edo Sushi',
#        'location': {'address': 'Sun Plaza #01-35',
#         'lat': 1.4480321501049274,
#         'lng': 103.81949494250227,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4480321501049274,
#           'lng': 103.81949494250227}],
#         'distance': 862,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Sun Plaza #01-35', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dd90202fa76ad96d14ad988-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf3c882899c6ea80c5efdc1',
#        'name': 'Mac@Sembawang',
#        'location': {'lat': 1.4498830437877883,
#         'lng': 103.82405375662006,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4498830437877883,
#           'lng': 103.82405375662006}],
#         'distance': 874,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf3c882899c6ea80c5efdc1-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d831a0c02eb54813ebf12f5',
#        'name': 'Sun Plaza Smoking Area',
#        'location': {'address': '30 Sembawang Drive',
#         'lat': 1.4478734106631226,
#         'lng': 103.81929116858329,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4478734106631226,
#           'lng': 103.81929116858329}],
#         'distance': 878,
#         'postalCode': '757713',
#         'cc': 'SG',
#         'city': 'Sembawang Estate',
#         'country': 'Singapore',
#         'formattedAddress': ['30 Sembawang Drive', '757713', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d123951735',
#          'name': 'Smoke Shop',
#          'pluralName': 'Smoke Shops',
#          'shortName': 'Smoke Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/tobacco_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d831a0c02eb54813ebf12f5-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d4269828b88b1f74415eb33',
#        'name': 'Patricia Schulte',
#        'location': {'address': 'Sembawang Shipyard',
#         'lat': 1.4623808175712685,
#         'lng': 103.82317424658915,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4623808175712685,
#           'lng': 103.82317424658915}],
#         'distance': 882,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Sembawang Shipyard', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d12d951735',
#          'name': 'Boat or Ferry',
#          'pluralName': 'Boats or Ferries',
#          'shortName': 'Boat / Ferry',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/boat_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d4269828b88b1f74415eb33-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f83e373e4b0422a01082f4b',
#        'name': 'Spicy Cafe',
#        'location': {'address': 'Sun Plaza',
#         'lat': 1.4477882864609743,
#         'lng': 103.81901579126993,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4477882864609743,
#           'lng': 103.81901579126993}],
#         'distance': 886,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Sun Plaza', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d156941735',
#          'name': 'Malay Restaurant',
#          'pluralName': 'Malay Restaurants',
#          'shortName': 'Malay',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/malaysian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f83e373e4b0422a01082f4b-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9c58bff964a520806136e3',
#        'name': 'Sembawang Shipyard',
#        'location': {'address': 'Admiralty Rd W',
#         'lat': 1.4622314679773805,
#         'lng': 103.8234459530093,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4622314679773805,
#           'lng': 103.8234459530093}],
#         'distance': 886,
#         'postalCode': '759956',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Admiralty Rd W', '759956', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d130941735',
#          'name': 'Building',
#          'pluralName': 'Buildings',
#          'shortName': 'Building',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9c58bff964a520806136e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c946fa601dd76b0911fb748',
#        'name': 'Bus Stop 58361 (North Link Bldg)',
#        'location': {'address': 'Admiralty Street',
#         'lat': 1.4614164999119503,
#         'lng': 103.81314996462771,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4614164999119503,
#           'lng': 103.81314996462771}],
#         'distance': 893,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Admiralty Street', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c946fa601dd76b0911fb748-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d8991bb4757721e3cb4a469',
#        'name': 'Sembawang Shipyard @ Super Floating Dock',
#        'location': {'lat': 1.4634902471599014,
#         'lng': 103.82288555911508,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.4634902471599014,
#           'lng': 103.82288555911508}],
#         'distance': 973,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0941735',
#          'name': 'Harbor / Marina',
#          'pluralName': 'Harbors / Marinas',
#          'shortName': 'Harbor / Marina',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/harbor_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d8991bb4757721e3cb4a469-30'}]}]}}

# %%
#function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list=row['categories']
    except:
        categories_list=row['venue.categories']
    
    if len(categories_list)==0:
        return None
    else:
        return categories_list[0]['name']

# %%
#Cleaning the json and structuring it into a Pandas DataFrame
venues = results['response']['groups'][0]['items']

#flatten json
nearby_venues = pd.json_normalize(venues)
                       
#filter columns
filtered_columns=['venue.name','venue.categories','venue.location.lat','venue.location.lng']
nearby_venues=nearby_venues.loc[:,filtered_columns]

#filter category for each row
nearby_venues['venue.categories']=nearby_venues.apply(get_category_type, axis=1)
                           
#clean columns
nearby_venues.columns=[col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head(200)
# Out:
#                                                  name            categories  \
# 0                                           Starbucks           Coffee Shop
# 1                                          McDonald's  Fast Food Restaurant
# 2                                    White Restaurant    Chinese Restaurant
# 3                           Happy Hawkers Coffee Shop            Food Court
# 4                                           Swensen's                Bistro
# 5                                      NTUC FairPrice           Supermarket
# 6                  Bus Stop 58121 (Blk 424A Car Park)           Bus Station
# 7                                Ya Kun Kaya Toast 亞坤           Coffee Shop
# 8                                 Chang Cheng Mee Wah            Food Court
# 9                                       Sushi Express   Japanese Restaurant
# 10                                                KFC  Fast Food Restaurant
# 11                                    Bar 3O1 Kitchen                   Bar
# 12                                    Seafood Kampong    Seafood Restaurant
# 13                                            D.U.I.T                Buffet
# 14                                            8 darts      Indoor Play Area
# 15                                   Hai Bin Prawning          Fishing Spot
# 16                                 Phan Nee Supermart         Grocery Store
# 17                                          Sun Plaza         Shopping Mall
# 18                 Blk 358 Admiralty Drive Playground            Playground
# 19  Pot Addiction International Steamboat And BBQ ...             BBQ Joint
# 20                            Super Sundries Minimart      Department Store
# 21                                            Watsons              Pharmacy
# 22                                     Toast Box 土司工坊           Coffee Shop
# 23                                          Edo Sushi      Sushi Restaurant
# 24                                      Mac@Sembawang  Fast Food Restaurant
# 25                             Sun Plaza Smoking Area            Smoke Shop
# 26                                   Patricia Schulte         Boat or Ferry
# 27                                         Spicy Cafe      Malay Restaurant
# 28                                 Sembawang Shipyard              Building
# 29                   Bus Stop 58361 (North Link Bldg)           Bus Station
# 30           Sembawang Shipyard @ Super Floating Dock       Harbor / Marina
#
#          lat         lng
# 0   1.448128  103.819652
# 1   1.448552  103.819927
# 2   1.448468  103.819869
# 3   1.452429  103.816921
# 4   1.448177  103.819471
# 5   1.448071  103.819419
# 6   1.453338  103.819547
# 7   1.448128  103.819441
# 8   1.452247  103.811192
# 9   1.448118  103.819348
# 10  1.447950  103.818971
# 11  1.458153  103.821720
# 12  1.458674  103.821917
# 13  1.458609  103.821968
# 14  1.459147  103.821687
# 15  1.459103  103.821760
# 16  1.460799  103.819167
# 17  1.448387  103.819750
# 18  1.449479  103.815906
# 19  1.448415  103.819870
# 20  1.461045  103.824056
# 21  1.448052  103.819269
# 22  1.448021  103.818967
# 23  1.448032  103.819495
# 24  1.449883  103.824054
# 25  1.447873  103.819291
# 26  1.462381  103.823174
# 27  1.447788  103.819016
# 28  1.462231  103.823446
# 29  1.461416  103.813150
# 30  1.463490  103.822886

# %%
#create 3 additional columns to indicate respective planning area and its longitude and latitude
semb=nearby_venues.assign(planning_area='SEMBAWANG',
                           area_latitude=latitude,
                           area_longitude=longitude)

# %%
#Repositioning the columns and renaming the column names

semb=semb[['planning_area','area_latitude','area_longitude','name','lat','lng','categories']]
semb.rename(columns={'name':'venue_name',
            'lat':'venue_latitude',
             'lng':'venue_longitude',
             'categories':'venue_categories'}, inplace=True)

# %%
#check data
semb
# Out:
#    planning_area  area_latitude  area_longitude  \
# 0      SEMBAWANG       1.455747      103.818828
# 1      SEMBAWANG       1.455747      103.818828
# 2      SEMBAWANG       1.455747      103.818828
# 3      SEMBAWANG       1.455747      103.818828
# 4      SEMBAWANG       1.455747      103.818828
# 5      SEMBAWANG       1.455747      103.818828
# 6      SEMBAWANG       1.455747      103.818828
# 7      SEMBAWANG       1.455747      103.818828
# 8      SEMBAWANG       1.455747      103.818828
# 9      SEMBAWANG       1.455747      103.818828
# 10     SEMBAWANG       1.455747      103.818828
# 11     SEMBAWANG       1.455747      103.818828
# 12     SEMBAWANG       1.455747      103.818828
# 13     SEMBAWANG       1.455747      103.818828
# 14     SEMBAWANG       1.455747      103.818828
# 15     SEMBAWANG       1.455747      103.818828
# 16     SEMBAWANG       1.455747      103.818828
# 17     SEMBAWANG       1.455747      103.818828
# 18     SEMBAWANG       1.455747      103.818828
# 19     SEMBAWANG       1.455747      103.818828
# 20     SEMBAWANG       1.455747      103.818828
# 21     SEMBAWANG       1.455747      103.818828
# 22     SEMBAWANG       1.455747      103.818828
# 23     SEMBAWANG       1.455747      103.818828
# 24     SEMBAWANG       1.455747      103.818828
# 25     SEMBAWANG       1.455747      103.818828
# 26     SEMBAWANG       1.455747      103.818828
# 27     SEMBAWANG       1.455747      103.818828
# 28     SEMBAWANG       1.455747      103.818828
# 29     SEMBAWANG       1.455747      103.818828
# 30     SEMBAWANG       1.455747      103.818828
#
#                                            venue_name  venue_latitude  \
# 0                                           Starbucks        1.448128
# 1                                          McDonald's        1.448552
# 2                                    White Restaurant        1.448468
# 3                           Happy Hawkers Coffee Shop        1.452429
# 4                                           Swensen's        1.448177
# 5                                      NTUC FairPrice        1.448071
# 6                  Bus Stop 58121 (Blk 424A Car Park)        1.453338
# 7                                Ya Kun Kaya Toast 亞坤        1.448128
# 8                                 Chang Cheng Mee Wah        1.452247
# 9                                       Sushi Express        1.448118
# 10                                                KFC        1.447950
# 11                                    Bar 3O1 Kitchen        1.458153
# 12                                    Seafood Kampong        1.458674
# 13                                            D.U.I.T        1.458609
# 14                                            8 darts        1.459147
# 15                                   Hai Bin Prawning        1.459103
# 16                                 Phan Nee Supermart        1.460799
# 17                                          Sun Plaza        1.448387
# 18                 Blk 358 Admiralty Drive Playground        1.449479
# 19  Pot Addiction International Steamboat And BBQ ...        1.448415
# 20                            Super Sundries Minimart        1.461045
# 21                                            Watsons        1.448052
# 22                                     Toast Box 土司工坊        1.448021
# 23                                          Edo Sushi        1.448032
# 24                                      Mac@Sembawang        1.449883
# 25                             Sun Plaza Smoking Area        1.447873
# 26                                   Patricia Schulte        1.462381
# 27                                         Spicy Cafe        1.447788
# 28                                 Sembawang Shipyard        1.462231
# 29                   Bus Stop 58361 (North Link Bldg)        1.461416
# 30           Sembawang Shipyard @ Super Floating Dock        1.463490
#
#     venue_longitude      venue_categories
# 0        103.819652           Coffee Shop
# 1        103.819927  Fast Food Restaurant
# 2        103.819869    Chinese Restaurant
# 3        103.816921            Food Court
# 4        103.819471                Bistro
# 5        103.819419           Supermarket
# 6        103.819547           Bus Station
# 7        103.819441           Coffee Shop
# 8        103.811192            Food Court
# 9        103.819348   Japanese Restaurant
# 10       103.818971  Fast Food Restaurant
# 11       103.821720                   Bar
# 12       103.821917    Seafood Restaurant
# 13       103.821968                Buffet
# 14       103.821687      Indoor Play Area
# 15       103.821760          Fishing Spot
# 16       103.819167         Grocery Store
# 17       103.819750         Shopping Mall
# 18       103.815906            Playground
# 19       103.819870             BBQ Joint
# 20       103.824056      Department Store
# 21       103.819269              Pharmacy
# 22       103.818967           Coffee Shop
# 23       103.819495      Sushi Restaurant
# 24       103.824054  Fast Food Restaurant
# 25       103.819291            Smoke Shop
# 26       103.823174         Boat or Ferry
# 27       103.819016      Malay Restaurant
# 28       103.823446              Building
# 29       103.813150           Bus Station
# 30       103.822886       Harbor / Marina

# %%
semb.to_csv("semb.csv")

# %% [markdown]
# ## QUEENSTOWN

# %%
# @hidden_cell
#Defining Foursquare credentials and version
CLIENT_ID='5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K'
CLIENT_SECRET='UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR'
VERSION='20180605'

# %%
# Create GET request url
latitude=queenstown.loc[0,'area_latitude']
longitude=queenstown.loc[0,'area_longitude']

LIMIT=200
radius=1000

url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
CLIENT_ID,
CLIENT_SECRET,
VERSION,
latitude,
longitude,
radius,
LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=5GYCGVHIUVEFMT10VNQK1EHYW4XAJIILTGVWUATISPOTWQ3K&client_secret=UXNQUS20PDIZSMSXW1NMHZXC55XGYYG5IRUCYXHSAD4TXVSR&v=20180605&ll=1.289072870703827,103.78455889386018&radius=1000&limit=200'

# %%
#send GET request url and examine results
results=requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '613da9260265b55f8822c3b2'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Central Region',
#   'headerFullLocation': 'Central Region, Singapore',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 55,
#   'suggestedBounds': {'ne': {'lat': 1.2980728797038361,
#     'lng': 103.79354437287707},
#    'sw': {'lat': 1.280072861703818, 'lng': 103.7755734148433}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '598c60e5fd16bb0cfe4dbe3f',
#        'name': 'The Good Beer Company',
#        'location': {'address': '#01-23 Ascent',
#         'crossStreet': 'Savourworld',
#         'lat': 1.2917369090991357,
#         'lng': 103.78426632723797,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2917369090991357,
#           'lng': 103.78426632723797}],
#         'distance': 298,
#         'postalCode': '118222',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-23 Ascent (Savourworld)',
#          '118222',
#          'Singapore']},
#        'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#          'name': 'Beer Bar',
#          'pluralName': 'Beer Bars',
#          'shortName': 'Beer Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-598c60e5fd16bb0cfe4dbe3f-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb45af787aa9521e31aadd1',
#        'name': 'Starbucks',
#        'location': {'address': '#01-03, Cintech IV Singapore Science Park I',
#         'crossStreet': '79 Science Park Dr.',
#         'lat': 1.2896736622595828,
#         'lng': 103.78990812340253,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2896736622595828,
#           'lng': 103.78990812340253}],
#         'distance': 599,
#         'postalCode': '118264',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-03, Cintech IV Singapore Science Park I (79 Science Park Dr.)',
#          '118264',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb45af787aa9521e31aadd1-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55e39e17498eae67c36f573b',
#        'name': 'Starbucks',
#        'location': {'address': '45 Science Park Rd #01-01',
#         'crossStreet': 'Singapore Science Park II',
#         'lat': 1.2874915150990114,
#         'lng': 103.78275531312087,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2874915150990114,
#           'lng': 103.78275531312087}],
#         'distance': 266,
#         'postalCode': '117407',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['45 Science Park Rd #01-01 (Singapore Science Park II)',
#          '117407',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55e39e17498eae67c36f573b-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d5cc217fb186dcb42fa039b',
#        'name': 'NUH Medical Centre (One@KentRidge)',
#        'location': {'address': '1 Lower Kent Ridge Rd',
#         'lat': 1.293741710397293,
#         'lng': 103.78435754711131,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.293741710397293,
#           'lng': 103.78435754711131}],
#         'distance': 520,
#         'postalCode': '119082',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Lower Kent Ridge Rd', '119082', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d104941735',
#          'name': 'Medical Center',
#          'pluralName': 'Medical Centers',
#          'shortName': 'Medical',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d5cc217fb186dcb42fa039b-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55211298498e52f76b90a21c',
#        'name': 'Diamond Kitchen 鑽石小廚',
#        'location': {'address': '#01-01 Oasis',
#         'crossStreet': '87 Science Park Drive',
#         'lat': 1.2875385233656247,
#         'lng': 103.79044427126507,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2875385233656247,
#           'lng': 103.79044427126507}],
#         'distance': 676,
#         'postalCode': '118260',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-01 Oasis (87 Science Park Drive)',
#          '118260',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55211298498e52f76b90a21c-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b78b42af964a52094de2ee3',
#        'name': 'Kent Ridge Park',
#        'location': {'address': 'Vigilante Dr',
#         'crossStreet': 'off South Buona Vista Rd',
#         'lat': 1.2838981812142432,
#         'lng': 103.79080295562744,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2838981812142432,
#           'lng': 103.79080295562744}],
#         'distance': 902,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Vigilante Dr (off South Buona Vista Rd)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b78b42af964a52094de2ee3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdbbfd2fc97370492eed005',
#        'name': 'Mr. Bean',
#        'location': {'address': '#01-12 Main Building, NUH',
#         'crossStreet': '5 Lower Kent Ridge Rd',
#         'lat': 1.2944918139449566,
#         'lng': 103.78433244621854,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2944918139449566,
#           'lng': 103.78433244621854}],
#         'distance': 603,
#         'postalCode': '119074',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-12 Main Building, NUH (5 Lower Kent Ridge Rd)',
#          '119074',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cdbbfd2fc97370492eed005-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5152742de4b09402e5cff6d4',
#        'name': "Breadstick's Cafe",
#        'location': {'address': '41 Science Park',
#         'crossStreet': '41 Science Park II',
#         'lat': 1.2886483610092634,
#         'lng': 103.78324889505281,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2886483610092634,
#           'lng': 103.78324889505281}],
#         'distance': 153,
#         'postalCode': '117610',
#         'cc': 'SG',
#         'neighborhood': 'Science Park Road',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['41 Science Park (41 Science Park II)',
#          '117610',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'shortName': 'Vietnamese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5152742de4b09402e5cff6d4-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2f3434ed37a59392cd6603',
#        'name': 'Khansama Tandoori Village',
#        'location': {'address': '#02-01 The Science Hub, 87 Science Park Dr.',
#         'crossStreet': 'Science Park 1',
#         'lat': 1.287893562288713,
#         'lng': 103.79023159269937,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.287893562288713,
#           'lng': 103.79023159269937}],
#         'distance': 644,
#         'postalCode': '118260',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#02-01 The Science Hub, 87 Science Park Dr. (Science Park 1)',
#          '118260',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2f3434ed37a59392cd6603-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52d762c1498e948dbdbb9084',
#        'name': 'Subway',
#        'location': {'address': 'NUH Center, Kent Ridge',
#         'lat': 1.2944492246814172,
#         'lng': 103.7843769380896,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2944492246814172,
#           'lng': 103.7843769380896}],
#         'distance': 598,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['NUH Center, Kent Ridge', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52d762c1498e948dbdbb9084-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b51b013f964a520a05227e3',
#        'name': 'Ju Shin Jung Korean Charcoal BBQ',
#        'location': {'address': '27 West Coast Highway, #01-18/19 Westway',
#         'lat': 1.2834278172633666,
#         'lng': 103.78090231804669,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2834278172633666,
#           'lng': 103.78090231804669}],
#         'distance': 748,
#         'postalCode': '117867',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['27 West Coast Highway, #01-18/19 Westway',
#          '117867',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b51b013f964a520a05227e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca46bcd5720b1f728b139ef',
#        'name': 'Barrels',
#        'location': {'address': '34 South Buona Vista Rd',
#         'lat': 1.2808070291102478,
#         'lng': 103.78685227962609,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2808070291102478,
#           'lng': 103.78685227962609}],
#         'distance': 954,
#         'postalCode': '118162',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['34 South Buona Vista Rd',
#          '118162',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ca46bcd5720b1f728b139ef-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bac92b4f964a520f7fb3ae3',
#        'name': '99 玖玖 Buona Vista Kitchen',
#        'location': {'address': '22 South Buona Vista Rd.',
#         'lat': 1.2804962450030761,
#         'lng': 103.7866607293182,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2804962450030761,
#           'lng': 103.7866607293182}],
#         'distance': 982,
#         'cc': 'SG',
#         'neighborhood': 'Central Region',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['22 South Buona Vista Rd.', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bac92b4f964a520f7fb3ae3-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba57019f964a520120739e3',
#        'name': 'Fitness Network @ Science Park',
#        'location': {'lat': 1.2881913716133162,
#         'lng': 103.79040366421044,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2881913716133162,
#           'lng': 103.79040366421044}],
#         'distance': 657,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba57019f964a520120739e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548533e1498e8f59ce341e34',
#        'name': 'Yolé',
#        'location': {'address': 'One @ Kent Ridge #01-37',
#         'crossStreet': '1 Lower Kent Ridge Road',
#         'lat': 1.2944612708679448,
#         'lng': 103.78437721146534,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2944612708679448,
#           'lng': 103.78437721146534}],
#         'distance': 600,
#         'postalCode': '119082',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['One @ Kent Ridge #01-37 (1 Lower Kent Ridge Road)',
#          '119082',
#          'Singapore']},
#        'categories': [{'id': '512e7cae91d4cbb4e5efe0af',
#          'name': 'Frozen Yogurt Shop',
#          'pluralName': 'Frozen Yogurt Shops',
#          'shortName': 'Yogurt',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/frozenyogurt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-548533e1498e8f59ce341e34-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4b9e08b61c745d8af1646b',
#        'name': 'The Coffee Bean & Tea Leaf',
#        'location': {'address': '#01-10, NUH Main Building',
#         'crossStreet': '5 Lower Kent Ridge Rd',
#         'lat': 1.2944771890720839,
#         'lng': 103.78420033279265,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2944771890720839,
#           'lng': 103.78420033279265}],
#         'distance': 602,
#         'postalCode': '119074',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-10, NUH Main Building (5 Lower Kent Ridge Rd)',
#          '119074',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e4b9e08b61c745d8af1646b-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd7c193f645c9b63db2a6e0',
#        'name': 'Best Bites @ Kendall',
#        'location': {'crossStreet': '50 Science Park Road',
#         'lat': 1.286387854275013,
#         'lng': 103.78354381825126,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.286387854275013,
#           'lng': 103.78354381825126}],
#         'distance': 319,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd7c193f645c9b63db2a6e0-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '526763c311d22cdfeb945d19',
#        'name': 'Starbucks',
#        'location': {'address': '#03-12 One@KentRidge (NUH Medical Centre)',
#         'crossStreet': '1 Lower Kent Ridge Rd.',
#         'lat': 1.2940407573135357,
#         'lng': 103.78448314602835,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2940407573135357,
#           'lng': 103.78448314602835}],
#         'distance': 553,
#         'postalCode': '119082',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#03-12 One@KentRidge (NUH Medical Centre) (1 Lower Kent Ridge Rd.)',
#          '119082',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-526763c311d22cdfeb945d19-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52f4d1c9498e33ea6a745e9f',
#        'name': 'Ottoman Kebab & Grill',
#        'location': {'address': '#01-34, Ascent (at Savourworld)',
#         'crossStreet': '2 Science Park Drive',
#         'lat': 1.2912627401187882,
#         'lng': 103.7844407558441,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2912627401187882,
#           'lng': 103.7844407558441}],
#         'distance': 244,
#         'postalCode': '118222',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['#01-34, Ascent (at Savourworld) (2 Science Park Drive)',
#          '118222',
#          'Singapore']},
#        'categories': [{'id': '5283c7b4e4b094cb91ec88d7',
#          'name': 'Kebab Restaurant',
#          'pluralName': 'Kebab Restaurants',
#          'shortName': 'Kebab',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52f4d1c9498e33ea6a745e9f-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '586f6c6e16f000131101bcc2',
#        'name': 'Kaffe & Toast',
#        'location': {'address': '1 Lower Kent Ridge',
#         'lat': 1.2944180300762302,
#         'lng': 103.78438880610335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2944180300762302,
#           'lng': 103.78438880610335}],
#         'distance': 595,
#         'cc': 'SG',
#         'neighborhood': 'Central Region',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Lower Kent Ridge', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-586f6c6e16f000131101bcc2-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b06c53af964a520f0ef22e3',
#        'name': 'Haw Par Villa',
#        'location': {'address': '262 Pasir Panjang Rd',
#         'lat': 1.2838552766437283,
#         'lng': 103.78142058849335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2838552766437283,
#           'lng': 103.78142058849335}],
#         'distance': 677,
#         'postalCode': '118628',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['262 Pasir Panjang Rd', '118628', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d166941735',
#          'name': 'Sculpture Garden',
#          'pluralName': 'Sculpture Gardens',
#          'shortName': 'Sculpture',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b06c53af964a520f0ef22e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dae6749fa8cf04fbdff2466',
#        'name': 'Ashoka Tandoor',
#        'location': {'address': '1 Science Park Road #01-11',
#         'crossStreet': 'Science Park 2',
#         'lat': 1.2894858526570812,
#         'lng': 103.77892287257826,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2894858526570812,
#           'lng': 103.77892287257826}],
#         'distance': 628,
#         'postalCode': '117528',
#         'cc': 'SG',
#         'neighborhood': 'Central Region',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Science Park Road #01-11 (Science Park 2)',
#          '117528',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dae6749fa8cf04fbdff2466-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbacff33db7b71387ba239a',
#        'name': 'Subway',
#        'location': {'address': 'Science Hub',
#         'crossStreet': '87 Science Park Drive',
#         'lat': 1.2874749712581857,
#         'lng': 103.79043853551268,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2874749712581857,
#           'lng': 103.79043853551268}],
#         'distance': 678,
#         'postalCode': '118260',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Science Hub (87 Science Park Drive)',
#          '118260',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbacff33db7b71387ba239a-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ca4a2af1ee76dcb435e03de',
#        'name': 'SuperSnacks',
#        'location': {'address': "29 Prince George's Park",
#         'crossStreet': 'near Residence 3',
#         'lat': 1.2912264678253609,
#         'lng': 103.78015560515489,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2912264678253609,
#           'lng': 103.78015560515489}],
#         'distance': 545,
#         'postalCode': '118426',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ["29 Prince George's Park (near Residence 3)",
#          '118426',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '32825701'}},
#       'referralId': 'e-0-4ca4a2af1ee76dcb435e03de-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56f94b7d498e1784e09bb001',
#        'name': 'Two Wings',
#        'location': {'address': 'timbre+',
#         'crossStreet': '73A Ayer Rajah Crescent',
#         'lat': 1.2974543319526448,
#         'lng': 103.78733153364837,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2974543319526448,
#           'lng': 103.78733153364837}],
#         'distance': 982,
#         'postalCode': '139957',
#         'cc': 'SG',
#         'neighborhood': 'Central Region',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['timbre+ (73A Ayer Rajah Crescent)',
#          '139957',
#          'Singapore']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56f94b7d498e1784e09bb001-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cdd06ee930af04d47bd9397',
#        'name': 'Ten Courts of Hell',
#        'location': {'address': '262 Pasir Panjang Road',
#         'crossStreet': 'Haw Par Villa (Tiger Balm Gardens)',
#         'lat': 1.2838997792962612,
#         'lng': 103.78172843293706,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2838997792962612,
#           'lng': 103.78172843293706}],
#         'distance': 656,
#         'postalCode': '118628',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['262 Pasir Panjang Road (Haw Par Villa (Tiger Balm Gardens))',
#          '118628',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d182941735',
#          'name': 'Theme Park',
#          'pluralName': 'Theme Parks',
#          'shortName': 'Theme Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/themepark_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cdd06ee930af04d47bd9397-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53281e84498e4e312c042fb9',
#        'name': 'Sunny Korean',
#        'location': {'address': '5 Lower Kent Ridge Road #01-12',
#         'crossStreet': 'National University Hospital',
#         'lat': 1.2944616473123893,
#         'lng': 103.78438261528443,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2944616473123893,
#           'lng': 103.78438261528443}],
#         'distance': 600,
#         'postalCode': '119074',
#         'cc': 'SG',
#         'state': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['5 Lower Kent Ridge Road #01-12 (National University Hospital)',
#          '119074',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'shortName': 'Korean',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53281e84498e4e312c042fb9-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52d8c2e8498ed22ccafca6bc',
#        'name': 'Seasonal Salad Bar',
#        'location': {'address': 'Lv 4, One@KentRidge (NUH Medical Centre)',
#         'crossStreet': '1 Lower Kent Ridge Rd.',
#         'lat': 1.2940217639287996,
#         'lng': 103.78451152441755,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2940217639287996,
#           'lng': 103.78451152441755}],
#         'distance': 550,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Lv 4, One@KentRidge (NUH Medical Centre) (1 Lower Kent Ridge Rd.)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52d8c2e8498ed22ccafca6bc-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55a4ca4a498ecaa5f89774cd',
#        'name': 'Kick Cafe @ Block 69',
#        'location': {'address': 'Blk 69',
#         'lat': 1.296386561370893,
#         'lng': 103.78673674751776,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.296386561370893,
#           'lng': 103.78673674751776}],
#         'distance': 849,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Blk 69', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55a4ca4a498ecaa5f89774cd-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5285f0d211d222ec665a479b',
#        'name': 'Xin Wang Hong Kong Café',
#        'location': {'address': 'One@KentRidge (NUH Medical Centre)',
#         'crossStreet': '1 Lower Kent Ridge Rd.',
#         'lat': 1.294069540854595,
#         'lng': 103.7844786414845,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.294069540854595,
#           'lng': 103.7844786414845}],
#         'distance': 556,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['One@KentRidge (NUH Medical Centre) (1 Lower Kent Ridge Rd.)',
#          'Singapore']},
#        'categories': [{'id': '52af3add3cf9994f4e043bf5',
#          'name': 'Hong Kong Restaurant',
#          'pluralName': 'Hong Kong Restaurants',
#          'shortName': 'Hong Kong',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5285f0d211d222ec665a479b-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54f90353498ec3febda7b885',
#        'name': 'Paddy Hills',
#        'location': {'address': '38 South Buona Vista Road',
#         'lat': 1.2809055856957479,
#         'lng': 103.78702640533447,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2809055856957479,
#           'lng': 103.78702640533447}],
#         'distance': 949,
#         'postalCode': '118164',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['38 South Buona Vista Road',
#          '118164',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54f90353498ec3febda7b885-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bdaf48297cf5a002c322e11',
#        'name': 'Famous Jb Fireworkz',
#        'location': {'address': '45 Science Park Road',
#         'lat': 1.2887843,
#         'lng': 103.782776,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2887843,
#           'lng': 103.782776}],
#         'distance': 201,
#         'postalCode': '117610',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['45 Science Park Road', '117610', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bdaf48297cf5a002c322e11-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8b8677f964a520d3a132e3',
#        'name': 'Pasir Panjang Wholesale Centre',
#        'location': {'address': '1 - 26 Wholesale Centre',
#         'crossStreet': 'West Coast Hwy',
#         'lat': 1.2854787627762003,
#         'lng': 103.77832753258474,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2854787627762003,
#           'lng': 103.77832753258474}],
#         'distance': 800,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 - 26 Wholesale Centre (West Coast Hwy)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1ff941735',
#          'name': 'Miscellaneous Shop',
#          'pluralName': 'Miscellaneous Shops',
#          'shortName': 'Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8b8677f964a520d3a132e3-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd70cfa7b1876b0c97b8d86',
#        'name': 'Haw Par Villa MRT Station (CC25)',
#        'location': {'address': '25 West Coast Hway',
#         'lat': 1.2830391083933481,
#         'lng': 103.781920777861,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2830391083933481,
#           'lng': 103.781920777861}],
#         'distance': 733,
#         'postalCode': '117863',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['25 West Coast Hway', '117863', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fd931735',
#          'name': 'Metro Station',
#          'pluralName': 'Metro Stations',
#          'shortName': 'Metro',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd70cfa7b1876b0c97b8d86-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '507d0e5ee4b01aa9e4cb9934',
#        'name': 'NUHS Gym',
#        'location': {'address': '14 Floor Tower Block',
#         'lat': 1.292441445359178,
#         'lng': 103.78327459796554,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.292441445359178,
#           'lng': 103.78327459796554}],
#         'distance': 401,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['14 Floor Tower Block', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d176941735',
#          'name': 'Gym',
#          'pluralName': 'Gyms',
#          'shortName': 'Gym',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-507d0e5ee4b01aa9e4cb9934-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '533aa607498e678b528677b9',
#        'name': 'Xi Long Hotpot & Family KTV',
#        'location': {'address': '27 West Coast Highway',
#         'lat': 1.2830501612119989,
#         'lng': 103.78066622506556,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2830501612119989,
#           'lng': 103.78066622506556}],
#         'distance': 798,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['27 West Coast Highway', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-533aa607498e678b528677b9-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '52e4d6f4498e98feec8ca8f7',
#        'name': 'Burger King',
#        'location': {'address': 'One@KentRidge (NUH Medical Centre)',
#         'crossStreet': '1 Lower Kent Ridge Rd.',
#         'lat': 1.2940685245992452,
#         'lng': 103.78446286509259,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2940685245992452,
#           'lng': 103.78446286509259}],
#         'distance': 556,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['One@KentRidge (NUH Medical Centre) (1 Lower Kent Ridge Rd.)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'shortName': 'Fast Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-52e4d6f4498e98feec8ca8f7-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d13ea9b73fc2d4344a4b26c',
#        'name': "Oriental Delight Catering (Lucy's) @ DSO Science Park",
#        'location': {'address': '20 Science Park Drive',
#         'lat': 1.2888876412051455,
#         'lng': 103.78917253046878,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2888876412051455,
#           'lng': 103.78917253046878}],
#         'distance': 513,
#         'postalCode': '118230',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['20 Science Park Drive', '118230', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d13ea9b73fc2d4344a4b26c-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c92e94c6cfea0934416b68b',
#        'name': 'Basement Food Court',
#        'location': {'lat': 1.2922999498147973,
#         'lng': 103.78832110503537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2922999498147973,
#           'lng': 103.78832110503537}],
#         'distance': 551,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c92e94c6cfea0934416b68b-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f2f89c2e4b01982f3268f2b',
#        'name': 'Laughing buddha',
#        'location': {'address': 'Haw Par Villa, Pasir Panjang Road',
#         'lat': 1.284592959051131,
#         'lng': 103.78228865604565,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.284592959051131,
#           'lng': 103.78228865604565}],
#         'distance': 559,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Haw Par Villa, Pasir Panjang Road',
#          'Singapore']},
#        'categories': [{'id': '52e81612bcbc57f1066b79ed',
#          'name': 'Outdoor Sculpture',
#          'pluralName': 'Outdoor Sculptures',
#          'shortName': 'Outdoor Sculpture',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f2f89c2e4b01982f3268f2b-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e1bd18ab0fb719c6e0f1a38',
#        'name': 'TUV SUD Cafeteria',
#        'location': {'address': '1 Science Park Drive',
#         'lat': 1.2931895705385021,
#         'lng': 103.78756844890265,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2931895705385021,
#           'lng': 103.78756844890265}],
#         'distance': 567,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Science Park Drive', 'Singapore']},
#        'categories': [{'id': '4d4b7105d754a06374d81259',
#          'name': 'Food',
#          'pluralName': 'Food',
#          'shortName': 'Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e1bd18ab0fb719c6e0f1a38-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e89460b9a52bc371efb548d',
#        'name': 'Soo SanNa Cafe',
#        'location': {'address': '71 Science Park Dr',
#         'lat': 1.2909642747930918,
#         'lng': 103.78930327417791,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2909642747930918,
#           'lng': 103.78930327417791}],
#         'distance': 568,
#         'postalCode': '118253',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['71 Science Park Dr', '118253', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e89460b9a52bc371efb548d-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c3aa0014565e21eda88556a',
#        'name': 'Kopitiam',
#        'location': {'address': '1 Wholesale Centre, #01-02',
#         'lat': 1.2851512867676709,
#         'lng': 103.77908152635116,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2851512867676709,
#           'lng': 103.77908152635116}],
#         'distance': 749,
#         'postalCode': '110001',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['1 Wholesale Centre, #01-02',
#          '110001',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c3aa0014565e21eda88556a-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d6b1965790d37046fc4e390',
#        'name': 'Delibar Cafe',
#        'location': {'address': '87 Science Park Dr, Science Hub',
#         'lat': 1.2875388263824628,
#         'lng': 103.79037477267653,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2875388263824628,
#           'lng': 103.79037477267653}],
#         'distance': 669,
#         'postalCode': '118260',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['87 Science Park Dr, Science Hub',
#          '118260',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d6b1965790d37046fc4e390-43'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4da4df987ccc816e8b869b7b',
#        'name': 'XIAO MEI Coffee Stall',
#        'location': {'address': '2-4 Ayer Rajah Crescent',
#         'lat': 1.2938229010285485,
#         'lng': 103.78851194209511,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2938229010285485,
#           'lng': 103.78851194209511}],
#         'distance': 687,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['2-4 Ayer Rajah Crescent', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4da4df987ccc816e8b869b7b-44'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3fd5591bd2a143aec6ec7c',
#        'name': '51A Ayer Rajah Crescent Hawker',
#        'location': {'address': '51A Ayer Rajah Crescent',
#         'lat': 1.293835327413666,
#         'lng': 103.7885869734595,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.293835327413666,
#           'lng': 103.7885869734595}],
#         'distance': 694,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['51A Ayer Rajah Crescent', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d3fd5591bd2a143aec6ec7c-45'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d17278cb15cb1f7c74ab221',
#        'name': 'Chilli Padi Nonya Cafe',
#        'location': {'address': '29 Heng Mui Keng Terrace',
#         'lat': 1.2916925066167102,
#         'lng': 103.77751342838499,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2916925066167102,
#           'lng': 103.77751342838499}],
#         'distance': 836,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['29 Heng Mui Keng Terrace', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d17278cb15cb1f7c74ab221-46'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d06136fe8d8594131542fa6',
#        'name': 'Chelsea FC Supporters Club (CFCSG)',
#        'location': {'address': 'The Jockey Club',
#         'crossStreet': '27 West Coast Highway, Westway,',
#         'lat': 1.2831902557086854,
#         'lng': 103.7806749343872,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2831902557086854,
#           'lng': 103.7806749343872}],
#         'distance': 784,
#         'postalCode': '117867',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['The Jockey Club (27 West Coast Highway, Westway,)',
#          '117867',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'shortName': 'Sports Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d06136fe8d8594131542fa6-47'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cd3496f4944721e57edeba6',
#        'name': 'Bus Stop 18131 (Science Pk)',
#        'location': {'address': 'AYE',
#         'lat': 1.2895634798322158,
#         'lng': 103.79185357283752,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2895634798322158,
#           'lng': 103.79185357283752}],
#         'distance': 813,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['AYE', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1fe931735',
#          'name': 'Bus Station',
#          'pluralName': 'Bus Stations',
#          'shortName': 'Bus Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cd3496f4944721e57edeba6-48'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cee1b8613aea143c8f06b9f',
#        'name': 'Bus Stop 18049 (Opp Normanton Park)',
#        'location': {'address': 'Ayer Rajah Expy',
#         'lat': 1.290144807533232,
#         'lng': 103.79204168590184,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.290144807533232,
#           'lng': 103.79204168590184}],
#         'distance': 841,
#         'cc': 'SG',
#         'neighborhood': 'Central Region',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Ayer Rajah Expy', 'Singapore']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b4f',
#          'name': 'Bus Stop',
#          'pluralName': 'Bus Stops',
#          'shortName': 'Bus Stop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/busstation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cee1b8613aea143c8f06b9f-49'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8b4edee51e6dcb023771de',
#        'name': 'Normanton Park Swimming Pool Seats',
#        'location': {'lat': 1.287149,
#         'lng': 103.792575,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.287149,
#           'lng': 103.792575}],
#         'distance': 917,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d15e941735',
#          'name': 'Pool',
#          'pluralName': 'Pools',
#          'shortName': 'Pool',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8b4edee51e6dcb023771de-50'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dff3e5352b1d747f678f0c9',
#        'name': 'Bayville Condominium',
#        'location': {'address': '42 South Buona Vista Rd',
#         'lat': 1.2813750881249273,
#         'lng': 103.78767842975958,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2813750881249273,
#           'lng': 103.78767842975958}],
#         'distance': 924,
#         'postalCode': '118166',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['42 South Buona Vista Rd',
#          '118166',
#          'Singapore']},
#        'categories': [{'id': '4d954b06a243a5684965b473',
#          'name': 'Residential Building (Apartment / Condo)',
#          'pluralName': 'Residential Buildings (Apartments / Condos)',
#          'shortName': 'Residential',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dff3e5352b1d747f678f0c9-51'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d3204d0c75a6ea801120aae',
#        'name': 'Look Out Point | Kent Ridge Park',
#        'location': {'address': 'Kent Ridge Park',
#         'lat': 1.2833743821225525,
#         'lng': 103.79091864983809,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2833743821225525,
#           'lng': 103.79091864983809}],
#         'distance': 950,
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Kent Ridge Park', 'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d3204d0c75a6ea801120aae-52'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '561729b4498ec6b931ad904c',
#        'name': 'Yong Kee Famous Fishball Noodles',
#        'location': {'address': 'Alexandra Village Food Centre #01-26',
#         'crossStreet': 'Jalan Bukit Merah',
#         'lat': 1.2888186628499239,
#         'lng': 103.7932106426997,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2888186628499239,
#           'lng': 103.7932106426997}],
#         'distance': 963,
#         'cc': 'SG',
#         'neighborhood': 'Central Region',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'formattedAddress': ['Alexandra Village Food Centre #01-26 (Jalan Bukit Merah)',
#          'Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'shortName': 'Noodles',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-561729b4498ec6b931ad904c-53'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c98b10907916dcb3319ee1b',
#        'name': 'Golden Mile / Thai Disco',
#        'location': {'lat': 1.289035998320592,
#         'lng': 103.79348516464233,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.289035998320592,
#           'lng': 103.79348516464233}],
#         'distance': 993,
#         'cc': 'SG',
#         'country': 'Singapore',
#         'formattedAddress': ['Singapore']},
#        'categories': [{'id': '4bf58dd8d48988d11f941735',
#          'name': 'Nightclub',
#          'pluralName': 'Nightclubs',
#          'shortName': 'Nightclub',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c98b10907916dcb3319ee1b-54'}]}]}}

# %%
#function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list=row['categories']
    except:
        categories_list=row['venue.categories']
    
    if len(categories_list)==0:
        return None
    else:
        
        return categories_list[0]['name']

# %%
#Cleaning the json and structuring it into a Pandas DataFrame
venues = results['response']['groups'][0]['items']

#flatten json
nearby_venues = pd.json_normalize(venues)
                       
#filter columns
filtered_columns=['venue.name','venue.categories','venue.location.lat','venue.location.lng']
nearby_venues=nearby_venues.loc[:,filtered_columns]

#filter category for each row
nearby_venues['venue.categories']=nearby_venues.apply(get_category_type, axis=1)
                           
#clean columns
nearby_venues.columns=[col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head(200)
# Out:
#                                                  name  \
# 0                               The Good Beer Company
# 1                                           Starbucks
# 2                                           Starbucks
# 3                  NUH Medical Centre (One@KentRidge)
# 4                                Diamond Kitchen 鑽石小廚
# 5                                     Kent Ridge Park
# 6                                            Mr. Bean
# 7                                   Breadstick's Cafe
# 8                           Khansama Tandoori Village
# 9                                              Subway
# 10                   Ju Shin Jung Korean Charcoal BBQ
# 11                                            Barrels
# 12                          99 玖玖 Buona Vista Kitchen
# 13                     Fitness Network @ Science Park
# 14                                               Yolé
# 15                         The Coffee Bean & Tea Leaf
# 16                               Best Bites @ Kendall
# 17                                          Starbucks
# 18                              Ottoman Kebab & Grill
# 19                                      Kaffe & Toast
# 20                                      Haw Par Villa
# 21                                     Ashoka Tandoor
# 22                                             Subway
# 23                                        SuperSnacks
# 24                                          Two Wings
# 25                                 Ten Courts of Hell
# 26                                       Sunny Korean
# 27                                 Seasonal Salad Bar
# 28                               Kick Cafe @ Block 69
# 29                            Xin Wang Hong Kong Café
# 30                                        Paddy Hills
# 31                                Famous Jb Fireworkz
# 32                     Pasir Panjang Wholesale Centre
# 33                   Haw Par Villa MRT Station (CC25)
# 34                                           NUHS Gym
# 35                        Xi Long Hotpot & Family KTV
# 36                                        Burger King
# 37  Oriental Delight Catering (Lucy's) @ DSO Scien...
# 38                                Basement Food Court
# 39                                    Laughing buddha
# 40                                  TUV SUD Cafeteria
# 41                                     Soo SanNa Cafe
# 42                                           Kopitiam
# 43                                       Delibar Cafe
# 44                              XIAO MEI Coffee Stall
# 45                     51A Ayer Rajah Crescent Hawker
# 46                             Chilli Padi Nonya Cafe
# 47                 Chelsea FC Supporters Club (CFCSG)
# 48                        Bus Stop 18131 (Science Pk)
# 49                Bus Stop 18049 (Opp Normanton Park)
# 50                 Normanton Park Swimming Pool Seats
# 51                               Bayville Condominium
# 52                   Look Out Point | Kent Ridge Park
# 53                   Yong Kee Famous Fishball Noodles
# 54                           Golden Mile / Thai Disco
#
#                                   categories       lat         lng
# 0                                   Beer Bar  1.291737  103.784266
# 1                                Coffee Shop  1.289674  103.789908
# 2                                Coffee Shop  1.287492  103.782755
# 3                             Medical Center  1.293742  103.784358
# 4                         Chinese Restaurant  1.287539  103.790444
# 5                                       Park  1.283898  103.790803
# 6                                Snack Place  1.294492  103.784332
# 7                      Vietnamese Restaurant  1.288648  103.783249
# 8                          Indian Restaurant  1.287894  103.790232
# 9                             Sandwich Place  1.294449  103.784377
# 10                         Korean Restaurant  1.283428  103.780902
# 11                                       Bar  1.280807  103.786852
# 12                        Chinese Restaurant  1.280496  103.786661
# 13                                       Gym  1.288191  103.790404
# 14                        Frozen Yogurt Shop  1.294461  103.784377
# 15                               Coffee Shop  1.294477  103.784200
# 16                          Asian Restaurant  1.286388  103.783544
# 17                               Coffee Shop  1.294041  103.784483
# 18                          Kebab Restaurant  1.291263  103.784441
# 19                               Coffee Shop  1.294418  103.784389
# 20                          Sculpture Garden  1.283855  103.781421
# 21                         Indian Restaurant  1.289486  103.778923
# 22                            Sandwich Place  1.287475  103.790439
# 23                      Fast Food Restaurant  1.291226  103.780156
# 24                       Fried Chicken Joint  1.297454  103.787332
# 25                                Theme Park  1.283900  103.781728
# 26                         Korean Restaurant  1.294462  103.784383
# 27                                Restaurant  1.294022  103.784512
# 28                                      Café  1.296387  103.786737
# 29                      Hong Kong Restaurant  1.294070  103.784479
# 30                                      Café  1.280906  103.787026
# 31                          Asian Restaurant  1.288784  103.782776
# 32                        Miscellaneous Shop  1.285479  103.778328
# 33                             Metro Station  1.283039  103.781921
# 34                                       Gym  1.292441  103.783275
# 35                          Asian Restaurant  1.283050  103.780666
# 36                      Fast Food Restaurant  1.294069  103.784463
# 37                          Asian Restaurant  1.288888  103.789173
# 38                                Food Court  1.292300  103.788321
# 39                         Outdoor Sculpture  1.284593  103.782289
# 40                                      Food  1.293190  103.787568
# 41                                      Café  1.290964  103.789303
# 42                                Food Court  1.285151  103.779082
# 43                          Asian Restaurant  1.287539  103.790375
# 44                            Breakfast Spot  1.293823  103.788512
# 45                                Food Court  1.293835  103.788587
# 46                          Asian Restaurant  1.291693  103.777513
# 47                                Sports Bar  1.283190  103.780675
# 48                               Bus Station  1.289563  103.791854
# 49                                  Bus Stop  1.290145  103.792042
# 50                                      Pool  1.287149  103.792575
# 51  Residential Building (Apartment / Condo)  1.281375  103.787678
# 52                            Scenic Lookout  1.283374  103.790919
# 53                              Noodle House  1.288819  103.793211
# 54                                 Nightclub  1.289036  103.793485

# %%
#create 3 additional columns to indicate respective planning area and its longitude and latitude
queenstown=nearby_venues.assign(planning_area='QUEENSTOWN',
                           area_latitude=latitude,
                           area_longitude=longitude)

# %%
#Repositioning the columns and renaming the column names
queenstown=queenstown[['planning_area','area_latitude','area_longitude','name','lat','lng','categories']]
queenstown.rename(columns={'name':'venue_name',
            'lat':'venue_latitude',
             'lng':'venue_longitude',
             'categories':'venue_categories'}, inplace=True)

# %%
#check data
queenstown
# Out:
#    planning_area  area_latitude  area_longitude  \
# 0     QUEENSTOWN       1.289073      103.784559
# 1     QUEENSTOWN       1.289073      103.784559
# 2     QUEENSTOWN       1.289073      103.784559
# 3     QUEENSTOWN       1.289073      103.784559
# 4     QUEENSTOWN       1.289073      103.784559
# 5     QUEENSTOWN       1.289073      103.784559
# 6     QUEENSTOWN       1.289073      103.784559
# 7     QUEENSTOWN       1.289073      103.784559
# 8     QUEENSTOWN       1.289073      103.784559
# 9     QUEENSTOWN       1.289073      103.784559
# 10    QUEENSTOWN       1.289073      103.784559
# 11    QUEENSTOWN       1.289073      103.784559
# 12    QUEENSTOWN       1.289073      103.784559
# 13    QUEENSTOWN       1.289073      103.784559
# 14    QUEENSTOWN       1.289073      103.784559
# 15    QUEENSTOWN       1.289073      103.784559
# 16    QUEENSTOWN       1.289073      103.784559
# 17    QUEENSTOWN       1.289073      103.784559
# 18    QUEENSTOWN       1.289073      103.784559
# 19    QUEENSTOWN       1.289073      103.784559
# 20    QUEENSTOWN       1.289073      103.784559
# 21    QUEENSTOWN       1.289073      103.784559
# 22    QUEENSTOWN       1.289073      103.784559
# 23    QUEENSTOWN       1.289073      103.784559
# 24    QUEENSTOWN       1.289073      103.784559
# 25    QUEENSTOWN       1.289073      103.784559
# 26    QUEENSTOWN       1.289073      103.784559
# 27    QUEENSTOWN       1.289073      103.784559
# 28    QUEENSTOWN       1.289073      103.784559
# 29    QUEENSTOWN       1.289073      103.784559
# 30    QUEENSTOWN       1.289073      103.784559
# 31    QUEENSTOWN       1.289073      103.784559
# 32    QUEENSTOWN       1.289073      103.784559
# 33    QUEENSTOWN       1.289073      103.784559
# 34    QUEENSTOWN       1.289073      103.784559
# 35    QUEENSTOWN       1.289073      103.784559
# 36    QUEENSTOWN       1.289073      103.784559
# 37    QUEENSTOWN       1.289073      103.784559
# 38    QUEENSTOWN       1.289073      103.784559
# 39    QUEENSTOWN       1.289073      103.784559
# 40    QUEENSTOWN       1.289073      103.784559
# 41    QUEENSTOWN       1.289073      103.784559
# 42    QUEENSTOWN       1.289073      103.784559
# 43    QUEENSTOWN       1.289073      103.784559
# 44    QUEENSTOWN       1.289073      103.784559
# 45    QUEENSTOWN       1.289073      103.784559
# 46    QUEENSTOWN       1.289073      103.784559
# 47    QUEENSTOWN       1.289073      103.784559
# 48    QUEENSTOWN       1.289073      103.784559
# 49    QUEENSTOWN       1.289073      103.784559
# 50    QUEENSTOWN       1.289073      103.784559
# 51    QUEENSTOWN       1.289073      103.784559
# 52    QUEENSTOWN       1.289073      103.784559
# 53    QUEENSTOWN       1.289073      103.784559
# 54    QUEENSTOWN       1.289073      103.784559
#
#                                            venue_name  venue_latitude  \
# 0                               The Good Beer Company        1.291737
# 1                                           Starbucks        1.289674
# 2                                           Starbucks        1.287492
# 3                  NUH Medical Centre (One@KentRidge)        1.293742
# 4                                Diamond Kitchen 鑽石小廚        1.287539
# 5                                     Kent Ridge Park        1.283898
# 6                                            Mr. Bean        1.294492
# 7                                   Breadstick's Cafe        1.288648
# 8                           Khansama Tandoori Village        1.287894
# 9                                              Subway        1.294449
# 10                   Ju Shin Jung Korean Charcoal BBQ        1.283428
# 11                                            Barrels        1.280807
# 12                          99 玖玖 Buona Vista Kitchen        1.280496
# 13                     Fitness Network @ Science Park        1.288191
# 14                                               Yolé        1.294461
# 15                         The Coffee Bean & Tea Leaf        1.294477
# 16                               Best Bites @ Kendall        1.286388
# 17                                          Starbucks        1.294041
# 18                              Ottoman Kebab & Grill        1.291263
# 19                                      Kaffe & Toast        1.294418
# 20                                      Haw Par Villa        1.283855
# 21                                     Ashoka Tandoor        1.289486
# 22                                             Subway        1.287475
# 23                                        SuperSnacks        1.291226
# 24                                          Two Wings        1.297454
# 25                                 Ten Courts of Hell        1.283900
# 26                                       Sunny Korean        1.294462
# 27                                 Seasonal Salad Bar        1.294022
# 28                               Kick Cafe @ Block 69        1.296387
# 29                            Xin Wang Hong Kong Café        1.294070
# 30                                        Paddy Hills        1.280906
# 31                                Famous Jb Fireworkz        1.288784
# 32                     Pasir Panjang Wholesale Centre        1.285479
# 33                   Haw Par Villa MRT Station (CC25)        1.283039
# 34                                           NUHS Gym        1.292441
# 35                        Xi Long Hotpot & Family KTV        1.283050
# 36                                        Burger King        1.294069
# 37  Oriental Delight Catering (Lucy's) @ DSO Scien...        1.288888
# 38                                Basement Food Court        1.292300
# 39                                    Laughing buddha        1.284593
# 40                                  TUV SUD Cafeteria        1.293190
# 41                                     Soo SanNa Cafe        1.290964
# 42                                           Kopitiam        1.285151
# 43                                       Delibar Cafe        1.287539
# 44                              XIAO MEI Coffee Stall        1.293823
# 45                     51A Ayer Rajah Crescent Hawker        1.293835
# 46                             Chilli Padi Nonya Cafe        1.291693
# 47                 Chelsea FC Supporters Club (CFCSG)        1.283190
# 48                        Bus Stop 18131 (Science Pk)        1.289563
# 49                Bus Stop 18049 (Opp Normanton Park)        1.290145
# 50                 Normanton Park Swimming Pool Seats        1.287149
# 51                               Bayville Condominium        1.281375
# 52                   Look Out Point | Kent Ridge Park        1.283374
# 53                   Yong Kee Famous Fishball Noodles        1.288819
# 54                           Golden Mile / Thai Disco        1.289036
#
#     venue_longitude                          venue_categories
# 0        103.784266                                  Beer Bar
# 1        103.789908                               Coffee Shop
# 2        103.782755                               Coffee Shop
# 3        103.784358                            Medical Center
# 4        103.790444                        Chinese Restaurant
# 5        103.790803                                      Park
# 6        103.784332                               Snack Place
# 7        103.783249                     Vietnamese Restaurant
# 8        103.790232                         Indian Restaurant
# 9        103.784377                            Sandwich Place
# 10       103.780902                         Korean Restaurant
# 11       103.786852                                       Bar
# 12       103.786661                        Chinese Restaurant
# 13       103.790404                                       Gym
# 14       103.784377                        Frozen Yogurt Shop
# 15       103.784200                               Coffee Shop
# 16       103.783544                          Asian Restaurant
# 17       103.784483                               Coffee Shop
# 18       103.784441                          Kebab Restaurant
# 19       103.784389                               Coffee Shop
# 20       103.781421                          Sculpture Garden
# 21       103.778923                         Indian Restaurant
# 22       103.790439                            Sandwich Place
# 23       103.780156                      Fast Food Restaurant
# 24       103.787332                       Fried Chicken Joint
# 25       103.781728                                Theme Park
# 26       103.784383                         Korean Restaurant
# 27       103.784512                                Restaurant
# 28       103.786737                                      Café
# 29       103.784479                      Hong Kong Restaurant
# 30       103.787026                                      Café
# 31       103.782776                          Asian Restaurant
# 32       103.778328                        Miscellaneous Shop
# 33       103.781921                             Metro Station
# 34       103.783275                                       Gym
# 35       103.780666                          Asian Restaurant
# 36       103.784463                      Fast Food Restaurant
# 37       103.789173                          Asian Restaurant
# 38       103.788321                                Food Court
# 39       103.782289                         Outdoor Sculpture
# 40       103.787568                                      Food
# 41       103.789303                                      Café
# 42       103.779082                                Food Court
# 43       103.790375                          Asian Restaurant
# 44       103.788512                            Breakfast Spot
# 45       103.788587                                Food Court
# 46       103.777513                          Asian Restaurant
# 47       103.780675                                Sports Bar
# 48       103.791854                               Bus Station
# 49       103.792042                                  Bus Stop
# 50       103.792575                                      Pool
# 51       103.787678  Residential Building (Apartment / Condo)
# 52       103.790919                            Scenic Lookout
# 53       103.793211                              Noodle House
# 54       103.793485                                 Nightclub

# %%
queenstown.to_csv("queenstown.csv")

# %%
#Create a list of dataframes and concatenate them
ev_list = [bedok,jw,cck,punggol,amk,semb,queenstown ]  
all_ev = pd.concat(ev_list)

# %%
#check data
all_ev
# Out:
#    planning_area  area_latitude  area_longitude  \
# 0          BEDOK       1.324047      103.928409
# 1          BEDOK       1.324047      103.928409
# 2          BEDOK       1.324047      103.928409
# 3          BEDOK       1.324047      103.928409
# 4          BEDOK       1.324047      103.928409
# ..           ...            ...             ...
# 50    QUEENSTOWN       1.289073      103.784559
# 51    QUEENSTOWN       1.289073      103.784559
# 52    QUEENSTOWN       1.289073      103.784559
# 53    QUEENSTOWN       1.289073      103.784559
# 54    QUEENSTOWN       1.289073      103.784559
#
#                             venue_name  venue_latitude  venue_longitude  \
# 0                Bedok Chwee Kueh 勿洛水粿        1.324903       103.930250
# 1               Haidilao Hot Pot 海底捞火锅        1.324299       103.929104
# 2                 Ya Kun Kaya Toast 亞坤        1.324095       103.929198
# 3           Song Zhou Luo Bo Gao 松洲箩卜糕        1.324836       103.930520
# 4                     FairPrice Fínest        1.324140       103.929260
# ..                                 ...             ...              ...
# 50  Normanton Park Swimming Pool Seats        1.287149       103.792575
# 51                Bayville Condominium        1.281375       103.787678
# 52    Look Out Point | Kent Ridge Park        1.283374       103.790919
# 53    Yong Kee Famous Fishball Noodles        1.288819       103.793211
# 54            Golden Mile / Thai Disco        1.289036       103.793485
#
#                             venue_categories
# 0                         Chinese Restaurant
# 1                          Hotpot Restaurant
# 2                                Coffee Shop
# 3                             Breakfast Spot
# 4                                Supermarket
# ..                                       ...
# 50                                      Pool
# 51  Residential Building (Apartment / Condo)
# 52                            Scenic Lookout
# 53                              Noodle House
# 54                                 Nightclub
#
# [413 rows x 7 columns]

# %%
#save to csv 
all_ev.to_csv('all_ev.csv', index=False)

# %%
#Check number of rows and columns
all_ev.shape
# Out:
# (413, 7)

# %% [markdown]
# #### We will be leaving out Tengah as it is currently an undeveloped area and the query resulted in a warning that there were insufficient results.

# %% [markdown]
# #### THE END
